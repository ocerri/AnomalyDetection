# %%
import numpy as np
import pickle

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

# %%
vVAE = 71
vCLF = 4
Eff_SM = 5.38e-06
use_loss = 'NLL'

# %%
# BSM_samples = ['Ato4l', 'Zprime', 'Wprime', 'leptoquark', 'hToTauTau', 'hChToTauNu']
BSM_samples = ['Ato4l', 'leptoquark', 'hToTauTau', 'hChToTauNu']

BSM_labels = {'Ato4l':r'$A\to 4l$', 
              'leptoquark':r'$LQ$', 
              'hToTauTau':r'$h\to \tau\tau$', 
              'hChToTauNu':r'$h^{+}\to \tau\nu$'}

VAE_loss = {'Tot':0, 'NLL':1, 'KL':2}

# %%
style_inj = '-'

BSM_colors = {'Ato4l':'r', 'leptoquark':'g', 'hToTauTau':'b', 'hChToTauNu':'k'}

BSM_injected= 'Ato4l'

# %%
d_inj = '../VAE/VAE_HLFONLY/VAE_all-in-one_v8_ROC{ll}_dict_{n}.pkl'.format(ll=VAE_loss[use_loss], n=BSM_injected)

f = open(d_inj, 'r')
d_inj = pickle.load(f)
f.close()

# %%
d_std = ['../VAE/VAE_HLFONLY/VAE_all-in-one_v71_ROC{ll}_dict_{n}.pkl'.format(ll=VAE_loss[use_loss], n=BSM_injected),
#          '../VAE/VAE_HLFONLY/VAE_all-in-one_v7_ROC{ll}_dict_{n}.pkl'.format(ll=VAE_loss[use_loss], n=BSM_injected)
        ]

eff_BSM_std = []
AUC_std = []
eff_SM_std = 0

for f in d_std:
    f = open(f, 'r')
    d = pickle.load(f)
    f.close()
    
    eff_SM_std = d['eff_SM']
    eff_BSM_std.append(d['eff_BSM'])  
    AUC_std.append(d['roc_auc'])  


eff_BSM_std = np.array(eff_BSM_std).T
AUC_std = np.array(AUC_std)

# %%
mean_BSM_std = np.mean(eff_BSM_std, axis=1)

# %%
matplotlib.rcParams.update({'font.size': 24})
f = plt.figure(figsize=(12,12))

plt.plot(eff_SM_std, mean_BSM_std, 
         linestyle='--',
         lw=2,
         color='k',
         label='{} (Train SM) \n (area = {:0.2f}$\pm${:0.2f})'.format(BSM_labels[BSM_injected], np.mean(AUC_std), np.std(AUC_std)))

plt.plot(d_inj['eff_SM'], d_inj['eff_BSM'], 
         linestyle=style_inj,
         lw=2,
         color='r',
         label='{l} (Train SM + {l}) \n (area = {a:0.2f})'.format(l=BSM_labels[BSM_injected], a=d_inj['roc_auc']))



plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle=':')
plt.plot([Eff_SM, Eff_SM], [1e-6, 1.05], color='magenta', lw=2, linestyle=':', label='50 SM evts/day')
plt.xlim([1e-6, 1.0])
plt.ylim([1e-6, 1.05])
plt.xlabel('SM efficiency')
plt.ylabel('BSM efficiency')
plt.title('')
plt.legend(loc='lower right')
plt.yscale('log')
plt.xscale('log')
plt.grid()

plt.savefig('../fig/paper_fig/ROC_{}_injection.png'.format(BSM_injected))
