# %% [markdown]
# VampPrior
#
# - Tried with 10 hidden dim -> not converged
# - Tried to add allLepMass and hidden from 4 to 5 -> Eff improve (~70% for Zprime) but reco is a shit
# - If remove VampEff decrease
# - When VampPrior 4 nodes and AllLepMass -> Reco converging, eff is smaller on KL but good on reco prob (~50% for Zprime)

# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.12/06

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# Using TensorFlow backend.
# 2.2.2

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'PhiMET', 'MT', 'nJets', 'bJets',
                'allJetMass', 'LepPt', 'LepEta', 'LepPhi', 'LepIsoCh',
                'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 'LepIsEle', 'nMu',
                'allMuMass', 'allMuPt', 'nEle', 'allEleMass', 'allElePt', 'nChHad',
                'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'MET', 'allJetMass',
                       'allMuPt','allElePt','allEleMass', 'allMuMass',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 11
Nf_gauss = 1
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	allEleMass
# 	allMuMass
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/'
SampleName = 'ttbar'
N_train = int(2e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (3003158, 24) (2000000, 22)

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim = 50
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

def SmashTo0(x):
    return 0*x

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(20, kernel_initializer='zeros', bias_initializer='ones', trainable=False)(fixed_input)
# h2_prior = Dense(100, activation=act_fun)(h1_prior)

L_prior_mean = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='zeros', trainable=True)(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='ones', trainable=True)(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit)(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return K.mean(0.5 * K.sum(kl_loss, axis=-1))

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    mu_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    sigma_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior) + RecoProb_forVAE(y_train, par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = 4*latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train, par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim: 2*latent_dim]
    mu_prior = NETout[:, 2*latent_dim: 3*latent_dim]
    sigma_prior = NETout[:, 3*latent_dim: 4*latent_dim]
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_prior_mean, L_prior_sigma, L_par1, L_par2, L_par3])

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
print vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 22)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           1150        input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           2550        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4)            0           dense_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 22)           0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           250         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 20)           460         lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           2550        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 17)           867         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 11)           561         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 4)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 22)           1122        dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 17)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 11)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 66)           0           dense_3[0][0]
#                                                                  lambda_1[0][0]
#                                                                  dense_11[0][0]
#                                                                  lambda_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# ==================================================================================================
# Total params: 10,086
# Trainable params: 9,626
# Non-trainable params: 460
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
fit_report = vae.fit(x=x_train, y=x_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=400,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, epsilon=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# /Users/olmo/programs/miniconda2/lib/python2.7/site-packages/keras/callbacks.py:999: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Train on 1600000 samples, validate on 400000 samples
# Epoch 1/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 135424.3634 - RecoProb_metric: 135233.8795 - KL_loss_metric: 190.5304 - val_loss: 78.2778 - val_RecoProb_metric: 57.6615 - val_KL_loss_metric: 20.6163
# Epoch 2/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 69.3697 - RecoProb_metric: 52.1680 - KL_loss_metric: 17.2017 - val_loss: 63.8380 - val_RecoProb_metric: 47.8154 - val_KL_loss_metric: 16.0226
# Epoch 3/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 62.5868 - RecoProb_metric: 46.7133 - KL_loss_metric: 15.8735 - val_loss: 60.4429 - val_RecoProb_metric: 44.9114 - val_KL_loss_metric: 15.5315
# Epoch 4/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 279.0582 - RecoProb_metric: 256.1832 - KL_loss_metric: 22.8751 - val_loss: 78.7771 - val_RecoProb_metric: 61.7341 - val_KL_loss_metric: 17.0430
# Epoch 5/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 61.7661 - RecoProb_metric: 46.0819 - KL_loss_metric: 15.6841 - val_loss: 57.0859 - val_RecoProb_metric: 41.8727 - val_KL_loss_metric: 15.2132
# Epoch 6/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 57.0089 - RecoProb_metric: 42.1708 - KL_loss_metric: 14.8381 - val_loss: 54.9768 - val_RecoProb_metric: 40.6991 - val_KL_loss_metric: 14.2777
# Epoch 7/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 55.7537 - RecoProb_metric: 41.7761 - KL_loss_metric: 13.9776 - val_loss: 55.7506 - val_RecoProb_metric: 41.9831 - val_KL_loss_metric: 13.7675
# Epoch 8/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 54.4743 - RecoProb_metric: 40.9636 - KL_loss_metric: 13.5107 - val_loss: 59.4582 - val_RecoProb_metric: 46.0654 - val_KL_loss_metric: 13.3928
# Epoch 9/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 54.5966 - RecoProb_metric: 41.1305 - KL_loss_metric: 13.4661 - val_loss: 50.6518 - val_RecoProb_metric: 37.1780 - val_KL_loss_metric: 13.4739
# Epoch 10/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 53.4011 - RecoProb_metric: 39.8812 - KL_loss_metric: 13.5199 - val_loss: 54.3610 - val_RecoProb_metric: 40.7870 - val_KL_loss_metric: 13.5740
# Epoch 11/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 51.6728 - RecoProb_metric: 38.3242 - KL_loss_metric: 13.3486 - val_loss: 54.7198 - val_RecoProb_metric: 41.5177 - val_KL_loss_metric: 13.2022
# Epoch 12/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 50.7156 - RecoProb_metric: 37.4634 - KL_loss_metric: 13.2522 - val_loss: 48.7481 - val_RecoProb_metric: 35.6333 - val_KL_loss_metric: 13.1148
# Epoch 13/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 52.0978 - RecoProb_metric: 39.8306 - KL_loss_metric: 12.2673 - val_loss: 49.9410 - val_RecoProb_metric: 38.4475 - val_KL_loss_metric: 11.4936
# Epoch 14/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 48.2975 - RecoProb_metric: 38.0238 - KL_loss_metric: 10.2737 - val_loss: 48.8966 - val_RecoProb_metric: 38.1185 - val_KL_loss_metric: 10.7782
# Epoch 15/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 45.7728 - RecoProb_metric: 36.8071 - KL_loss_metric: 8.9657 - val_loss: 44.5579 - val_RecoProb_metric: 36.1264 - val_KL_loss_metric: 8.4315
# Epoch 16/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 44.7616 - RecoProb_metric: 36.4542 - KL_loss_metric: 8.3075 - val_loss: 43.4828 - val_RecoProb_metric: 35.4187 - val_KL_loss_metric: 8.0642
# Epoch 17/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 44.1913 - RecoProb_metric: 36.2337 - KL_loss_metric: 7.9576 - val_loss: 46.3423 - val_RecoProb_metric: 38.5223 - val_KL_loss_metric: 7.8200
# Epoch 18/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 43.1172 - RecoProb_metric: 36.2083 - KL_loss_metric: 6.9089 - val_loss: 42.8618 - val_RecoProb_metric: 36.2842 - val_KL_loss_metric: 6.5776
# Epoch 19/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 42.7250 - RecoProb_metric: 36.0497 - KL_loss_metric: 6.6753 - val_loss: 42.3641 - val_RecoProb_metric: 35.8786 - val_KL_loss_metric: 6.4855
# Epoch 20/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 42.3932 - RecoProb_metric: 35.7988 - KL_loss_metric: 6.5945 - val_loss: 41.3763 - val_RecoProb_metric: 34.8477 - val_KL_loss_metric: 6.5286
# Epoch 21/100
# 1600000/1600000 [==============================] - 36s 23us/step - loss: 42.2025 - RecoProb_metric: 35.6254 - KL_loss_metric: 6.5771 - val_loss: 41.4490 - val_RecoProb_metric: 35.1225 - val_KL_loss_metric: 6.3265
# Epoch 22/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 42.0326 - RecoProb_metric: 35.4841 - KL_loss_metric: 6.5485 - val_loss: 42.4253 - val_RecoProb_metric: 35.7929 - val_KL_loss_metric: 6.6324
# Epoch 23/100
# 1600000/1600000 [==============================] - 36s 22us/step - loss: 41.8132 - RecoProb_metric: 35.2727 - KL_loss_metric: 6.5405 - val_loss: 41.2331 - val_RecoProb_metric: 34.7516 - val_KL_loss_metric: 6.4815
# Epoch 24/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 41.6882 - RecoProb_metric: 35.1456 - KL_loss_metric: 6.5426 - val_loss: 41.7330 - val_RecoProb_metric: 35.1025 - val_KL_loss_metric: 6.6305
# Epoch 25/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 41.5590 - RecoProb_metric: 34.9933 - KL_loss_metric: 6.5658 - val_loss: 41.6316 - val_RecoProb_metric: 34.9640 - val_KL_loss_metric: 6.6675
# Epoch 26/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 41.4002 - RecoProb_metric: 34.8074 - KL_loss_metric: 6.5928 - val_loss: 40.9958 - val_RecoProb_metric: 34.3458 - val_KL_loss_metric: 6.6500
# Epoch 27/100
# 1600000/1600000 [==============================] - 47s 29us/step - loss: 41.2944 - RecoProb_metric: 34.6821 - KL_loss_metric: 6.6123 - val_loss: 42.3229 - val_RecoProb_metric: 35.4929 - val_KL_loss_metric: 6.8301
# Epoch 28/100
# 1600000/1600000 [==============================] - 46s 29us/step - loss: 41.1759 - RecoProb_metric: 34.5321 - KL_loss_metric: 6.6438 - val_loss: 40.9584 - val_RecoProb_metric: 34.3511 - val_KL_loss_metric: 6.6073
# Epoch 29/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 41.0351 - RecoProb_metric: 34.3474 - KL_loss_metric: 6.6877 - val_loss: 40.5860 - val_RecoProb_metric: 33.9200 - val_KL_loss_metric: 6.6660
# Epoch 30/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 40.9863 - RecoProb_metric: 34.2872 - KL_loss_metric: 6.6990 - val_loss: 40.7092 - val_RecoProb_metric: 34.1860 - val_KL_loss_metric: 6.5232
# Epoch 31/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 40.8728 - RecoProb_metric: 34.1469 - KL_loss_metric: 6.7258 - val_loss: 40.2945 - val_RecoProb_metric: 33.4737 - val_KL_loss_metric: 6.8208
# Epoch 32/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 40.7647 - RecoProb_metric: 34.0000 - KL_loss_metric: 6.7648 - val_loss: 41.2870 - val_RecoProb_metric: 34.8484 - val_KL_loss_metric: 6.4387
# Epoch 33/100
# 1600000/1600000 [==============================] - 44s 27us/step - loss: 40.6835 - RecoProb_metric: 33.8925 - KL_loss_metric: 6.7910 - val_loss: 40.6900 - val_RecoProb_metric: 33.8349 - val_KL_loss_metric: 6.8551
# Epoch 34/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 40.6008 - RecoProb_metric: 33.7733 - KL_loss_metric: 6.8274 - val_loss: 40.1492 - val_RecoProb_metric: 33.2992 - val_KL_loss_metric: 6.8500
# Epoch 35/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 40.6039 - RecoProb_metric: 33.7412 - KL_loss_metric: 6.8627 - val_loss: 39.9666 - val_RecoProb_metric: 33.1272 - val_KL_loss_metric: 6.8394
# Epoch 36/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 40.4398 - RecoProb_metric: 33.5524 - KL_loss_metric: 6.8873 - val_loss: 40.9171 - val_RecoProb_metric: 33.9320 - val_KL_loss_metric: 6.9851
# Epoch 37/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 40.4051 - RecoProb_metric: 33.4964 - KL_loss_metric: 6.9087 - val_loss: 39.8790 - val_RecoProb_metric: 32.9919 - val_KL_loss_metric: 6.8871
# Epoch 38/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 40.2953 - RecoProb_metric: 33.3519 - KL_loss_metric: 6.9434 - val_loss: 40.0446 - val_RecoProb_metric: 33.0161 - val_KL_loss_metric: 7.0285
# Epoch 39/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 40.2558 - RecoProb_metric: 33.2922 - KL_loss_metric: 6.9636 - val_loss: 39.7755 - val_RecoProb_metric: 32.8203 - val_KL_loss_metric: 6.9551
# Epoch 40/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 40.1843 - RecoProb_metric: 33.1892 - KL_loss_metric: 6.9952 - val_loss: 40.3156 - val_RecoProb_metric: 33.2091 - val_KL_loss_metric: 7.1065
# Epoch 41/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 40.1485 - RecoProb_metric: 33.1443 - KL_loss_metric: 7.0042 - val_loss: 40.4825 - val_RecoProb_metric: 33.6460 - val_KL_loss_metric: 6.8365
# Epoch 42/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 40.0883 - RecoProb_metric: 33.0643 - KL_loss_metric: 7.0240 - val_loss: 41.5730 - val_RecoProb_metric: 34.4121 - val_KL_loss_metric: 7.1610
# Epoch 43/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 40.0355 - RecoProb_metric: 32.9894 - KL_loss_metric: 7.0461 - val_loss: 40.9966 - val_RecoProb_metric: 33.9920 - val_KL_loss_metric: 7.0046
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.00010000000475.
# Epoch 44/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 39.2674 - RecoProb_metric: 31.9937 - KL_loss_metric: 7.2738 - val_loss: 39.2018 - val_RecoProb_metric: 31.8149 - val_KL_loss_metric: 7.3869
# Epoch 45/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 39.1650 - RecoProb_metric: 31.7056 - KL_loss_metric: 7.4594 - val_loss: 39.1206 - val_RecoProb_metric: 31.5869 - val_KL_loss_metric: 7.5336
# Epoch 46/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 39.1041 - RecoProb_metric: 31.5564 - KL_loss_metric: 7.5478 - val_loss: 39.0193 - val_RecoProb_metric: 31.4444 - val_KL_loss_metric: 7.5749
# Epoch 47/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 39.0608 - RecoProb_metric: 31.4607 - KL_loss_metric: 7.6001 - val_loss: 39.0182 - val_RecoProb_metric: 31.3693 - val_KL_loss_metric: 7.6488
# Epoch 48/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 39.0256 - RecoProb_metric: 31.3830 - KL_loss_metric: 7.6426 - val_loss: 39.0067 - val_RecoProb_metric: 31.3556 - val_KL_loss_metric: 7.6511
# Epoch 49/100
# 1600000/1600000 [==============================] - 43s 27us/step - loss: 38.9991 - RecoProb_metric: 31.3206 - KL_loss_metric: 7.6785 - val_loss: 38.9878 - val_RecoProb_metric: 31.3107 - val_KL_loss_metric: 7.6771
# Epoch 50/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 38.9718 - RecoProb_metric: 31.2638 - KL_loss_metric: 7.7079 - val_loss: 38.9093 - val_RecoProb_metric: 31.1899 - val_KL_loss_metric: 7.7194
# Epoch 51/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.9523 - RecoProb_metric: 31.2204 - KL_loss_metric: 7.7319 - val_loss: 38.9323 - val_RecoProb_metric: 31.1860 - val_KL_loss_metric: 7.7463
# Epoch 52/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 38.9327 - RecoProb_metric: 31.1812 - KL_loss_metric: 7.7516 - val_loss: 38.8692 - val_RecoProb_metric: 31.1364 - val_KL_loss_metric: 7.7328
# Epoch 53/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 38.9122 - RecoProb_metric: 31.1409 - KL_loss_metric: 7.7713 - val_loss: 38.8280 - val_RecoProb_metric: 31.0730 - val_KL_loss_metric: 7.7550
# Epoch 54/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.8982 - RecoProb_metric: 31.1121 - KL_loss_metric: 7.7862 - val_loss: 38.8647 - val_RecoProb_metric: 31.0773 - val_KL_loss_metric: 7.7875
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.0000000475e-05.
# Epoch 55/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.8078 - RecoProb_metric: 31.0101 - KL_loss_metric: 7.7977 - val_loss: 38.7851 - val_RecoProb_metric: 30.9866 - val_KL_loss_metric: 7.7985
# Epoch 56/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.8068 - RecoProb_metric: 31.0022 - KL_loss_metric: 7.8045 - val_loss: 38.7874 - val_RecoProb_metric: 30.9900 - val_KL_loss_metric: 7.7974
# Epoch 57/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.8031 - RecoProb_metric: 30.9935 - KL_loss_metric: 7.8096 - val_loss: 38.7721 - val_RecoProb_metric: 30.9592 - val_KL_loss_metric: 7.8128
# Epoch 58/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 38.8014 - RecoProb_metric: 30.9880 - KL_loss_metric: 7.8134 - val_loss: 38.7847 - val_RecoProb_metric: 30.9802 - val_KL_loss_metric: 7.8045
# Epoch 59/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.7996 - RecoProb_metric: 30.9825 - KL_loss_metric: 7.8171 - val_loss: 38.7751 - val_RecoProb_metric: 30.9640 - val_KL_loss_metric: 7.8111
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.00000006569e-06.
# Epoch 60/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.7846 - RecoProb_metric: 30.9675 - KL_loss_metric: 7.8171 - val_loss: 38.7611 - val_RecoProb_metric: 30.9466 - val_KL_loss_metric: 7.8145
# Epoch 61/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.7826 - RecoProb_metric: 30.9650 - KL_loss_metric: 7.8176 - val_loss: 38.7621 - val_RecoProb_metric: 30.9451 - val_KL_loss_metric: 7.8169
# Epoch 62/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 38.7832 - RecoProb_metric: 30.9650 - KL_loss_metric: 7.8182 - val_loss: 38.7619 - val_RecoProb_metric: 30.9469 - val_KL_loss_metric: 7.8151
# Epoch 63/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.7860 - RecoProb_metric: 30.9658 - KL_loss_metric: 7.8202 - val_loss: 38.7646 - val_RecoProb_metric: 30.9445 - val_KL_loss_metric: 7.8201
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.00000011116e-07.
# Epoch 64/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.7814 - RecoProb_metric: 30.9602 - KL_loss_metric: 7.8212 - val_loss: 38.7582 - val_RecoProb_metric: 30.9402 - val_KL_loss_metric: 7.8180
# Epoch 65/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 38.7827 - RecoProb_metric: 30.9626 - KL_loss_metric: 7.8201 - val_loss: 38.7604 - val_RecoProb_metric: 30.9432 - val_KL_loss_metric: 7.8173
# Epoch 00065: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.plot(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.plot(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
if 1:
    vae.save('last_saved_VAE.h5')
else:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model('last_saved_VAE.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if 1:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save('last_saved_prior.h5')
else:
    Prior_Dumper = load_model('last_saved_prior.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [-5.0799723  0.7282389  2.1745014 -1.5529678]
# [5.8661957 1.4528172 5.9247093 1.1729805]

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save('last_saved_encoder.h5')
else:
    encoder = load_model('last_saved_encoder.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
data_folder = '../../data/'

BSM_samples = ['AtoChHW', 'AtoChHW_HIGHMASS', 'Ato4l', 'Zprime', 'Wprime', 'qcd', 'Wlnu']

x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    lower_bound = mu_prior[kk] - 6*sigma_prior[kk]
    upper_bound = mu_prior[kk] + 6*sigma_prior[kk]
    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], lower_bound, upper_bound)
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], lower_bound, upper_bound)
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('last_saved_autoencoder.h5')
else:
    autoencoder = load_model('last_saved_autoencoder.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 95.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[1:]))
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = (bincenters[10]-bincenters[9])*np.ones_like(bincenters)
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# MET
# allJetMass
# allMuPt
# allElePt
# allEleMass
# allMuMass
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# LepEta
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
def numpy_KL_loss(mu, sigma):
    sp = np.atleast_2d(sigma_prior)
    mp = np.atleast_2d(mu_prior)
    kl_loss = np.square(sigma)*np.square(sp)
    kl_loss += np.square((mp - mu)/sp)
    kl_loss += np.log(sp/sigma) -1

    return 0.5 * np.sum(kl_loss, axis=-1)

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1) - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(single_NLL, axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]
    print binning
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-3))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    
    canvases.append(c)
# Out:
# [100, 18.907858919132778, 283.457557281665]
# [100, 11.644623603003403, 273.72827967156167]
# [100, 6.1632676, 52.3611108651723]
