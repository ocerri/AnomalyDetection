# %% [markdown]
# VampPrior

# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.12/06

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# Using TensorFlow backend.
# 2.2.2

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'PhiMET', 'MT', 'nJets', 'bJets',
                'allJetMass', 'LepPt', 'LepEta', 'LepPhi', 'LepIsoCh',
                'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 'LepIsEle', 'nMu',
                'allMuMass', 'allMuPt', 'nEle', 'allEleMass', 'allElePt', 'nChHad',
                'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'MET', 'allJetMass',
                       'allMuPt','allElePt',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 9
Nf_gauss = 1
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/'
SampleName = 'ttbar'
N_train = int(1e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (3003158, 24) (1000000, 20)

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim =80
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

def SmashTo0(x):
    return 0*x

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(100, kernel_initializer='zeros', bias_initializer='ones')(fixed_input)
h1_prior.trainable = False
# h2_prior = Dense(100, activation=act_fun)(h1_prior)

L_prior_mean = Dense(latent_dim)(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim)(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit)(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return K.mean(0.5 * K.sum(kl_loss, axis=-1))

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    mu_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    sigma_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior) + RecoProb_forVAE(y_train, par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = 4*latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train, par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim: 2*latent_dim]
    mu_prior = NETout[:, 2*latent_dim: 3*latent_dim]
    sigma_prior = NETout[:, 3*latent_dim: 4*latent_dim]
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_prior_mean, L_prior_sigma, L_par1, L_par2, L_par3])

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
# print vae.summary()

# %% [markdown]
# # Training

# %%
fit_report = vae.fit(x=x_train, y=x_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=200,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, min_delta=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# Train on 800000 samples, validate on 200000 samples
# Epoch 1/100
# 800000/800000 [==============================] - 40s 50us/step - loss: 40649.0155 - RecoProb_metric: 40428.1745 - KL_loss_metric: 220.8368 - val_loss: 70.0003 - val_RecoProb_metric: 54.2017 - val_KL_loss_metric: 15.7986
# Epoch 2/100
# 800000/800000 [==============================] - 50s 62us/step - loss: 64.0137 - RecoProb_metric: 49.6687 - KL_loss_metric: 14.3450 - val_loss: 58.5866 - val_RecoProb_metric: 45.0935 - val_KL_loss_metric: 13.4931
# Epoch 3/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 54.9251 - RecoProb_metric: 42.0913 - KL_loss_metric: 12.8338 - val_loss: 52.5520 - val_RecoProb_metric: 40.7567 - val_KL_loss_metric: 11.7953
# Epoch 4/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 71.0617 - RecoProb_metric: 54.8332 - KL_loss_metric: 16.2285 - val_loss: 68.9204 - val_RecoProb_metric: 53.2493 - val_KL_loss_metric: 15.6711
# Epoch 5/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 58.3733 - RecoProb_metric: 44.0108 - KL_loss_metric: 14.3625 - val_loss: 51.6865 - val_RecoProb_metric: 38.1799 - val_KL_loss_metric: 13.5066
# Epoch 6/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 53.5396 - RecoProb_metric: 40.3618 - KL_loss_metric: 13.1778 - val_loss: 50.4216 - val_RecoProb_metric: 38.1137 - val_KL_loss_metric: 12.3079
# Epoch 7/100
# 800000/800000 [==============================] - 43s 54us/step - loss: 51.1400 - RecoProb_metric: 38.8733 - KL_loss_metric: 12.2667 - val_loss: 45.2006 - val_RecoProb_metric: 35.6590 - val_KL_loss_metric: 9.5416
# Epoch 8/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 47.0695 - RecoProb_metric: 38.0104 - KL_loss_metric: 9.0591 - val_loss: 43.8487 - val_RecoProb_metric: 36.1563 - val_KL_loss_metric: 7.6924
# Epoch 9/100
# 800000/800000 [==============================] - 38s 47us/step - loss: 43.0527 - RecoProb_metric: 36.0278 - KL_loss_metric: 7.0249 - val_loss: 42.6453 - val_RecoProb_metric: 36.7093 - val_KL_loss_metric: 5.9360
# Epoch 10/100
# 800000/800000 [==============================] - 38s 47us/step - loss: 41.4218 - RecoProb_metric: 35.5325 - KL_loss_metric: 5.8893 - val_loss: 40.3854 - val_RecoProb_metric: 34.8200 - val_KL_loss_metric: 5.5654
# Epoch 11/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 40.6417 - RecoProb_metric: 34.8549 - KL_loss_metric: 5.7868 - val_loss: 39.8053 - val_RecoProb_metric: 34.0861 - val_KL_loss_metric: 5.7192
# Epoch 12/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 40.1976 - RecoProb_metric: 34.4228 - KL_loss_metric: 5.7748 - val_loss: 39.5239 - val_RecoProb_metric: 33.8400 - val_KL_loss_metric: 5.6838
# Epoch 13/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 39.9151 - RecoProb_metric: 34.1904 - KL_loss_metric: 5.7246 - val_loss: 39.6641 - val_RecoProb_metric: 34.0250 - val_KL_loss_metric: 5.6390
# Epoch 14/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 39.6155 - RecoProb_metric: 33.8313 - KL_loss_metric: 5.7842 - val_loss: 38.9252 - val_RecoProb_metric: 33.0348 - val_KL_loss_metric: 5.8904
# Epoch 15/100
# 800000/800000 [==============================] - 55s 69us/step - loss: 39.0268 - RecoProb_metric: 33.1992 - KL_loss_metric: 5.8276 - val_loss: 39.3207 - val_RecoProb_metric: 33.5862 - val_KL_loss_metric: 5.7345
# Epoch 16/100
# 800000/800000 [==============================] - 57s 71us/step - loss: 38.7537 - RecoProb_metric: 32.8482 - KL_loss_metric: 5.9055 - val_loss: 38.3387 - val_RecoProb_metric: 32.3574 - val_KL_loss_metric: 5.9812
# Epoch 17/100
# 800000/800000 [==============================] - 45s 56us/step - loss: 38.6088 - RecoProb_metric: 32.6664 - KL_loss_metric: 5.9423 - val_loss: 37.9955 - val_RecoProb_metric: 32.0649 - val_KL_loss_metric: 5.9306
# Epoch 18/100
# 800000/800000 [==============================] - 43s 54us/step - loss: 38.8272 - RecoProb_metric: 32.9179 - KL_loss_metric: 5.9092 - val_loss: 39.0939 - val_RecoProb_metric: 33.2296 - val_KL_loss_metric: 5.8643
# Epoch 19/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 40.5739 - RecoProb_metric: 34.8024 - KL_loss_metric: 5.7715 - val_loss: 39.3813 - val_RecoProb_metric: 33.6064 - val_KL_loss_metric: 5.7749
# Epoch 20/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 38.8836 - RecoProb_metric: 33.0118 - KL_loss_metric: 5.8718 - val_loss: 38.9098 - val_RecoProb_metric: 32.9595 - val_KL_loss_metric: 5.9503
# Epoch 21/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 38.4998 - RecoProb_metric: 32.4574 - KL_loss_metric: 6.0424 - val_loss: 38.1820 - val_RecoProb_metric: 32.0963 - val_KL_loss_metric: 6.0858
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000475.
# Epoch 22/100
# 800000/800000 [==============================] - 37s 46us/step - loss: 37.5053 - RecoProb_metric: 31.0640 - KL_loss_metric: 6.4413 - val_loss: 37.4575 - val_RecoProb_metric: 30.8364 - val_KL_loss_metric: 6.6211
# Epoch 23/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 37.3459 - RecoProb_metric: 30.6723 - KL_loss_metric: 6.6737 - val_loss: 37.4475 - val_RecoProb_metric: 30.7218 - val_KL_loss_metric: 6.7257
# Epoch 24/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 37.2257 - RecoProb_metric: 30.4463 - KL_loss_metric: 6.7793 - val_loss: 37.1314 - val_RecoProb_metric: 30.2839 - val_KL_loss_metric: 6.8475
# Epoch 25/100
# 800000/800000 [==============================] - 43s 53us/step - loss: 37.1267 - RecoProb_metric: 30.2773 - KL_loss_metric: 6.8494 - val_loss: 37.0593 - val_RecoProb_metric: 30.1843 - val_KL_loss_metric: 6.8750
# Epoch 26/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 37.0512 - RecoProb_metric: 30.1426 - KL_loss_metric: 6.9086 - val_loss: 37.0140 - val_RecoProb_metric: 30.0806 - val_KL_loss_metric: 6.9334
# Epoch 27/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 36.9828 - RecoProb_metric: 30.0275 - KL_loss_metric: 6.9553 - val_loss: 36.9204 - val_RecoProb_metric: 29.9485 - val_KL_loss_metric: 6.9719
# Epoch 28/100
# 800000/800000 [==============================] - 38s 48us/step - loss: 36.9260 - RecoProb_metric: 29.9279 - KL_loss_metric: 6.9981 - val_loss: 36.8084 - val_RecoProb_metric: 29.8414 - val_KL_loss_metric: 6.9670
# Epoch 29/100
# 800000/800000 [==============================] - 42s 53us/step - loss: 36.8724 - RecoProb_metric: 29.8436 - KL_loss_metric: 7.0288 - val_loss: 36.7839 - val_RecoProb_metric: 29.7670 - val_KL_loss_metric: 7.0168
# Epoch 30/100
# 800000/800000 [==============================] - 41s 52us/step - loss: 36.8140 - RecoProb_metric: 29.7549 - KL_loss_metric: 7.0591 - val_loss: 36.7588 - val_RecoProb_metric: 29.6945 - val_KL_loss_metric: 7.0644
# Epoch 31/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 36.7698 - RecoProb_metric: 29.6792 - KL_loss_metric: 7.0906 - val_loss: 36.7464 - val_RecoProb_metric: 29.6697 - val_KL_loss_metric: 7.0767
# Epoch 32/100
# 800000/800000 [==============================] - 45s 56us/step - loss: 36.7435 - RecoProb_metric: 29.6214 - KL_loss_metric: 7.1220 - val_loss: 36.6683 - val_RecoProb_metric: 29.5602 - val_KL_loss_metric: 7.1080
# Epoch 33/100
# 800000/800000 [==============================] - 42s 52us/step - loss: 36.6909 - RecoProb_metric: 29.5518 - KL_loss_metric: 7.1391 - val_loss: 36.6830 - val_RecoProb_metric: 29.5017 - val_KL_loss_metric: 7.1813
# Epoch 34/100
# 800000/800000 [==============================] - 54s 68us/step - loss: 36.6560 - RecoProb_metric: 29.4895 - KL_loss_metric: 7.1665 - val_loss: 36.5765 - val_RecoProb_metric: 29.3869 - val_KL_loss_metric: 7.1896
# Epoch 35/100
# 800000/800000 [==============================] - 44s 55us/step - loss: 36.6108 - RecoProb_metric: 29.4229 - KL_loss_metric: 7.1880 - val_loss: 36.5891 - val_RecoProb_metric: 29.4127 - val_KL_loss_metric: 7.1763
# Epoch 36/100
# 800000/800000 [==============================] - 51s 64us/step - loss: 36.5723 - RecoProb_metric: 29.3710 - KL_loss_metric: 7.2013 - val_loss: 36.5650 - val_RecoProb_metric: 29.3504 - val_KL_loss_metric: 7.2146
# Epoch 37/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 36.5401 - RecoProb_metric: 29.3206 - KL_loss_metric: 7.2194 - val_loss: 36.4727 - val_RecoProb_metric: 29.2852 - val_KL_loss_metric: 7.1875
# Epoch 38/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 36.5050 - RecoProb_metric: 29.2722 - KL_loss_metric: 7.2327 - val_loss: 36.5619 - val_RecoProb_metric: 29.3513 - val_KL_loss_metric: 7.2106
# Epoch 39/100
# 800000/800000 [==============================] - 48s 59us/step - loss: 36.4713 - RecoProb_metric: 29.2285 - KL_loss_metric: 7.2428 - val_loss: 36.4841 - val_RecoProb_metric: 29.2441 - val_KL_loss_metric: 7.2400
# Epoch 40/100
# 800000/800000 [==============================] - 48s 61us/step - loss: 36.5023 - RecoProb_metric: 29.2302 - KL_loss_metric: 7.2721 - val_loss: 36.4259 - val_RecoProb_metric: 29.1237 - val_KL_loss_metric: 7.3022
# Epoch 41/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 36.4056 - RecoProb_metric: 29.1380 - KL_loss_metric: 7.2676 - val_loss: 36.5391 - val_RecoProb_metric: 29.2699 - val_KL_loss_metric: 7.2692
# Epoch 42/100
# 800000/800000 [==============================] - 38s 47us/step - loss: 36.4033 - RecoProb_metric: 29.1202 - KL_loss_metric: 7.2831 - val_loss: 36.3424 - val_RecoProb_metric: 29.0043 - val_KL_loss_metric: 7.3381
# Epoch 43/100
# 800000/800000 [==============================] - 46s 57us/step - loss: 36.3467 - RecoProb_metric: 29.0486 - KL_loss_metric: 7.2981 - val_loss: 36.2315 - val_RecoProb_metric: 28.9460 - val_KL_loss_metric: 7.2855
# Epoch 44/100
# 800000/800000 [==============================] - 38s 47us/step - loss: 36.3439 - RecoProb_metric: 29.0303 - KL_loss_metric: 7.3136 - val_loss: 36.3249 - val_RecoProb_metric: 29.0015 - val_KL_loss_metric: 7.3234
# Epoch 45/100
# 800000/800000 [==============================] - 37s 47us/step - loss: 36.3294 - RecoProb_metric: 29.0071 - KL_loss_metric: 7.3223 - val_loss: 36.3172 - val_RecoProb_metric: 29.0321 - val_KL_loss_metric: 7.2851
# Epoch 46/100
# 800000/800000 [==============================] - 41s 51us/step - loss: 36.2815 - RecoProb_metric: 28.9604 - KL_loss_metric: 7.3211 - val_loss: 36.3776 - val_RecoProb_metric: 29.0583 - val_KL_loss_metric: 7.3193
# Epoch 47/100
# 800000/800000 [==============================] - 39s 48us/step - loss: 36.2679 - RecoProb_metric: 28.9310 - KL_loss_metric: 7.3368 - val_loss: 36.2485 - val_RecoProb_metric: 28.8829 - val_KL_loss_metric: 7.3656
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.0000000475e-05.
# Epoch 48/100
# 800000/800000 [==============================] - 38s 47us/step - loss: 36.0840 - RecoProb_metric: 28.7535 - KL_loss_metric: 7.3305 - val_loss: 36.0866 - val_RecoProb_metric: 28.7700 - val_KL_loss_metric: 7.3166
# Epoch 49/100
# 800000/800000 [==============================] - 37s 47us/step - loss: 36.0805 - RecoProb_metric: 28.7453 - KL_loss_metric: 7.3352 - val_loss: 36.0860 - val_RecoProb_metric: 28.7526 - val_KL_loss_metric: 7.3334
# Epoch 50/100
# 800000/800000 [==============================] - 40s 50us/step - loss: 36.0746 - RecoProb_metric: 28.7337 - KL_loss_metric: 7.3409 - val_loss: 36.0788 - val_RecoProb_metric: 28.7291 - val_KL_loss_metric: 7.3497
# Epoch 51/100
# 800000/800000 [==============================] - 39s 48us/step - loss: 36.0696 - RecoProb_metric: 28.7266 - KL_loss_metric: 7.3430 - val_loss: 36.0728 - val_RecoProb_metric: 28.7357 - val_KL_loss_metric: 7.3371
# Epoch 52/100
# 800000/800000 [==============================] - 42s 52us/step - loss: 36.0665 - RecoProb_metric: 28.7209 - KL_loss_metric: 7.3456 - val_loss: 36.0836 - val_RecoProb_metric: 28.7299 - val_KL_loss_metric: 7.3537
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1.00000006569e-06.
# Epoch 53/100
# 800000/800000 [==============================] - 47s 58us/step - loss: 36.0472 - RecoProb_metric: 28.6975 - KL_loss_metric: 7.3496 - val_loss: 36.0629 - val_RecoProb_metric: 28.7188 - val_KL_loss_metric: 7.3441
# Epoch 54/100
# 800000/800000 [==============================] - 54s 67us/step - loss: 36.0445 - RecoProb_metric: 28.6956 - KL_loss_metric: 7.3489 - val_loss: 36.0666 - val_RecoProb_metric: 28.7207 - val_KL_loss_metric: 7.3459
# Epoch 55/100
# 800000/800000 [==============================] - 48s 59us/step - loss: 36.0442 - RecoProb_metric: 28.6961 - KL_loss_metric: 7.3481 - val_loss: 36.0606 - val_RecoProb_metric: 28.7098 - val_KL_loss_metric: 7.3508
# Epoch 56/100
# 800000/800000 [==============================] - 40s 50us/step - loss: 36.0432 - RecoProb_metric: 28.6926 - KL_loss_metric: 7.3507 - val_loss: 36.0723 - val_RecoProb_metric: 28.7232 - val_KL_loss_metric: 7.3491
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1.00000011116e-07.
# Epoch 00056: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.semilogy(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.semilogy(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
vae.save('last_saved_VAE.h5')

# %%
if 0:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model('last_saved_VAE.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if 1:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save('last_saved_prior.h5')
else:
    Prior_Dumper = load_model('last_saved_prior.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [-0.3302398   4.5273376  -0.59251577  3.0900059 ]
# [1.6331812 4.092133  3.8294544 1.231809 ]

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save('last_saved_encoder.h5')
else:
    encoder = load_model('last_saved_encoder.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
data_folder = '../../data/'

BSM_samples = ['AtoChHW', 'AtoChHW_HIGHMASS', 'Ato4l', 'Zprime', 'Wprime', 'qcd', 'Wlnu']

x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    lower_bound = mu_prior[kk] - 6*sigma_prior[kk]
    upper_bound = mu_prior[kk] + 6*sigma_prior[kk]
    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], lower_bound, upper_bound)
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], lower_bound, upper_bound)
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('last_saved_autoencoder.h5')
else:
    autoencoder = load_model('last_saved_autoencoder.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 95.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[1:]))
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = (bincenters[10]-bincenters[9])*np.ones_like(bincenters)
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# MET
# allJetMass
# allMuPt
# allElePt
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# LepEta
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
sigma_prior
# Out:
# array([1.6331812, 4.092133 , 3.8294544, 1.231809 ], dtype=float32)

# %%
def numpy_KL_loss(mu, sigma):
    sp = np.atleast_2d(sigma_prior)
    mp = np.atleast_2d(mu_prior)
    kl_loss = np.square(sigma)*np.square(sp)
    kl_loss += np.square((mp - mu)/sp)
    kl_loss += np.log(sp/sigma) -1

    return 0.5 * np.sum(kl_loss, axis=-1)

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1) - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(single_NLL, axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]
    print binning
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-3))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    
    canvases.append(c)
# Out:
# [100, 15.915744915862124, 301.6836617749661]
# [100, 8.76333059396271, 283.75685712115245]
# [100, 6.107852, 67.43600805284248]
