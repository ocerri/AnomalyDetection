# %% [markdown]
# VampPrior
#
# - Tried with 10 hidden dim -> not converged
# - Tried to add allLepMass and hidden from 4 to 5 -> Eff improve but reco is a shit
# - If remove VampEff decrease

# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.12/06

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# Using TensorFlow backend.
# 2.1.1

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'PhiMET', 'MT', 'nJets', 'bJets',
                'allJetMass', 'LepPt', 'LepEta', 'LepPhi', 'LepIsoCh',
                'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 'LepIsEle', 'nMu',
                'allMuMass', 'allMuPt', 'nEle', 'allEleMass', 'allElePt', 'nChHad',
                'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'MET', 'allJetMass',
                       'allMuPt','allElePt','allEleMass', 'allMuMass',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 11
Nf_gauss = 1
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	allEleMass
# 	allMuMass
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/'
SampleName = 'qcd'
BSM_samples = ['AtoChHW', 'AtoChHW_HIGHMASS', 'Ato4l', 'Zprime', 'Wprime', 'Wlnu', 'ttbar']

N_train = int(2e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (1166195, 24) (1166195, 22)

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim = 50
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

def SmashTo0(x):
    return 0*x

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(20, kernel_initializer='zeros', bias_initializer='ones', trainable=False)(fixed_input)
# h2_prior = Dense(100, activation=act_fun)(h1_prior)

L_prior_mean = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='zeros', trainable=True)(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='ones', trainable=True)(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit)(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return K.mean(0.5 * K.sum(kl_loss, axis=-1))

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    mu_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    sigma_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior) + RecoProb_forVAE(y_train[:, :original_dim], par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = 4*latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train[:, :original_dim], par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim: 2*latent_dim]
    mu_prior = NETout[:, 2*latent_dim: 3*latent_dim]
    sigma_prior = NETout[:, 3*latent_dim: 4*latent_dim]
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_prior_mean, L_prior_sigma, L_par1, L_par2, L_par3], axis=1)

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
print vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 22)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           1150        input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           2550        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4)            0           dense_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 22)           0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           250         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 20)           460         lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           2550        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 17)           867         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 11)           561         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 4)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 22)           1122        dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 17)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 11)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 66)           0           dense_3[0][0]
#                                                                  lambda_1[0][0]
#                                                                  dense_11[0][0]
#                                                                  lambda_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# ==================================================================================================
# Total params: 10,086
# Trainable params: 9,626
# Non-trainable params: 460
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
y_train = np.concatenate((x_train, np.zeros((x_train.shape[0], 66 - x_train.shape[1]))), axis=1)

# %%
fit_report = vae.fit(x=x_train, y=y_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=400,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, epsilon=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# Train on 932956 samples, validate on 233239 samples
# Epoch 1/100
# 932956/932956 [==============================] - 71s 76us/step - loss: 9524.3073 - RecoProb_metric: 9298.5067 - KL_loss_metric: 225.8004 - val_loss: 75.3548 - val_RecoProb_metric: 53.8599 - val_KL_loss_metric: 21.4949 RecoProb_metric: 67275.1207 - K - ETA: 1:04 - loss: 55046.8019 - RecoProb_metr - ETA: 1:00 - loss: 46401.1268 - RecoProb_metric: 45504.0569 - - ETA: 46s - loss: 26957.6031 - RecoProb_metric: 26388.7087 - KL_loss_metric: 568.89 - ETA:  - ETA: 37s - loss: 20233.5382 - RecoProb_metric: - ETA: 33s - loss: 18021.381 - ETA: 16s - loss: 12666.4654 - RecoProb_metric - ETA: 13s - loss: 11809.2866 - RecoProb_metric: 11534.8552 - KL_loss_ - ETA: 11s - loss: 11458.0706 - RecoProb_metric: 11191.0272 - KL_loss_metri - ETA: 10s - loss: 11267.4419 - RecoProb_metric: 11004.4254 - KL_loss_me - ETA: 9s - loss: 11077.5984 -  - ETA: 6s - loss: 10589.6541 - RecoProb_metric:
# Epoch 2/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 68.3282 - RecoProb_metric: 49.5787 - KL_loss_metric: 18.7495 - val_loss: 57.0565 - val_RecoProb_metric: 42.9547 - val_KL_loss_metric: 14.1018
# Epoch 3/100
# 932956/932956 [==============================] - 68s 73us/step - loss: 52.1172 - RecoProb_metric: 39.8442 - KL_loss_metric: 12.2730 - val_loss: 49.5744 - val_RecoProb_metric: 38.5082 - val_KL_loss_metric: 11.0662.3510 - RecoProb_metric: 40.5311 - KL_loss_metric: - ETA: 26s - loss: 53.3283 - RecoProb_metric: 4 - ETA: 25s - loss: 53.2461 - RecoProb_metric: 40.4736 - ETA: 23s - loss: 53.1701 - RecoProb_metric: 40.43 - ETA: 22s - loss: 53.1026 - RecoPr - - ETA: 9s - loss: 52.5111 - RecoProb_metric: 40.0577 -
# Epoch 4/100
# 932956/932956 [==============================] - 68s 73us/step - loss: 47.2860 - RecoProb_metric: 37.5597 - KL_loss_metric: 9.7264 - val_loss: 45.0978 - val_RecoProb_metric: 36.1610 - val_KL_loss_metric: 8.9368ss: 47.4005 - RecoProb_metric: 37.6186 - KL_los - ETA: 2s - loss: 4
# Epoch 5/100
# 932956/932956 [==============================] - 62s 66us/step - loss: 42.8101 - RecoProb_metric: 34.4533 - KL_loss_metric: 8.3568 - val_loss: 40.0383 - val_RecoProb_metric: 32.0691 - val_KL_loss_metric: 7.9692
# Epoch 6/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 39.9898 - RecoProb_metric: 31.6453 - KL_loss_metric: 8.3445 - val_loss: 38.5830 - val_RecoProb_metric: 31.0732 - val_KL_loss_metric: 7.5099ob_metric: 32.4899 - KL_lo - ETA: 36s - loss: 41. - ETA: 32s - loss: 41.0249 - RecoProb_metric: 32.2103 - KL_loss_metric: 8.8 - ETA: 31s - loss: 41.0030 - Reco - ETA: 27s - loss: 40.8446 - RecoProb_metric: 32.0835 - KL_loss_metric: 8 - ETA: 27s - loss: 40.8320 - RecoProb_metric: 32.0683 - KL_loss_met - ETA: 26s - loss: - ETA: 21s - loss: 40.8485 - RecoProb_metri - ETA: 17s - loss: 40.6863 - RecoProb_metric: 32.0320 - KL_loss_ - E - ETA: 2s - loss:
# Epoch 7/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 37.8487 - RecoProb_metric: 30.4016 - KL_loss_metric: 7.4471 - val_loss: 36.1895 - val_RecoProb_metric: 28.5394 - val_KL_loss_metric: 7.6501 - ETA: 43s - loss: 38.5694 - RecoProb_metric: 30.9243 - KL_loss_metric: 7.64 - ETA: 42s - loss: 38.5713 - RecoProb_metric: 30.915 - ETA: 41s - loss: 38.5366 - RecoProb_m - ETA: 38s - loss: 38.6863 - RecoProb_metric: 30.8927 - KL_loss_ - ETA: 37s - loss: 38.5794 - RecoProb_metric: 30.8108  - ETA: 35s - loss: 38.5961 - RecoProb_metric: 30.8658 - KL_loss_metri - ETA: 34s - loss: 38.5695 - RecoProb_metric: 30.8513 - KL_loss_m - ETA: 33s - loss: 38.4749 - Rec - ETA: 29s - loss: 38.3756 - RecoProb_metric: 30.720 - ETA: 26s - loss: 38.2883 - RecoProb_met - ETA: 1s - loss: 37.8756 - RecoProb_metric: 30
# Epoch 8/100
# 932956/932956 [==============================] - 67s 71us/step - loss: 38.3121 - RecoProb_metric: 31.1048 - KL_loss_metric: 7.2073 - val_loss: 42.0661 - val_RecoProb_metric: 33.1712 - val_KL_loss_metric: 8.8949- RecoProb_metric: 30.1894 - KL - ETA: 40s - loss: 37.3255 - RecoP - ETA: 35s - loss: 37.1299 - RecoPr
# Epoch 9/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 37.5460 - RecoProb_metric: 30.6521 - KL_loss_metric: 6.8938 - val_loss: 35.2245 - val_RecoProb_metric: 28.5177 - val_KL_loss_metric: 6.7069s - loss: 36.0666 - RecoProb_metric: 29.5454 - KL_loss_metric:  - ETA: 35s - loss: 36.0195 - RecoProb_metric: 29.5200 - KL_loss_m - ETA: 34s - loss: 35.9171 - RecoProb_metric: 29.4605  - ETA: 32s - loss: 35.7814 - Rec - ETA: 28s - loss: 36.6518 - RecoProb_metric: 30.1252 -  - ETA: 25s
# Epoch 10/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 35.3917 - RecoProb_metric: 29.4868 - KL_loss_metric: 5.9050 - val_loss: 33.7731 - val_RecoProb_metric: 27.1350 - val_KL_loss_metric: 6.6381
# Epoch 11/100
# 932956/932956 [==============================] - 65s 69us/step - loss: 32.9010 - RecoProb_metric: 27.5430 - KL_loss_metric: 5.3579 - val_loss: 35.4219 - val_RecoProb_metric: 30.3980 - val_KL_loss_metric: 5.0239
# Epoch 12/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 32.7211 - RecoProb_metric: 27.5408 - KL_loss_metric: 5.1803 - val_loss: 32.3430 - val_RecoProb_metric: 25.8278 - val_KL_loss_metric: 6.5151: 32.5372 - RecoProb_metric: 27.4268 - KL_loss_metric: 5. - ETA: 46s - loss: 32.5103 - RecoProb_metric: 27.4007 - KL - ETA: 44s - loss: 32.4073 - RecoProb_metric: 27 - ETA: 41s - loss: 32.7111 - RecoProb_metric: 27.6061 - KL_l - ETA: 40s - loss: 32.6170 - ETA: 12s - loss: 32.2194 - RecoProb_metric: 27.1583 - KL_loss_metric -  - ETA: 2s - loss: 32.6222
# Epoch 13/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 31.3696 - RecoProb_metric: 26.2911 - KL_loss_metric: 5.0785 - val_loss: 30.7773 - val_RecoProb_metric: 25.9032 - val_KL_loss_metric: 4.8740
# Epoch 14/100
# 932956/932956 [==============================] - 68s 73us/step - loss: 31.0779 - RecoProb_metric: 26.0453 - KL_loss_metric: 5.0327 - val_loss: 30.1786 - val_RecoProb_metric: 25.2166 - val_KL_loss_metric: 4.9619s - ETA: 37s - loss: 31.4221 - RecoProb_metric: 26.3216 - KL_loss_metr - ETA: 36s - loss: 31.3816 - RecoProb_metric: 26.2858 - KL - ETA: 34s - loss: 31.30 - ETA: 28s - loss: 31.3655 - RecoProb_ - ETA: 24s - loss: 31.3101 - RecoProb_metric: 26.2255 - KL_l - ETA: 23s - loss: 31.2862 - RecoProb_metric: 26.2077 - KL - ETA: 20s - loss: 31.2281 - RecoProb_metric: 26.1553 - KL_loss_metric: 5.072 - ETA: 20s - loss: 31.2245 - RecoProb_metric: 26.1521 - KL_loss_metric: 5
# Epoch 15/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 31.0081 - RecoProb_metric: 25.6572 - KL_loss_metric: 5.3509 - val_loss: 29.6121 - val_RecoProb_metric: 24.5539 - val_KL_loss_metric: 5.0582
# Epoch 16/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 30.0966 - RecoProb_metric: 25.0620 - KL_loss_metric: 5.0347 - val_loss: 30.2620 - val_RecoProb_metric: 25.0991 - val_KL_loss_metric: 5.1629oss: 31.077 - ETA: 58s - loss: 30.3958 - RecoProb_metric: 25.3283 - KL_loss_metric: 5 - ETA: 57s - loss: 30.3417 - RecoProb_metric: 25.2723 - KL_loss - ETA: 55s - loss: 30.2529 - RecoProb_ - ET - ETA: 40s - loss: 30.0108 - RecoProb_metric: 24.9851 - KL_loss_metric: 5 - ETA: 40s - loss: 30.0249 - Re - ETA: 36s - loss: 30.0365 - RecoProb_metric: 25.0263 - KL_loss_metri - ETA: 35s - loss: 30.0195 - RecoProb_metric: 25.0109 - KL_loss_metric: 5.00 - ETA: 35s - loss: 30.0178 - RecoProb_metric: 25.0089 - K - ETA: 33s - loss: 29.9927 - RecoProb_metric: 24.9857 - KL_loss_metric - ETA: 32s - loss: 29.9861 - RecoProb_ - ETA: 29s - loss: 29.9454 - RecoProb_metric: 24.9387 - KL_loss_metri - ETA: 28s - loss: 29.9392 - RecoProb_metric: 24.9323 -
# Epoch 17/100
# 932956/932956 [==============================] - 64s 69us/step - loss: 30.0210 - RecoProb_metric: 24.9512 - KL_loss_metric: 5.0697 - val_loss: 29.0648 - val_RecoProb_metric: 24.0041 - val_KL_loss_metric: 5.0606s: 2
# Epoch 18/100
# 932956/932956 [==============================] - 62s 66us/step - loss: 29.6747 - RecoProb_metric: 24.5937 - KL_loss_metric: 5.0810 - val_loss: 32.5781 - val_RecoProb_metric: 27.1771 - val_KL_loss_metric: 5.4010- RecoProb_me - ETA: 47s - loss: 29.1712 - ETA: 38s - ETA: 32s - loss: 30.1237 -
# Epoch 19/100
# 932956/932956 [==============================] - 63s 68us/step - loss: 29.3116 - RecoProb_metric: 24.1652 - KL_loss_metric: 5.1464 - val_loss: 29.6539 - val_RecoProb_metric: 24.4946 - val_KL_loss_metric: 5.15936 - Re - ETA: 32s - loss: 29.2998 - RecoProb_metric: 24.1663 - KL_loss_metric: 5.133 - ETA: 31s -  - ETA: 26s - los - ETA: 5s - loss: 29.1854 - RecoProb_metr - ETA: 3s - loss: 29.1739 - RecoProb_metric: 24.0442 - KL_loss_metric - ETA: 3s - loss: 29.1694 - RecoProb_metric: 24.0402 - KL - ETA: 2s - loss: 29.2804 - RecoProb_
# Epoch 20/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 29.8430 - RecoProb_metric: 24.6212 - KL_loss_metric: 5.2217 - val_loss: 28.3154 - val_RecoProb_metric: 23.0330 - val_KL_loss_metric: 5.2824
# Epoch 21/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 29.4100 - RecoProb_metric: 24.1439 - KL_loss_metric: 5.2661 - val_loss: 28.4847 - val_RecoProb_metric: 23.2157 - val_KL_loss_metric: 5.26911:00 - loss: 28.7152  - ETA: 41s - loss: 29.1850 - RecoProb_metric: 23.9231 - KL_loss - ETA: 14s - loss: 28.9164 - RecoProb_met
# Epoch 22/100
# 932956/932956 [==============================] - 66s 70us/step - loss: 28.5338 - RecoProb_metric: 23.3118 - KL_loss_metric: 5.2220 - val_loss: 28.0191 - val_RecoProb_metric: 22.8125 - val_KL_loss_metric: 5.2066 loss: 28.6142 - RecoProb_metric: 23.4058 - KL_loss_metric:  - ETA: 53s - loss: 28.6016 - RecoProb_metric: 23.3921  - ETA: 50s - loss: 28.5717 - RecoProb_metric: 23.3643 - KL_loss_m - ETA: 49s - loss: 28.6393 - RecoProb_metric: 23.4428 - KL_loss_me - ETA: 48s - loss: 28.6242 - R - ETA: 43s - loss: 28.6085 - RecoProb_metric: 23.40 - ETA: 41s - loss: 28.5947 - - ETA: 35s - loss: 28.5666 - RecoProb_metric: 23.3 - ETA: 33s - loss: 28.573
# Epoch 23/100
# 932956/932956 [==============================] - 59s 63us/step - loss: 29.0413 - RecoProb_metric: 23.7241 - KL_loss_metric: 5.3172 - val_loss: 27.9849 - val_RecoProb_metric: 22.6854 - val_KL_loss_metric: 5.299623.6827 - KL_loss_m - ETA: 35s - loss: 29.2753 - RecoProb_metric - ETA: 32s - loss: 29.3383 - RecoProb_metric: 23.9662 - KL_loss_met - ETA: 30s - loss: 29. - ETA: 25s - loss: 29.2704 - RecoProb_metric: 23.916 - ETA: 14s - loss:
# Epoch 24/100
# 932956/932956 [==============================] - 61s 65us/step - loss: 29.0609 - RecoProb_metric: 23.6899 - KL_loss_metric: 5.3710 - val_loss: 28.4159 - val_RecoProb_metric: 23.1120 - val_KL_loss_metric: 5.3039- KL_loss_metri - ETA: 15s - los - ETA: 5s - loss: 29.1004 - RecoPro - ETA: 3s - loss: 29.0910 - RecoProb_metric: 23.7111 - KL_los - ETA: 2s - loss: 29.0856 - RecoProb_metric: 23.7069 - KL_loss_metric:  - ETA: 2s - loss: 29.0838
# Epoch 25/100
# 932956/932956 [==============================] - 62s 66us/step - loss: 28.5282 - RecoProb_metric: 23.2801 - KL_loss_metric: 5.2481 - val_loss: 29.8115 - val_RecoProb_metric: 24.4157 - val_KL_loss_metric: 5.3958: 20s - l
# Epoch 26/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 28.4994 - RecoProb_metric: 23.1132 - KL_loss_metric: 5.3862 - val_loss: 28.3651 - val_RecoProb_metric: 22.9423 - val_KL_loss_metric: 5.4228ETA: 32s - loss: 28.5340 - RecoProb_metric: 23.1500 - KL - ETA: 24s - los - ETA: 19s - loss: 28.5909 - Rec - ETA: 15s - loss: 28.5594 - RecoProb_metric: 23.1663 - KL_loss_metric: 5.393 - ETA: 15s - loss: 28.5598 - RecoProb_metric: 23.1663 - - ETA: 13s - loss: 28.5350 - RecoProb_metric: 23.1428 - KL_los - ETA: 11s - loss: 28.5239 - RecoProb_metric: 23.1330 -  - ETA: 9s - loss: 28.5499 - RecoProb_metric: 23.160 - ETA: 8s - loss: 28.5400 - RecoPro - ETA: 6s - loss: 28.5382 - R
# Epoch 27/100
# 931600/932956 [============================>.] - ETA: 0s - loss: 28.6065 - RecoProb_metric: 23.1661 - KL_loss_metric: 5.4404 - ETA: 42s - loss: 29.7056 - Reco - ETA: 38s - loss: 29.4095 - R - ETA: - ETA: 27s -  - ETA: 14s - loss: 28.7685 - RecoProb_metric: 23.33 - ETA: 12s - lo - ETA: 7s - loss: 28.6901 - RecoProb_metric: 23.2463 - KL_loss_me - ETA: 7s - loss: 28.6809 - RecoProb_metric: 23.2379 - KL_l - ETA: 6s - loss: 28.6813 - RecoProb_metric: 23.236 - ETA: 5s - l - ETA: 1s - loss: 28.6335 - RecoP
# Epoch 00027: reducing learning rate to 0.00010000000475.
# 932956/932956 [==============================] - 67s 72us/step - loss: 28.6086 - RecoProb_metric: 23.1683 - KL_loss_metric: 5.4403 - val_loss: 28.1990 - val_RecoProb_metric: 22.8630 - val_KL_loss_metric: 5.3360
# Epoch 28/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 27.1419 - RecoProb_metric: 21.4928 - KL_loss_metric: 5.6492 - val_loss: 27.0419 - val_RecoProb_metric: 21.3027 - val_KL_loss_metric: 5.739221.7872 - KL_l - ETA: 53s - loss: 27.2601 - RecoProb_metric: 21.7661 - KL_loss_metric -  - ETA: 42s - loss: 27.2323 - RecoProb_metric: 21.6995 - KL_loss_metric - ETA: 41s - loss: 27.2280 - RecoProb_metric: 21.6928 - KL_loss_metr - ETA: 40s - loss: 27.2257 - RecoProb_metric: 21.6860 - KL_loss_metric: 5.5 - ETA: 40s - loss: 27.2251 - RecoProb_metric: 21.6846 - KL_loss_ - ETA: 39s - loss: 27.2170 - RecoProb_metric: 21.6720 - KL_lo - ETA: 38s -  - ETA: 33s
# Epoch 29/100
# 932956/932956 [==============================] - 62s 67us/step - loss: 26.9950 - RecoProb_metric: 21.1719 - KL_loss_metric: 5.8231 - val_loss: 26.9770 - val_RecoProb_metric: 21.1328 - val_KL_loss_metric: 5.8442- loss: 27.0546 - RecoProb_metric: 21.2798 - KL_loss_metric: 5. - ETA: 43s - loss: 27.0559 - RecoProb_met - ETA: 39s - loss: 27.0426 - RecoProb_metric: 21.2590 - KL_loss_metric: - ETA: 38s - loss: 27.0404 - RecoProb_metric: 21.2559 - KL_loss_metric: 5 - ETA: 37s - loss: 27.0423 - RecoProb_ - ETA: 33s - lo - ETA: 27s - loss: 27.0351 - RecoProb_metric: 21.2345 - KL_loss_
# Epoch 30/100
# 932956/932956 [==============================] - 58s 63us/step - loss: 26.8613 - RecoProb_metric: 20.9526 - KL_loss_metric: 5.9088 - val_loss: 26.8467 - val_RecoProb_metric: 20.9117 - val_KL_loss_metric: 5.9350
# Epoch 31/100
# 932956/932956 [==============================] - 62s 66us/step - loss: 26.7537 - RecoProb_metric: 20.7803 - KL_loss_metric: 5.9734 - val_loss: 26.8137 - val_RecoProb_metric: 20.8087 - val_KL_loss_metric: 6.0049RecoProb_metric: 20.8006 - KL_loss_ - ETA: 46s - loss: 26.7502 - RecoProb_metric: 20.8 - ETA: 44s - loss: 26.7518 - RecoProb_metric - ETA: 41s - loss: 26.7606 - - ETA: 37s - loss: 26.7570 - RecoProb_metric: 20.8016 - KL_l - ETA: 35s - loss: 26.7663 - RecoProb_metric: 20.8103 - KL_loss - ETA: 34s - loss:  -
# Epoch 32/100
# 932956/932956 [==============================] - 65s 69us/step - loss: 26.6717 - RecoProb_metric: 20.6553 - KL_loss_metric: 6.0164 - val_loss: 26.6778 - val_RecoProb_metric: 20.6594 - val_KL_loss_metric: 6.0184lo - ETA: 28s - loss: 26.6778 - RecoProb_metric: 20.67 - ETA: 25s - loss: 26.6738 - RecoProb_metric: 20.6695 - KL_loss_metric: 6.0 - ETA: 25s - loss: 26.6727 - RecoProb_metr - ETA: 15s - loss: 26.6737 - RecoProb - ETA: 11s - loss: 26.6743 - RecoProb_metric: 20.6620 - KL_loss_metric - ETA: 1
# Epoch 33/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 26.5885 - RecoProb_metric: 20.5317 - KL_loss_metric: 6.0568 - val_loss: 26.6007 - val_RecoProb_metric: 20.5232 - val_KL_loss_metric: 6.077423 - ETA: 47s - loss: 26.6174 - RecoPr - ETA: 42s - loss: 26.6025 - RecoProb_metric: 20.5582 - KL_loss_metric: 6.04 - ETA: 42s - l
# Epoch 34/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 26.5388 - RecoProb_metric: 20.4471 - KL_loss_metric: 6.0917 - val_loss: 26.7225 - val_RecoProb_metric: 20.5892 - val_KL_loss_metric: 6.1333.5877 - RecoProb_m - ETA: 45s - loss: 26.5927 - RecoProb_metric: 20.5050 - KL_l - ETA: 44s - loss: 26.5902 - RecoProb_metric: 20.5034 - KL_ - ETA: 42s - loss: 2 - ETA: 36s - loss: 26.5700 - RecoProb_metric: 20 - ETA: 34s - loss: 26.5620 - RecoProb_met - ET - ETA: 24s - loss: 26.5405 - RecoProb_metri - ETA: 20s - loss: 26.5457 - RecoProb_metric: 20.4599 - KL_loss_ - ETA: 19s - loss: 26.5450 - RecoProb_metric: 20.4587 - KL_loss_me - ETA: 18s - loss: 26.5485 - RecoProb_metric: 20.4585 - KL_loss_metric: - ETA: 17s - loss: 26.5505 - RecoProb_metric: 20.4590 - KL_loss_metric: - ETA: 17s - loss: 26.5500 - RecoProb_metric:  - ETA: 14s - loss: 26.5441 - RecoProb_metric: 20.4527 - KL_loss_m - ETA: 13s - loss: 26.5399 - Re - ETA: 9s - loss: 26.5389 - RecoPro - ETA: 7s - loss: 26. - ETA: 5s - l - ETA: 2s - loss: 26.5420 - RecoProb_metric: 20.4502 -  - ETA: 1s - loss: 26.5403 - RecoProb_metric: 20.4485 - KL
# Epoch 35/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 26.4729 - RecoProb_metric: 20.3536 - KL_loss_metric: 6.1193 - val_loss: 26.5890 - val_RecoProb_metric: 20.3583 - val_KL_loss_metric: 6.2307715 - RecoProb_metric: 20.3523 - KL_loss_metric:  - ETA: 0s - loss: 26.4714 - RecoProb_metric: 20.3523 - KL
# Epoch 36/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 26.4120 - RecoProb_metric: 20.2709 - KL_loss_metric: 6.1411 - val_loss: 26.5345 - val_RecoProb_metric: 20.3700 - val_KL_loss_metric: 6.1645coProb_metric: 20.2711 - KL_loss_metric:
# Epoch 37/100
# 932956/932956 [==============================] - 67s 71us/step - loss: 26.3961 - RecoProb_metric: 20.2187 - KL_loss_metric: 6.1773 - val_loss: 26.4063 - val_RecoProb_metric: 20.1966 - val_KL_loss_metric: 6.2098 ETA: 12s - loss: 26.4051 - RecoProb_metric: 20.2301 - KL_loss_metric: 6. - ETA: 12s - loss: 26.4068 - RecoProb_metric: 20. - ETA: 3s - loss: 26.39 - ETA: 0s - loss: 26.3955 - RecoProb_metric: 20.2185 - KL_loss_
# Epoch 38/100
# 932956/932956 [==============================] - 63s 68us/step - loss: 26.3531 - RecoProb_metric: 20.1638 - KL_loss_metric: 6.1892 - val_loss: 26.3412 - val_RecoProb_metric: 20.1218 - val_KL_loss_metric: 6.2194
# Epoch 39/100
# 932956/932956 [==============================] - 58s 63us/step - loss: 26.2753 - RecoProb_metric: 20.0726 - KL_loss_metric: 6.2027 - val_loss: 26.4185 - val_RecoProb_metric: 20.2006 - val_KL_loss_metric: 6.2179s: 26.2566 - RecoProb_metric: 20.0710  - ETA: 48s - loss: 26.2565 - RecoProb_metric: 20.0692 - KL_loss_metric: 6 - ETA: 48s - loss: 26.2640 - RecoProb_metric: 20.0756 - - ETA: 47s - loss: 26.2532 - RecoProb_metric: 20.0608 - KL_l - ETA: 46s - loss: 26.2492 - RecoProb_m - ETA: 42s - loss: 26.2648 - RecoProb_metric: 20.0707 - KL_loss_metric: 6 - ETA: 42s - loss: 26.2665 - RecoProb_metric: 20.0718 - KL_los - ETA: 40s - loss: 26.2621 - RecoProb_metric: - - ETA: 2s - loss: 26.2766 - RecoProb_metric: 20.0743 - KL_loss_metric: 6.20 - ETA: 2s - loss: 26.2768 - RecoProb_metric:  - ETA: 0s - loss: 26.2756 - RecoProb_metric: 20.0728 -
# Epoch 40/100
# 932956/932956 [==============================] - 63s 67us/step - loss: 26.2970 - RecoProb_metric: 20.0642 - KL_loss_metric: 6.2328 - val_loss: 26.3618 - val_RecoProb_metric: 20.1232 - val_KL_loss_metric: 6.2386oss: 26.2380 - ETA: 37s - loss: 26.2421 - Reco - ETA: 32s - loss: 26.2599 - RecoProb_metric: 20.0275 - KL_loss_metric: 6 - ETA: 32s - loss: 26.2637 - RecoProb_metric: 20.0316 - KL_loss_met - ETA: 31s - loss: 26.2651 - RecoProb_metric:  - ETA: 28s - loss: 26.2553 - RecoProb_metric: 20.0251 - KL_loss_metric: 6. - ETA: 27s - loss: 26.260 - ETA: 22s - loss: 26.2527 - RecoProb_metric: 20.0249 - KL_loss_metric: - ETA: - ETA: 4s - loss: 26.2982 - Rec - ETA: 2s - loss: 26.3008 - RecoProb_metric: 20.0667 - KL_loss_metric: 6.23 - ETA: 2s
# Epoch 41/100
# 932956/932956 [==============================] - 65s 69us/step - loss: 26.2019 - RecoProb_metric: 19.9564 - KL_loss_metric: 6.2455 - val_loss: 26.4529 - val_RecoProb_metric: 20.2102 - val_KL_loss_metric: 6.2427
# Epoch 42/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 26.1912 - RecoProb_metric: 19.9363 - KL_loss_metric: 6.2549 - val_loss: 26.2425 - val_RecoProb_metric: 20.0043 - val_KL_loss_metric: 6.2382Prob_metric: 19.9308 - KL_loss_metric: 6.247 - ETA: 57s - loss: 26.1801 - RecoProb_metric: 19.9322 - KL_loss_metric: 6. - ETA: 57s -  - ETA: 49s - loss: 26.1566
# Epoch 43/100
# 932956/932956 [==============================] - 63s 68us/step - loss: 26.1439 - RecoProb_metric: 19.8874 - KL_loss_metric: 6.2565 - val_loss: 26.2000 - val_RecoProb_metric: 19.8849 - val_KL_loss_metric: 6.3152oss: 26.1486 - RecoProb_metric:  - ETA: 13s - loss: 26.1449 - RecoProb_metric: 19.8921 - KL_loss_metric: 6.2 - ETA: 13s - loss: 26.1453  - ETA: 5s - loss: 26.1494 - RecoProb_metric: 19.8934 - KL_loss_metric: 6.25 - ETA: 5s - loss: 26.1493 - Rec
# Epoch 44/100
# 932956/932956 [==============================] - 64s 69us/step - loss: 26.1193 - RecoProb_metric: 19.8426 - KL_loss_metric: 6.2768 - val_loss: 26.1157 - val_RecoProb_metric: 19.8489 - val_KL_loss_metric: 6.2669.1181 - RecoProb_metric: 19.8410 - KL_loss_
# Epoch 45/100
# 932956/932956 [==============================] - 61s 65us/step - loss: 26.1425 - RecoProb_metric: 19.8446 - KL_loss_metric: 6.2979 - val_loss: 26.3223 - val_RecoProb_metric: 20.0584 - val_KL_loss_metric: 6.2640oss: 26.1431 - RecoProb_metric: 19.8456 - KL_l
# Epoch 46/100
# 932956/932956 [==============================] - 61s 65us/step - loss: 26.0415 - RecoProb_metric: 19.7494 - KL_loss_metric: 6.2921 - val_loss: 26.1843 - val_RecoProb_metric: 19.8903 - val_KL_loss_metric: 6.2940 RecoProb_metric: 19.8175 - KL_loss_metric: 6 - ETA: 55s - loss: 26.0936 - RecoPr - ETA: 39s - loss: 26.0682 - RecoProb_metri - ETA: 36s - loss: 26.0571 - Re - ETA: 32s - loss: 26. - ETA:
# Epoch 47/100
# 932956/932956 [==============================] - 62s 66us/step - loss: 26.0267 - RecoProb_metric: 19.7103 - KL_loss_metric: 6.3164 - val_loss: 26.1210 - val_RecoProb_metric: 19.7701 - val_KL_loss_metric: 6.3509oss: 26.0208 - RecoProb_metric: 19.7340 - ETA: 54s - loss: 26.0432 - RecoProb_metric: 19.7504 - KL_loss_metric: 6 - ETA: 52s - - ETA: 45s - loss: 26.0858 - RecoProb_metric: 19.7738 - KL_loss_metric: 6. - ETA: 44s - loss: 26.0798 - RecoProb_metric:  - ETA: 35s - loss: 26.0466 - RecoProb_metric: 19.7211 - KL_loss_metric: 6.3 - ETA: 35s - loss: 26.0470 - RecoProb_metric: 19.7217 - KL_loss - ETA: 26s - loss: 26.0383 - RecoProb_metric: 19 - ETA: 16s - loss: 26.0278 - Re - ETA: 11s - loss: 26.0234 - RecoProb_metric: 19.708
# Epoch 48/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 26.0295 - RecoProb_metric: 19.6899 - KL_loss_metric: 6.3396 - val_loss: 26.4555 - val_RecoProb_metric: 19.8887 - val_KL_loss_metric: 6.5668oss: 26.0728 - RecoProb_metr - ETA: 35s - loss: 26.0885 - RecoProb_me - ETA: 17s - loss: 26.040
# Epoch 49/100
# 932000/932956 [============================>.] - ETA: 0s - loss: 25.9747 - RecoProb_metric: 19.6467 - KL_loss_metric: 6.3279 - ETA: 40s  - ETA: 33s - loss: 26.0123 - RecoProb_metric: 19.6762  - ETA: 0s - loss: 25.9757 - RecoProb_metric: 19.6474 - KL_los
# Epoch 00049: reducing learning rate to 1.0000000475e-05.
# 932956/932956 [==============================] - 65s 69us/step - loss: 25.9745 - RecoProb_metric: 19.6465 - KL_loss_metric: 6.3279 - val_loss: 26.0318 - val_RecoProb_metric: 19.6318 - val_KL_loss_metric: 6.4000
# Epoch 50/100
# 932956/932956 [==============================] - 65s 69us/step - loss: 25.8204 - RecoProb_metric: 19.4899 - KL_loss_metric: 6.3305 - val_loss: 25.9129 - val_RecoProb_metric: 19.5753 - val_KL_loss_metric: 6.3377 25.8215 - RecoProb_metric: 19.4947 - K - ETA: 4s - loss: 25.8202 - RecoPro - ETA: 1s - loss: 25.8223 - Rec
# Epoch 51/100
# 932956/932956 [==============================] - 66s 71us/step - loss: 25.8132 - RecoProb_metric: 19.4741 - KL_loss_metric: 6.3391 - val_loss: 25.9248 - val_RecoProb_metric: 19.5720 - val_KL_loss_metric: 6.3528278 - RecoProb_me - ETA: 46s - loss: 25.8329 - - ETA: 42s - loss: 25.8194 - RecoProb_metric: 19.4844 - - ETA: 39s - loss: 25.8206 - RecoProb_metric: 19.4840 -  - ETA: 37s - loss: 25.8237 - RecoProb_metric: 19.4 - ETA: 35s - loss: 25.8247 - RecoPro - ETA: 31s - loss: 25.8245 - RecoProb_metric: 19.4868 - KL_loss - ETA: 30s - loss: 25.8237 - RecoProb_metric: 19.4 - ETA: 27s - loss: 25.8199 - RecoProb_metric: 19.4834 - KL_loss_metric: - ETA: 26s - loss: 25.8224 - RecoProb_metric: 19.4862 - KL_loss_metric: 6.3 - ETA: 26s - loss: 25.8214 - RecoProb_metric: 19.4856  - ETA: 24s - loss: 25.8193 - RecoProb_metric: 19. - ETA: 21s - loss: 25.8148 - RecoProb - ETA: 17s - loss: 25.8115 - RecoProb_metric: 1 - ETA: 14s - loss: 25.809 - ETA: 9s - loss: 25.8114 - RecoProb_metric:  - ETA: 8s - loss: 25.8118 - RecoProb_me - ETA: 6s - l
# Epoch 52/100
# 932956/932956 [==============================] - 67s 72us/step - loss: 25.8135 - RecoProb_metric: 19.4672 - KL_loss_metric: 6.3463 - val_loss: 25.9401 - val_RecoProb_metric: 19.5855 - val_KL_loss_metric: 6.3546 - loss: 25.8135 - RecoProb_metr
# Epoch 53/100
# 932956/932956 [==============================] - 65s 70us/step - loss: 25.8068 - RecoProb_metric: 19.4539 - KL_loss_metric: 6.3528 - val_loss: 25.9285 - val_RecoProb_metric: 19.5817 - val_KL_loss_metric: 6.3468 - RecoProb_ - ETA: 58s - loss: 25.7966 - RecoProb_metric: 19.4504 - KL_loss_metric: 6.34 - ETA: 58s - loss: 25.7975 - RecoProb_metric: 19.4513 - KL_l - ETA: 56s - loss: 25.7949 - RecoProb_metric: 19.4494 - KL_loss_m - ETA: 54s - loss: 25. - ETA: 49s - loss: 25.7876 - RecoProb_metric:  - ETA: 46s - loss: 25.8024 - RecoProb_metric: 19.4486 - KL_lo - ET - ETA: 36s - loss: 25.8102  - ETA: 31s - loss: 25.8048 - RecoProb_metric: 19.4513 - KL_loss_ - ETA: 29s - l - ETA: 24s - - ETA: 18s - loss: 25.8053 - RecoProb_metri - ETA: 13s - loss:  - ETA: 8s - loss: 25.8019 - RecoProb_metric - ETA: 7s - l - ETA - ETA: 0s - loss: 25.8084 - RecoProb_metric: 19.4551 -
# Epoch 54/100
# 932956/932956 [==============================] - 56s 60us/step - loss: 25.8060 - RecoProb_metric: 19.4481 - KL_loss_metric: 6.3580 - val_loss: 25.9080 - val_RecoProb_metric: 19.5466 - val_KL_loss_metric: 6.3614
# Epoch 55/100
# 931600/932956 [============================>.] - ETA: 0s - loss: 25.8039 - RecoProb_metric: 19.4303 - KL_loss_metric: 6.3736
# Epoch 00055: reducing learning rate to 1.00000006569e-06.
# 932956/932956 [==============================] - 29s 31us/step - loss: 25.8034 - RecoProb_metric: 19.4298 - KL_loss_metric: 6.3736 - val_loss: 25.9235 - val_RecoProb_metric: 19.5278 - val_KL_loss_metric: 6.3957
# Epoch 56/100
# 932956/932956 [==============================] - 28s 30us/step - loss: 25.7847 - RecoProb_metric: 19.4025 - KL_loss_metric: 6.3822 - val_loss: 25.9112 - val_RecoProb_metric: 19.5336 - val_KL_loss_metric: 6.3777
# Epoch 57/100
# 932956/932956 [==============================] - 28s 30us/step - loss: 25.7841 - RecoProb_metric: 19.4169 - KL_loss_metric: 6.3672 - val_loss: 25.8990 - val_RecoProb_metric: 19.5312 - val_KL_loss_metric: 6.3678
# Epoch 58/100
# 932956/932956 [==============================] - 29s 31us/step - loss: 25.7734 - RecoProb_metric: 19.4168 - KL_loss_metric: 6.3566 - val_loss: 25.8932 - val_RecoProb_metric: 19.5365 - val_KL_loss_metric: 6.3567
# Epoch 00058: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.plot(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.plot(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
if 1:
    vae.save(SampleName + '_v3-1_SWAN_VAE.h5')
else:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model(SampleName + '_v3-1_SWAN_VAE.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if 1:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save(SampleName + '_v3-1_SWAN_prior.h5')
else:
    Prior_Dumper = load_model(SampleName + '_v3-1_SWAN_prior.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [-5.79259491 -3.37539148 -4.05108881 -4.89123678]
# [ 1.9159925   3.12084293  1.85077894  1.80354142]

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save(SampleName + '_v3-1_SWAN_encoder.h5')
else:
    encoder = load_model(SampleName + '_v3-1_SWAN_encoder.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# AtoChHW_HIGHMASS
# Wlnu
# AtoChHW
# Wprime
# Ato4l
# Zprime
# ttbar

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    lower_bound = mu_prior[kk] - 6*sigma_prior[kk]
    upper_bound = mu_prior[kk] + 6*sigma_prior[kk]
    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], lower_bound, upper_bound)
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], lower_bound, upper_bound)
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)
    
fout = rt.TFile('plots/'+SampleName + '_v3-1_SWAN_meanZ.root', 'RECREATE')
for obj in canvases + histos:
    obj.Write()

fout.Close()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: hBSM6_3 (Potential memory leak).

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save(SampleName + '_v3-1_SWAN_autoencoder.h5')
else:
    autoencoder = load_model(SampleName + '_v3-1_SWAN_autoencoder.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# AtoChHW_HIGHMASS
# Wlnu
# AtoChHW
# Wprime
# Ato4l
# Zprime
# ttbar

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
a = np.array([1,2,3,4,5])
np.argmin(a<3)
a[2:]
# Out:
# array([3, 4, 5])

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 99.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        if np.sum(bin_edges>clip_x_to0) > 0:
            i_aux = np.argmin(bin_edges<clip_x_to0)
            bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[i_aux:]))
        else:
            bin_edges = np.array([0, clip_x_to0])
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bin_edges[1:] - bin_edges[:-1]
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# [   0.            3.95032698    7.90065395   11.85098093   15.80130791
#    19.75163488   23.70196186   27.65228884   31.60261581   35.55294279
#    39.50326977   43.45359674   47.40392372   51.3542507    55.30457767
#    59.25490465   63.20523163   67.15555861   71.10588558   75.05621256
#    79.00653954   82.95686651   86.90719349   90.85752047   94.80784744
#    98.75817442  102.7085014   106.65882837  110.60915535  114.55948233
#   118.5098093   122.46013628  126.41046326  130.36079023  134.31111721
#   138.26144419  142.21177116  146.16209814  150.11242512  154.06275209
#   158.01307907]
# MET
# [  0.           1.32918859   2.65837719   3.98756578   5.31675438
#    6.64594297   7.97513157   9.30432016  10.63350876  11.96269735
#   13.29188595  14.62107454  15.95026314  17.27945173  18.60864033
#   19.93782892  21.26701752  22.59620611  23.92539471  25.2545833
#   26.5837719   27.91296049  29.24214909  30.57133768  31.90052628
#   33.22971487  34.55890347  35.88809206  37.21728065  38.54646925
#   39.87565784  41.20484644  42.53403503  43.86322363  45.19241222
#   46.52160082  47.85078941  49.17997801  50.5091666   51.8383552
#   53.16754379]
# allJetMass
# [   0.            6.74234857   13.48469713   20.2270457    26.96939426
#    33.71174283   40.45409139   47.19643996   53.93878853   60.68113709
#    67.42348566   74.16583422   80.90818279   87.65053135   94.39287992
#   101.13522848  107.87757705  114.61992562  121.36227418  128.10462275
#   134.84697131  141.58931988  148.33166844  155.07401701  161.81636558
#   168.55871414  175.30106271  182.04341127  188.78575984  195.5281084
#   202.27045697  209.01280554  215.7551541   222.49750267  229.23985123
#   235.9821998   242.72454836  249.46689693  256.2092455   262.95159406
#   269.69394263]
# allMuPt
# [  0.           2.10730124   4.21460249   6.32190373   8.42920497
#   10.53650621  12.64380746  14.7511087   16.85840994  18.96571119
#   21.07301243  23.18031367  25.28761491  27.39491616  29.5022174
#   31.60951864  33.71681989  35.82412113  37.93142237  40.03872361
#   42.14602486  44.2533261   46.36062734  48.46792858  50.57522983
#   52.68253107  54.78983231  56.89713356  59.0044348   61.11173604
#   63.21903728  65.32633853  67.43363977  69.54094101  71.64824226
#   73.7555435   75.86284474  77.97014598  80.07744723  82.18474847
#   84.29204971]
# allElePt
# [  0.           2.15943264   4.31886528   6.47829792   8.63773056
#   10.7971632   12.95659584  15.11602848  17.27546112  19.43489376
#   21.5943264   23.75375904  25.91319168  28.07262432  30.23205696
#   32.3914896   34.55092224  36.71035488  38.86978752  41.02922016
#   43.1886528   45.34808544  47.50751808  49.66695072  51.82638336
#   53.985816    56.14524864  58.30468128  60.46411392  62.62354656
#   64.7829792   66.94241184  69.10184448  71.26127712  73.42070976
#   75.5801424   77.73957504  79.89900768  82.05844032  84.21787296
#   86.3773056 ]
# allEleMass
# [  0.00000000e+00   1.90734863e-07   3.81469727e-07   5.72204590e-07
#    7.62939453e-07   9.53674316e-07   1.14440918e-06   1.33514404e-06
#    1.52587891e-06   1.71661377e-06   1.90734863e-06   2.09808350e-06
#    2.28881836e-06   2.47955322e-06   2.67028809e-06   2.86102295e-06
#    3.05175781e-06   3.24249268e-06   3.43322754e-06   3.62396240e-06
#    3.81469727e-06   4.00543213e-06   4.19616699e-06   4.38690186e-06
#    4.57763672e-06   4.76837158e-06   4.95910645e-06   5.14984131e-06
#    5.34057617e-06   5.53131104e-06   5.72204590e-06   5.91278076e-06
#    6.10351563e-06   6.29425049e-06   6.48498535e-06   6.67572021e-06
#    6.86645508e-06   7.05718994e-06   7.24792480e-06   7.43865967e-06
#    7.62939453e-06]
# allMuMass
# [  0.00000000e+00   6.74349576e-08   1.34869915e-07   2.02304873e-07
#    2.69739830e-07   3.37174788e-07   4.04609746e-07   4.72044703e-07
#    5.39479661e-07   6.06914619e-07   6.74349576e-07   7.41784534e-07
#    8.09219491e-07   8.76654449e-07   9.44089407e-07   1.01152436e-06
#    1.07895932e-06   1.14639428e-06   1.21382924e-06   1.28126419e-06
#    1.34869915e-06   1.41613411e-06   1.48356907e-06   1.55100403e-06
#    1.61843898e-06   1.68587394e-06   1.75330890e-06   1.82074386e-06
#    1.88817881e-06   1.95561377e-06   2.02304873e-06   2.09048369e-06
#    2.15791864e-06   2.22535360e-06   2.29278856e-06   2.36022352e-06
#    2.42765847e-06   2.49509343e-06   2.56252839e-06   2.62996335e-06
#    2.69739830e-06]
# LepPt
# [  0.           1.24589484   2.49178968   3.73768453   4.98357937
#    6.22947421   7.47536905   8.7212639    9.96715874  11.21305358
#   12.45894842  13.70484326  14.95073811  16.19663295  17.44252779
#   18.68842263  19.93431747  21.18021232  22.42610716  23.672002
#   24.91789684  26.16379169  27.40968653  28.65558137  29.90147621
#   31.14737105  32.3932659   33.63916074  34.88505558  36.13095042
#   37.37684526  38.62274011  39.86863495  41.11452979  42.36042463
#   43.60631948  44.85221432  46.09810916  47.344004    48.58989884
#   49.83579369]
# LepIsoCh
# [ 0.          0.00932165  0.0186433   0.02796496  0.03728661  0.04660826
#   0.05592991  0.06525157  0.07457322  0.08389487  0.09321652  0.10253817
#   0.11185983  0.12118148  0.13050313  0.13982478  0.14914644  0.15846809
#   0.16778974  0.17711139  0.18643304  0.1957547   0.20507635  0.214398
#   0.22371965  0.23304131  0.24236296  0.25168461  0.26100626  0.27032791
#   0.27964957  0.28897122  0.29829287  0.30761452  0.31693618  0.32625783
#   0.33557948  0.34490113  0.35422278  0.36354444  0.37286609]
# LepIsoGamma
# [ 0.          0.00586772  0.01173545  0.01760317  0.02347089  0.02933862
#   0.03520634  0.04107407  0.04694179  0.05280951  0.05867724  0.06454496
#   0.07041268  0.07628041  0.08214813  0.08801586  0.09388358  0.0997513
#   0.10561903  0.11148675  0.11735447  0.1232222   0.12908992  0.13495765
#   0.14082537  0.14669309  0.15256082  0.15842854  0.16429626  0.17016399
#   0.17603171  0.18189944  0.18776716  0.19363488  0.19950261  0.20537033
#   0.21123805  0.21710578  0.2229735   0.22884123  0.23470895]
# LepIsoNeu
# [ 0.          0.00541553  0.01083105  0.01624658  0.02166211  0.02707763
#   0.03249316  0.03790868  0.04332421  0.04873974  0.05415526  0.05957079
#   0.06498632  0.07040184  0.07581737  0.0812329   0.08664842  0.09206395
#   0.09747948  0.102895    0.10831053  0.11372605  0.11914158  0.12455711
#   0.12997263  0.13538816  0.14080369  0.14621921  0.15163474  0.15705027
#   0.16246579  0.16788132  0.17329685  0.17871237  0.1841279   0.18954342
#   0.19495895  0.20037448  0.20579     0.21120553  0.21662106]
# LepEta
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
def numpy_KL_loss(mu, sigma):
    sp = np.atleast_2d(sigma_prior)
    mp = np.atleast_2d(mu_prior)
    kl_loss = np.square(sigma)*np.square(sp)
    kl_loss += np.square((mp - mu)/sp)
    kl_loss += np.log(sp/sigma) -1

    return 0.5 * np.sum(kl_loss, axis=-1)

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1).real - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(single_NLL, axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# AtoChHW_HIGHMASS
# Wlnu
# AtoChHW
# Wprime
# Ato4l
# Zprime
# ttbar

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]
    print binning
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(8)
    h.SetFillColorAlpha(8, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-3))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 46]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)
    
fout = rt.TFile('plots/'+SampleName+ '_v3-1_SWAN_losses.root', 'RECREATE')
for obj in canvases + histos:
    obj.Write()

fout.Close()
# Out:
# [100, 12.32707506379422, 265.5896870322627]
# [100, 5.9451427087614999, 230.53715890970909]
# [100, 5.0977311, 67.810135031011697]

# %%
import h5py

fout = h5py.File('losses/'+SampleName+ '_v3-1_array.h5', "w")
fout.create_dataset(SampleName, data=np.array(loss_train))

for k,v in loss_sig.items():
    print k
    fout.create_dataset(k, data=np.array(v))
    
fout.close()
# Out:
# AtoChHW_HIGHMASS
# Wlnu
# AtoChHW
# Wprime
# Ato4l
# Zprime
# ttbar

# %%
f = h5py.File('losses/ttbar_v3-1_array.h5', 'r')
f.keys()
# Out:
# [u'Ato4l',
#  u'AtoChHW',
#  u'AtoChHW_HIGHMASS',
#  u'Wlnu',
#  u'Wprime',
#  u'Zprime',
#  u'qcd',
#  u'ttbar']
