# %% [markdown]
# - Traial to remove the KL divergence

# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.12/06

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# Using TensorFlow backend.
# 2.2.2

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'PhiMET', 'MT', 'nJets', 'bJets',
                'allJetMass', 'LepPt', 'LepEta', 'LepPhi', 'LepIsoCh',
                'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 'LepIsEle', 'nMu',
                'allMuMass', 'allMuPt', 'nEle', 'allEleMass', 'allElePt', 'nChHad',
                'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'MET', 'allJetMass',
                       'allMuPt','allElePt','allEleMass', 'allMuMass',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 11
Nf_gauss = 1
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	allEleMass
# 	allMuMass
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/'
SampleName = 'ttbar'
N_train = int(2e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (3003158, 24) (2000000, 22)

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim = 50
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

def SmashTo0(x):
    return 0*x

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(20, kernel_initializer='zeros', bias_initializer='ones', trainable=False)(fixed_input)
# h2_prior = Dense(100, activation=act_fun)(h1_prior)

L_prior_mean = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='zeros', trainable=True)(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='ones', trainable=True)(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit)(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return K.mean(0.5 * K.sum(kl_loss, axis=-1))

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    mu_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    sigma_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
#     return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior) + RecoProb_forVAE(y_train, par1, par2, par3)
    return RecoProb_forVAE(y_train, par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = 4*latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train, par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim: 2*latent_dim]
    mu_prior = NETout[:, 2*latent_dim: 3*latent_dim]
    sigma_prior = NETout[:, 3*latent_dim: 4*latent_dim]
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_prior_mean, L_prior_sigma, L_par1, L_par2, L_par3])

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
print vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 22)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           1150        input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           2550        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4)            0           dense_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 22)           0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           250         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 20)           460         lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           2550        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 17)           867         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 11)           561         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 4)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 22)           1122        dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 17)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 11)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 66)           0           dense_3[0][0]
#                                                                  lambda_1[0][0]
#                                                                  dense_11[0][0]
#                                                                  lambda_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# ==================================================================================================
# Total params: 10,086
# Trainable params: 9,626
# Non-trainable params: 460
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
fit_report = vae.fit(x=x_train, y=x_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=400,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, epsilon=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# /Users/olmo/programs/miniconda2/lib/python2.7/site-packages/keras/callbacks.py:999: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# Train on 1600000 samples, validate on 400000 samples
# Epoch 1/100
# 1600000/1600000 [==============================] - 44s 27us/step - loss: 120681.0432 - RecoProb_metric: 120681.0195 - KL_loss_metric: 5335.0244 - val_loss: 76.2332 - val_RecoProb_metric: 76.2332 - val_KL_loss_metric: 7061.5778
# Epoch 2/100
# 1600000/1600000 [==============================] - 48s 30us/step - loss: 57.2864 - RecoProb_metric: 57.2864 - KL_loss_metric: 4332.4914 - val_loss: 51.4510 - val_RecoProb_metric: 51.4510 - val_KL_loss_metric: 3993.7432
# Epoch 3/100
# 1600000/1600000 [==============================] - 47s 29us/step - loss: 51.2051 - RecoProb_metric: 51.2051 - KL_loss_metric: 4457.2422 - val_loss: 54.0077 - val_RecoProb_metric: 54.0077 - val_KL_loss_metric: 4243.7280
# Epoch 4/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 46.7793 - RecoProb_metric: 46.7793 - KL_loss_metric: 4110.2549 - val_loss: 48.4870 - val_RecoProb_metric: 48.4870 - val_KL_loss_metric: 2860.3046
# Epoch 5/100
# 1600000/1600000 [==============================] - 45s 28us/step - loss: 41.8986 - RecoProb_metric: 41.8986 - KL_loss_metric: 2681.9251 - val_loss: 39.4685 - val_RecoProb_metric: 39.4685 - val_KL_loss_metric: 1796.4777
# Epoch 6/100
# 1600000/1600000 [==============================] - 44s 28us/step - loss: 47.9084 - RecoProb_metric: 47.9084 - KL_loss_metric: 3059.7456 - val_loss: 45.0490 - val_RecoProb_metric: 45.0490 - val_KL_loss_metric: 3456.7418
# Epoch 7/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 43.2042 - RecoProb_metric: 43.2042 - KL_loss_metric: 2348.3075 - val_loss: 39.9376 - val_RecoProb_metric: 39.9376 - val_KL_loss_metric: 1534.5243
# Epoch 8/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 38.4724 - RecoProb_metric: 38.4724 - KL_loss_metric: 1176.0796 - val_loss: 36.7173 - val_RecoProb_metric: 36.7173 - val_KL_loss_metric: 882.1046
# Epoch 9/100
# 1600000/1600000 [==============================] - 35s 22us/step - loss: 36.8650 - RecoProb_metric: 36.8650 - KL_loss_metric: 739.7302 - val_loss: 35.8599 - val_RecoProb_metric: 35.8599 - val_KL_loss_metric: 622.8107
# Epoch 10/100
# 1600000/1600000 [==============================] - 35s 22us/step - loss: 35.9104 - RecoProb_metric: 35.9104 - KL_loss_metric: 584.3313 - val_loss: 35.5972 - val_RecoProb_metric: 35.5972 - val_KL_loss_metric: 533.5311
# Epoch 11/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 35.1500 - RecoProb_metric: 35.1500 - KL_loss_metric: 508.1858 - val_loss: 36.7004 - val_RecoProb_metric: 36.7004 - val_KL_loss_metric: 480.8033
# Epoch 12/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 34.6001 - RecoProb_metric: 34.6001 - KL_loss_metric: 448.6396 - val_loss: 34.6220 - val_RecoProb_metric: 34.6220 - val_KL_loss_metric: 435.2654
# Epoch 13/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 34.2689 - RecoProb_metric: 34.2689 - KL_loss_metric: 427.7949 - val_loss: 33.2296 - val_RecoProb_metric: 33.2296 - val_KL_loss_metric: 412.1529
# Epoch 14/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 34.2132 - RecoProb_metric: 34.2132 - KL_loss_metric: 384.4135 - val_loss: 33.7596 - val_RecoProb_metric: 33.7596 - val_KL_loss_metric: 385.8586
# Epoch 15/100
# 1600000/1600000 [==============================] - 36s 22us/step - loss: 34.1934 - RecoProb_metric: 34.1934 - KL_loss_metric: 368.4559 - val_loss: 32.8573 - val_RecoProb_metric: 32.8573 - val_KL_loss_metric: 340.7450
# Epoch 16/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 33.5138 - RecoProb_metric: 33.5138 - KL_loss_metric: 351.9869 - val_loss: 32.4649 - val_RecoProb_metric: 32.4649 - val_KL_loss_metric: 348.4009
# Epoch 17/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 33.4958 - RecoProb_metric: 33.4958 - KL_loss_metric: 344.0578 - val_loss: 37.1554 - val_RecoProb_metric: 37.1554 - val_KL_loss_metric: 358.2529
# Epoch 18/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 33.1678 - RecoProb_metric: 33.1678 - KL_loss_metric: 336.3052 - val_loss: 32.7274 - val_RecoProb_metric: 32.7274 - val_KL_loss_metric: 325.5558
# Epoch 19/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 33.3103 - RecoProb_metric: 33.3103 - KL_loss_metric: 322.1892 - val_loss: 36.6978 - val_RecoProb_metric: 36.6978 - val_KL_loss_metric: 310.4748
# Epoch 20/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 33.0334 - RecoProb_metric: 33.0334 - KL_loss_metric: 300.4430 - val_loss: 32.4377 - val_RecoProb_metric: 32.4377 - val_KL_loss_metric: 304.4234
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000475.
# Epoch 21/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 31.1600 - RecoProb_metric: 31.1600 - KL_loss_metric: 307.7464 - val_loss: 30.9154 - val_RecoProb_metric: 30.9154 - val_KL_loss_metric: 311.8335
# Epoch 22/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 30.8859 - RecoProb_metric: 30.8859 - KL_loss_metric: 316.2620 - val_loss: 30.7654 - val_RecoProb_metric: 30.7654 - val_KL_loss_metric: 316.3555
# Epoch 23/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 30.7400 - RecoProb_metric: 30.7400 - KL_loss_metric: 319.4435 - val_loss: 30.6107 - val_RecoProb_metric: 30.6107 - val_KL_loss_metric: 319.0621
# Epoch 24/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 30.6232 - RecoProb_metric: 30.6232 - KL_loss_metric: 321.4378 - val_loss: 30.5219 - val_RecoProb_metric: 30.5219 - val_KL_loss_metric: 322.3514
# Epoch 25/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 30.4984 - RecoProb_metric: 30.4984 - KL_loss_metric: 322.0407 - val_loss: 30.3540 - val_RecoProb_metric: 30.3540 - val_KL_loss_metric: 320.7982
# Epoch 26/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 30.4340 - RecoProb_metric: 30.4340 - KL_loss_metric: 323.1890 - val_loss: 30.3448 - val_RecoProb_metric: 30.3448 - val_KL_loss_metric: 322.6074
# Epoch 27/100
# 1600000/1600000 [==============================] - 68s 42us/step - loss: 30.3313 - RecoProb_metric: 30.3313 - KL_loss_metric: 323.9640 - val_loss: 30.7890 - val_RecoProb_metric: 30.7890 - val_KL_loss_metric: 324.8797
# Epoch 28/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 30.2587 - RecoProb_metric: 30.2587 - KL_loss_metric: 324.0250 - val_loss: 30.3825 - val_RecoProb_metric: 30.3825 - val_KL_loss_metric: 324.3808
# Epoch 29/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 30.2169 - RecoProb_metric: 30.2169 - KL_loss_metric: 325.2697 - val_loss: 30.0932 - val_RecoProb_metric: 30.0932 - val_KL_loss_metric: 323.8361
# Epoch 30/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 30.1638 - RecoProb_metric: 30.1638 - KL_loss_metric: 325.3524 - val_loss: 30.0774 - val_RecoProb_metric: 30.0774 - val_KL_loss_metric: 325.0798
# Epoch 31/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 30.0762 - RecoProb_metric: 30.0762 - KL_loss_metric: 324.8882 - val_loss: 30.0561 - val_RecoProb_metric: 30.0561 - val_KL_loss_metric: 323.2508
# Epoch 32/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 30.0326 - RecoProb_metric: 30.0326 - KL_loss_metric: 325.2880 - val_loss: 29.9454 - val_RecoProb_metric: 29.9454 - val_KL_loss_metric: 324.7843
# Epoch 33/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 29.9725 - RecoProb_metric: 29.9725 - KL_loss_metric: 325.9352 - val_loss: 29.8986 - val_RecoProb_metric: 29.8986 - val_KL_loss_metric: 325.1284
# Epoch 34/100
# 1600000/1600000 [==============================] - 39s 25us/step - loss: 29.9286 - RecoProb_metric: 29.9286 - KL_loss_metric: 326.1277 - val_loss: 29.8297 - val_RecoProb_metric: 29.8297 - val_KL_loss_metric: 325.2658
# Epoch 35/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 29.8803 - RecoProb_metric: 29.8803 - KL_loss_metric: 326.1587 - val_loss: 29.7586 - val_RecoProb_metric: 29.7586 - val_KL_loss_metric: 325.0936
# Epoch 36/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 29.8445 - RecoProb_metric: 29.8445 - KL_loss_metric: 326.3120 - val_loss: 29.9055 - val_RecoProb_metric: 29.9055 - val_KL_loss_metric: 324.4194
# Epoch 37/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 29.7787 - RecoProb_metric: 29.7787 - KL_loss_metric: 325.3648 - val_loss: 29.6832 - val_RecoProb_metric: 29.6832 - val_KL_loss_metric: 322.5428
# Epoch 38/100
# 1600000/1600000 [==============================] - 37s 23us/step - loss: 29.7388 - RecoProb_metric: 29.7388 - KL_loss_metric: 323.3242 - val_loss: 29.8988 - val_RecoProb_metric: 29.8988 - val_KL_loss_metric: 321.4628
# Epoch 39/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 29.7030 - RecoProb_metric: 29.7030 - KL_loss_metric: 321.3847 - val_loss: 29.5926 - val_RecoProb_metric: 29.5926 - val_KL_loss_metric: 320.3913
# Epoch 40/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 29.6527 - RecoProb_metric: 29.6527 - KL_loss_metric: 318.9603 - val_loss: 29.6058 - val_RecoProb_metric: 29.6058 - val_KL_loss_metric: 317.0939
# Epoch 41/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 29.6469 - RecoProb_metric: 29.6469 - KL_loss_metric: 317.4486 - val_loss: 29.6609 - val_RecoProb_metric: 29.6609 - val_KL_loss_metric: 313.5768
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1.0000000475e-05.
# Epoch 42/100
# 1600000/1600000 [==============================] - 39s 24us/step - loss: 29.4413 - RecoProb_metric: 29.4413 - KL_loss_metric: 315.7588 - val_loss: 29.4433 - val_RecoProb_metric: 29.4433 - val_KL_loss_metric: 314.9501
# Epoch 43/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 29.4258 - RecoProb_metric: 29.4258 - KL_loss_metric: 316.1631 - val_loss: 29.4326 - val_RecoProb_metric: 29.4326 - val_KL_loss_metric: 315.6880
# Epoch 44/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 29.4149 - RecoProb_metric: 29.4149 - KL_loss_metric: 316.4962 - val_loss: 29.4247 - val_RecoProb_metric: 29.4247 - val_KL_loss_metric: 315.0090
# Epoch 45/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 29.4081 - RecoProb_metric: 29.4081 - KL_loss_metric: 316.3882 - val_loss: 29.4053 - val_RecoProb_metric: 29.4053 - val_KL_loss_metric: 315.3102
# Epoch 46/100
# 1600000/1600000 [==============================] - 42s 26us/step - loss: 29.4003 - RecoProb_metric: 29.4003 - KL_loss_metric: 316.4825 - val_loss: 29.4054 - val_RecoProb_metric: 29.4054 - val_KL_loss_metric: 315.7135
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.00000006569e-06.
# Epoch 47/100
# 1600000/1600000 [==============================] - 41s 25us/step - loss: 29.3761 - RecoProb_metric: 29.3761 - KL_loss_metric: 316.7418 - val_loss: 29.3701 - val_RecoProb_metric: 29.3701 - val_KL_loss_metric: 315.6749
# Epoch 48/100
# 1600000/1600000 [==============================] - 44s 27us/step - loss: 29.3742 - RecoProb_metric: 29.3742 - KL_loss_metric: 316.6581 - val_loss: 29.3678 - val_RecoProb_metric: 29.3678 - val_KL_loss_metric: 315.5474
# Epoch 49/100
# 1600000/1600000 [==============================] - 49s 30us/step - loss: 29.3729 - RecoProb_metric: 29.3729 - KL_loss_metric: 316.6458 - val_loss: 29.3702 - val_RecoProb_metric: 29.3702 - val_KL_loss_metric: 315.5799
# Epoch 50/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 29.3717 - RecoProb_metric: 29.3717 - KL_loss_metric: 316.5581 - val_loss: 29.3669 - val_RecoProb_metric: 29.3669 - val_KL_loss_metric: 315.5797
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.00000011116e-07.
# Epoch 51/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 29.3687 - RecoProb_metric: 29.3687 - KL_loss_metric: 316.6236 - val_loss: 29.3646 - val_RecoProb_metric: 29.3646 - val_KL_loss_metric: 315.5723
# Epoch 52/100
# 1600000/1600000 [==============================] - 36s 23us/step - loss: 29.3684 - RecoProb_metric: 29.3684 - KL_loss_metric: 316.6185 - val_loss: 29.3647 - val_RecoProb_metric: 29.3647 - val_KL_loss_metric: 315.5769
# Epoch 53/100
# 1600000/1600000 [==============================] - 41s 26us/step - loss: 29.3683 - RecoProb_metric: 29.3683 - KL_loss_metric: 316.6142 - val_loss: 29.3646 - val_RecoProb_metric: 29.3646 - val_KL_loss_metric: 315.5542
# Epoch 54/100
# 1600000/1600000 [==============================] - 38s 24us/step - loss: 29.3682 - RecoProb_metric: 29.3682 - KL_loss_metric: 316.6179 - val_loss: 29.3644 - val_RecoProb_metric: 29.3644 - val_KL_loss_metric: 315.5647
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.00000008274e-08.
# Epoch 55/100
# 1600000/1600000 [==============================] - 40s 25us/step - loss: 29.3679 - RecoProb_metric: 29.3679 - KL_loss_metric: 316.5991 - val_loss: 29.3642 - val_RecoProb_metric: 29.3642 - val_KL_loss_metric: 315.5551
# Epoch 00055: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.plot(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.plot(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
if 1:
    vae.save('last_saved_VAE.h5')
else:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model('last_saved_VAE.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if 1:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save('last_saved_prior.h5')
else:
    Prior_Dumper = load_model('last_saved_prior.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [0. 0. 0. 0.]
# [2.005 2.005 2.005 2.005]

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save('last_saved_encoder.h5')
else:
    encoder = load_model('last_saved_encoder.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
data_folder = '../../data/'

BSM_samples = ['AtoChHW', 'AtoChHW_HIGHMASS', 'Ato4l', 'Zprime', 'Wprime', 'qcd', 'Wlnu']

x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    lower_bound = -100#mu_prior[kk] - 6*sigma_prior[kk]
    upper_bound = 50#mu_prior[kk] + 6*sigma_prior[kk]
    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], lower_bound, upper_bound)
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], lower_bound, upper_bound)
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('last_saved_autoencoder.h5')
else:
    autoencoder = load_model('last_saved_autoencoder.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 95.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[1:]))
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = (bincenters[10]-bincenters[9])*np.ones_like(bincenters)
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# MET
# allJetMass
# allMuPt
# allElePt
# allEleMass
# allMuMass
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# LepEta
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
def numpy_KL_loss(mu, sigma):
    sp = np.atleast_2d(sigma_prior)
    mp = np.atleast_2d(mu_prior)
    kl_loss = np.square(sigma)*np.square(sp)
    kl_loss += np.square((mp - mu)/sp)
    kl_loss += np.log(sp/sigma) -1

    return 0.5 * np.sum(kl_loss, axis=-1)

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1) - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(single_NLL, axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]
    print binning
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-3))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    
    canvases.append(c)
# Out:
# [100, 48.79546028742264, 19445.071177204485]
# [100, 8.793749538428422, 334.2498247937884]
# [100, 26.316807, 19388.886888280962]
