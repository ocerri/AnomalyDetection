# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.12/06

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# Using TensorFlow backend.
# 2.2.2

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'PhiMET', 'MT', 'nJets', 'bJets',
                'allJetMass', 'LepPt', 'LepEta', 'LepPhi', 'LepIsoCh',
                'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 'LepIsEle', 'nMu',
                'allMuMass', 'allMuPt', 'nEle', 'allEleMass', 'allElePt', 'nChHad',
                'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'MET', 'allJetMass',
                       'allMuPt','allElePt',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 9
Nf_gauss = 1
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/'
SampleName = 'ttbar'
N_train = int(1e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (3003158, 24) (1000000, 20)

# %%
# aux = x_train.T
# scale = np.where(np.less(np.min(aux, axis=1), 0), np.std(aux, axis=1), np.percentile(aux, 60, axis=1))
# for s,n in zip(scale, active_hlf_features):
#     print n, s
   
scale = np.zeros(len(sel))
for k, i in enumerate(sel):
    x = raw_sample[:N_train, i]
    m = np.min(x)
    
    if 'Charge' in hlf_features[i] or 'IsEle' in hlf_features[i]:
        s = 1
    elif 'LepIso' in hlf_features[i]:
        s = np.percentile(x, 90)
    elif m < 0:
        s = np.std(x)
    else:
        s = np.percentile(x, 60)

    print hlf_features[i], '{:1.3e}'.format(s)
    scale[k] = float(s)
    
#     x_train[:, k] /= s
# Out:
# (20,)
# HT 2.865e+02
# MET 7.096e+01
# allJetMass 3.557e+02
# allMuPt 7.222e+01
# allElePt 6.722e+01
# LepPt 6.069e+01
# LepIsoCh 1.143e-01
# LepIsoGamma 6.144e-02
# LepIsoNeu 6.271e-02
# LepEta 1.240e+00
# MT 1.143e+02
# nMu 2.000e+00
# nJets 4.000e+00
# bJets 2.000e+00
# nEle 2.000e+00
# LepCharge 1.000e+00
# LepIsEle 1.000e+00
# nChHad 3.220e+02
# nNeuHad 1.370e+02
# nPhoton 8.400e+01
# [2.86501191e+02 7.09573654e+01 3.55720741e+02 7.22214333e+01
#  6.72200073e+01 6.06896492e+01 1.14305810e-01 6.14422155e-02
#  6.27084952e-02 1.24027471e+00 1.14285647e+02 2.00000000e+00
#  4.00000000e+00 2.00000000e+00 2.00000000e+00 1.00000000e+00
#  1.00000000e+00 3.22000000e+02 1.37000000e+02 8.40000000e+01]

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim =80
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma):
    kl_loss = - 0.5 * K.sum(1 + 2*K.log(sigma) - K.square(mu) - K.square(sigma), axis=-1)
    return K.mean(kl_loss)

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return KL_loss_forVAE(mu, sigma) + RecoProb_forVAE(y_train, par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = latent_dim
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train, par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim:2*latent_dim]
    return KL_loss_forVAE(mu, sigma)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_par1, L_par2, L_par3])

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
# print vae.summary()

# %% [markdown]
# # Training

# %%
fit_report = vae.fit(x=x_train, y=x_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=200,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, min_delta=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# Train on 800000 samples, validate on 200000 samples
# Epoch 1/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 66896.1680 - RecoProb_metric: 66220.9794 - KL_loss_metric: 675.1954 - val_loss: 110.4003 - val_RecoProb_metric: 71.1959 - val_KL_loss_metric: 39.2044
# Epoch 2/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 91.3167 - RecoProb_metric: 63.8280 - KL_loss_metric: 27.4887 - val_loss: 81.0095 - val_RecoProb_metric: 58.3636 - val_KL_loss_metric: 22.6459
# Epoch 3/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 71.3366 - RecoProb_metric: 53.4110 - KL_loss_metric: 17.9256 - val_loss: 65.5161 - val_RecoProb_metric: 49.4403 - val_KL_loss_metric: 16.0759
# Epoch 4/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 62.4730 - RecoProb_metric: 47.9861 - KL_loss_metric: 14.4870 - val_loss: 57.9333 - val_RecoProb_metric: 44.8400 - val_KL_loss_metric: 13.0933
# Epoch 5/100
# 800000/800000 [==============================] - 30s 38us/step - loss: 59.1526 - RecoProb_metric: 46.3776 - KL_loss_metric: 12.7751 - val_loss: 54.8406 - val_RecoProb_metric: 44.0562 - val_KL_loss_metric: 10.7843
# Epoch 6/100
# 800000/800000 [==============================] - 34s 43us/step - loss: 59.3917 - RecoProb_metric: 45.8763 - KL_loss_metric: 13.5153 - val_loss: 62.7767 - val_RecoProb_metric: 48.9488 - val_KL_loss_metric: 13.8279
# Epoch 7/100
# 800000/800000 [==============================] - 33s 41us/step - loss: 54.1560 - RecoProb_metric: 43.8410 - KL_loss_metric: 10.3150 - val_loss: 53.5322 - val_RecoProb_metric: 46.3983 - val_KL_loss_metric: 7.1339
# Epoch 8/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 50.1748 - RecoProb_metric: 42.2574 - KL_loss_metric: 7.9174 - val_loss: 52.0836 - val_RecoProb_metric: 44.0291 - val_KL_loss_metric: 8.0546
# Epoch 9/100
# 800000/800000 [==============================] - 31s 39us/step - loss: 48.1453 - RecoProb_metric: 41.0036 - KL_loss_metric: 7.1418 - val_loss: 46.8468 - val_RecoProb_metric: 40.7743 - val_KL_loss_metric: 6.0725
# Epoch 10/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 46.7412 - RecoProb_metric: 39.7690 - KL_loss_metric: 6.9722 - val_loss: 46.6260 - val_RecoProb_metric: 38.3801 - val_KL_loss_metric: 8.2459
# Epoch 11/100
# 800000/800000 [==============================] - 35s 43us/step - loss: 45.9222 - RecoProb_metric: 38.8187 - KL_loss_metric: 7.1035 - val_loss: 45.4784 - val_RecoProb_metric: 38.5074 - val_KL_loss_metric: 6.9710
# Epoch 12/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 45.3719 - RecoProb_metric: 38.1761 - KL_loss_metric: 7.1957 - val_loss: 44.7014 - val_RecoProb_metric: 37.4172 - val_KL_loss_metric: 7.2842
# Epoch 13/100
# 800000/800000 [==============================] - 33s 41us/step - loss: 45.0947 - RecoProb_metric: 37.8258 - KL_loss_metric: 7.2689 - val_loss: 45.1917 - val_RecoProb_metric: 37.5363 - val_KL_loss_metric: 7.6554
# Epoch 14/100
# 800000/800000 [==============================] - 33s 41us/step - loss: 44.8093 - RecoProb_metric: 37.5049 - KL_loss_metric: 7.3043 - val_loss: 44.4483 - val_RecoProb_metric: 36.8636 - val_KL_loss_metric: 7.5846
# Epoch 15/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 44.4122 - RecoProb_metric: 36.9766 - KL_loss_metric: 7.4356 - val_loss: 44.0673 - val_RecoProb_metric: 36.4932 - val_KL_loss_metric: 7.5741
# Epoch 16/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 44.2962 - RecoProb_metric: 36.7959 - KL_loss_metric: 7.5003 - val_loss: 44.1595 - val_RecoProb_metric: 36.6479 - val_KL_loss_metric: 7.5116
# Epoch 17/100
# 800000/800000 [==============================] - 31s 39us/step - loss: 44.1963 - RecoProb_metric: 36.6122 - KL_loss_metric: 7.5841 - val_loss: 43.9250 - val_RecoProb_metric: 36.5779 - val_KL_loss_metric: 7.3471
# Epoch 18/100
# 800000/800000 [==============================] - 32s 41us/step - loss: 44.0272 - RecoProb_metric: 36.3646 - KL_loss_metric: 7.6626 - val_loss: 43.8302 - val_RecoProb_metric: 36.1155 - val_KL_loss_metric: 7.7146
# Epoch 19/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 43.9141 - RecoProb_metric: 36.1289 - KL_loss_metric: 7.7852 - val_loss: 43.6317 - val_RecoProb_metric: 35.7314 - val_KL_loss_metric: 7.9004
# Epoch 20/100
# 800000/800000 [==============================] - 36s 45us/step - loss: 44.1000 - RecoProb_metric: 36.2597 - KL_loss_metric: 7.8403 - val_loss: 43.7730 - val_RecoProb_metric: 35.8984 - val_KL_loss_metric: 7.8747
# Epoch 21/100
# 800000/800000 [==============================] - 33s 42us/step - loss: 43.7710 - RecoProb_metric: 35.8106 - KL_loss_metric: 7.9605 - val_loss: 43.5763 - val_RecoProb_metric: 35.5686 - val_KL_loss_metric: 8.0077
# Epoch 22/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 43.6793 - RecoProb_metric: 35.6467 - KL_loss_metric: 8.0326 - val_loss: 43.5804 - val_RecoProb_metric: 35.7679 - val_KL_loss_metric: 7.8125
# Epoch 23/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 43.6103 - RecoProb_metric: 35.5274 - KL_loss_metric: 8.0829 - val_loss: 43.6691 - val_RecoProb_metric: 35.5354 - val_KL_loss_metric: 8.1337
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000475.
# Epoch 24/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 43.1122 - RecoProb_metric: 34.7584 - KL_loss_metric: 8.3538 - val_loss: 43.0574 - val_RecoProb_metric: 34.5739 - val_KL_loss_metric: 8.4835
# Epoch 25/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 43.0728 - RecoProb_metric: 34.5989 - KL_loss_metric: 8.4739 - val_loss: 43.0175 - val_RecoProb_metric: 34.5190 - val_KL_loss_metric: 8.4985
# Epoch 26/100
# 800000/800000 [==============================] - 33s 41us/step - loss: 43.0289 - RecoProb_metric: 34.4832 - KL_loss_metric: 8.5457 - val_loss: 43.0040 - val_RecoProb_metric: 34.4119 - val_KL_loss_metric: 8.5921
# Epoch 27/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 43.0029 - RecoProb_metric: 34.3866 - KL_loss_metric: 8.6163 - val_loss: 42.9536 - val_RecoProb_metric: 34.3060 - val_KL_loss_metric: 8.6476
# Epoch 28/100
# 800000/800000 [==============================] - 31s 39us/step - loss: 42.9736 - RecoProb_metric: 34.2975 - KL_loss_metric: 8.6761 - val_loss: 42.9444 - val_RecoProb_metric: 34.2646 - val_KL_loss_metric: 8.6799
# Epoch 29/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 42.9399 - RecoProb_metric: 34.2012 - KL_loss_metric: 8.7387 - val_loss: 42.9116 - val_RecoProb_metric: 34.1611 - val_KL_loss_metric: 8.7505
# Epoch 30/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 42.9104 - RecoProb_metric: 34.1201 - KL_loss_metric: 8.7903 - val_loss: 42.9143 - val_RecoProb_metric: 34.0179 - val_KL_loss_metric: 8.8964
# Epoch 31/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 42.8791 - RecoProb_metric: 34.0236 - KL_loss_metric: 8.8555 - val_loss: 42.9300 - val_RecoProb_metric: 34.0877 - val_KL_loss_metric: 8.8423
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000000475e-05.
# Epoch 32/100
# 800000/800000 [==============================] - 34s 42us/step - loss: 42.8045 - RecoProb_metric: 33.8987 - KL_loss_metric: 8.9058 - val_loss: 42.7882 - val_RecoProb_metric: 33.8554 - val_KL_loss_metric: 8.9328
# Epoch 33/100
# 800000/800000 [==============================] - 35s 43us/step - loss: 42.7835 - RecoProb_metric: 33.8341 - KL_loss_metric: 8.9494 - val_loss: 42.8693 - val_RecoProb_metric: 33.9006 - val_KL_loss_metric: 8.9687
# Epoch 34/100
# 800000/800000 [==============================] - 32s 39us/step - loss: 42.7677 - RecoProb_metric: 33.8092 - KL_loss_metric: 8.9585 - val_loss: 42.7588 - val_RecoProb_metric: 33.7840 - val_KL_loss_metric: 8.9748
# Epoch 35/100
# 800000/800000 [==============================] - 33s 42us/step - loss: 42.7663 - RecoProb_metric: 33.7870 - KL_loss_metric: 8.9793 - val_loss: 42.7948 - val_RecoProb_metric: 33.8126 - val_KL_loss_metric: 8.9823
# Epoch 36/100
# 800000/800000 [==============================] - 33s 41us/step - loss: 42.7625 - RecoProb_metric: 33.7685 - KL_loss_metric: 8.9940 - val_loss: 44.4480 - val_RecoProb_metric: 35.4482 - val_KL_loss_metric: 8.9998
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.00000006569e-06.
# Epoch 37/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 42.7556 - RecoProb_metric: 33.7604 - KL_loss_metric: 8.9952 - val_loss: 42.7270 - val_RecoProb_metric: 33.7251 - val_KL_loss_metric: 9.0019
# Epoch 38/100
# 800000/800000 [==============================] - 31s 39us/step - loss: 42.7478 - RecoProb_metric: 33.7477 - KL_loss_metric: 9.0002 - val_loss: 43.7523 - val_RecoProb_metric: 34.7456 - val_KL_loss_metric: 9.0067
# Epoch 39/100
# 800000/800000 [==============================] - 31s 38us/step - loss: 42.7456 - RecoProb_metric: 33.7448 - KL_loss_metric: 9.0009 - val_loss: 43.3661 - val_RecoProb_metric: 34.3634 - val_KL_loss_metric: 9.0027
# Epoch 40/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 42.7413 - RecoProb_metric: 33.7378 - KL_loss_metric: 9.0035 - val_loss: 42.7835 - val_RecoProb_metric: 33.7811 - val_KL_loss_metric: 9.0024
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.00000011116e-07.
# Epoch 41/100
# 800000/800000 [==============================] - 33s 42us/step - loss: 42.7448 - RecoProb_metric: 33.7430 - KL_loss_metric: 9.0017 - val_loss: 42.7909 - val_RecoProb_metric: 33.7857 - val_KL_loss_metric: 9.0052
# Epoch 42/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 42.7470 - RecoProb_metric: 33.7429 - KL_loss_metric: 9.0040 - val_loss: 42.7229 - val_RecoProb_metric: 33.7154 - val_KL_loss_metric: 9.0075
# Epoch 43/100
# 800000/800000 [==============================] - 31s 39us/step - loss: 42.7461 - RecoProb_metric: 33.7402 - KL_loss_metric: 9.0059 - val_loss: 42.8015 - val_RecoProb_metric: 33.7936 - val_KL_loss_metric: 9.0079
# Epoch 44/100
# 800000/800000 [==============================] - 32s 40us/step - loss: 42.7399 - RecoProb_metric: 33.7343 - KL_loss_metric: 9.0056 - val_loss: 42.7387 - val_RecoProb_metric: 33.7311 - val_KL_loss_metric: 9.0076
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.00000008274e-08.
# Epoch 45/100
# 800000/800000 [==============================] - 30s 37us/step - loss: 42.7489 - RecoProb_metric: 33.7431 - KL_loss_metric: 9.0058 - val_loss: 42.7899 - val_RecoProb_metric: 33.7821 - val_KL_loss_metric: 9.0078
# Epoch 00045: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.semilogy(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.semilogy(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
vae.save('last_saved_VAE.h5')

# %%
if 0:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model('last_saved_VAE.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save('last_saved_encoder.h5')
else:
    encoder = load_model('last_saved_encoder.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
data_folder = '../../data/'

BSM_samples = ['AtoChHW', 'AtoChHW_HIGHMASS', 'Ato4l', 'Zprime', 'Wprime', 'qcd', 'Wlnu']

x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], binning[1], binning[2])
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], binning[1], binning[2])
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('last_saved_autoencoder.h5')
else:
    autoencoder = load_model('last_saved_autoencoder.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 95.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[1:]))
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = (bincenters[10]-bincenters[9])*np.ones_like(bincenters)
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# MET
# allJetMass
# allMuPt
# allElePt
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# LepEta
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
def numpy_KL_loss(mu, sigma):
    kl_loss = - 0.5 * np.sum(1 + 2*np.log(sigma) - np.square(mu) - np.square(sigma), axis=-1)
    return kl_loss

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1) - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(single_NLL, axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# AtoChHW_HIGHMASS
# Ato4l
# Wlnu
# AtoChHW
# Wprime
# qcd
# Zprime

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]

    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-4))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    
    canvases.append(c)
