# %% [markdown]
# Like 5 but with more stat

# %%
VAEversion='7'

# %%
from glob import glob
import os, sys, scipy, pickle
from scipy.stats import chi2, poisson
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

from prettytable import PrettyTable

# %%
import ROOT as rt
import root_numpy as rtnp
from utility_func import *
# Out:
# Welcome to JupyROOT 6.10/08
# /Users/olmo/programs/root-6.10.08/lib/ROOT.py:318: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   return _orig_ihook( name, *args, **kwds )
# Using TensorFlow backend.

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN, ModelCheckpoint
from keras.constraints import max_norm
import keras
print keras.__version__
# Out:
# 2.1.2

# %%
do_training = 1

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'METp', 'METo', 'MT', 'nJets', 
                'bJets', 'allJetMass', 'LepPt', 'LepEta', 
                'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 
                'LepIsEle', 'nMu', 'allMuMass', 'allMuPt', 'nEle', 
                'allEleMass', 'allElePt', 'nChHad', 'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'allJetMass',
                       'allMuPt', 'allMuMass',
                       'allElePt','allEleMass',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'METp', 'METo',
                       
                       'MT',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad']

Nf_lognorm = 10
Nf_gauss = 2
Nf_Pgauss = 1
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 2

sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)
# print 'Activated HLF:'
# for n in np.array(hlf_features)[sel]:
#     print '\t', n

# %%
data_folder = '../../data/HLF_ONLY/'
TrainSamplesName = ['Wlnu', 'qcd', 'Zll', 'ttbar']
BSM_samples = ['Ato4l', 'Zprime', 'Wprime', 'leptoquark', 'hToTauTau', 'hChToTauNu']

N_train_max = int(9e6)
training_split_fraction = 0.5

# %%
fraction = np.array([0.592, 0.338, 0.067, 0.003])

raw_sample = {}
l = np.zeros(4)
for i,n in enumerate(TrainSamplesName):
    raw_sample[n] = np.load(data_folder+n+'_sample.npy')
#     np.random.shuffle(raw_sample[n])
    l[i] = raw_sample[n].shape[0]
    
i_min = np.argmin(l/fraction)
if TrainSamplesName[i_min]=='qcd':
    print 'QCD is limiting, using it for both val and split'
    N_train = min(N_train_max, l[i_min]/fraction[i_min])
else:
    N_train = min(N_train_max, training_split_fraction*l[i_min]/fraction[i_min])

if N_train < N_train_max:
    print 'Limiting stat. sample:', TrainSamplesName[i_min]
else:
    print 'Sample available satisfying '

N_val = N_train*(1-training_split_fraction)/training_split_fraction - 1
print 'Expected {:.2f}M train'.format(N_train/1.0e6)
print 'Expected {:.2f}M val'.format(N_val/1.0e6)
# Out:
# QCD is limiting, using it for both val and split
# Limiting stat. sample: qcd
# Expected 3.45M train
# Expected 3.45M val

# %%
x_train_s = {}
x_val_s = {}

table = PrettyTable(['Sample', 'Evts tot', 'Train', 'Val'])

for i,n in enumerate(TrainSamplesName):
    N_train_aux = int(N_train * fraction[i])
    x_train_s[n] = raw_sample[n][:N_train_aux, sel]
    N_val_aux = int(N_val * fraction[i])
    if TrainSamplesName[i_min]=='qcd' and n == 'qcd':
        print 'QCD is limiting, using it for both val and split'
        np.random.shuffle(raw_sample[n])
        x_val_s[n] = raw_sample[n][:N_val_aux, sel]
    elif N_train_aux+N_val_aux < raw_sample[n].shape[0]:
        x_val_s[n] = raw_sample[n][N_train_aux : N_train_aux+N_val_aux, sel]
    else:
        print 'Error', n
        continue
    table.add_row([n, raw_sample[n].shape[0], x_train_s[n].shape[0], x_val_s[n].shape[0]])
print table
    
x_train = np.concatenate((x_train_s['Wlnu'], x_train_s['qcd'], x_train_s['Zll'], x_train_s['ttbar']))
x_val = np.concatenate((x_val_s['Wlnu'], x_val_s['qcd'], x_val_s['Zll'], x_val_s['ttbar']))

print 'Tot training {:.2f} M'.format(x_train.shape[0]/1.0e6)
print 'Tot val {:.2f} M'.format(x_val.shape[0]/1.0e6)
# Out:
# QCD is limiting, using it for both val and split
# +--------+----------+---------+---------+
# | Sample | Evts tot |  Train  |   Val   |
# +--------+----------+---------+---------+
# |  Wlnu  | 8000082  | 2042566 | 2042565 |
# |  qcd   | 1166195  | 1166195 | 1166194 |
# |  Zll   | 1777383  |  231168 |  231168 |
# | ttbar  | 5001726  |  10350  |  10350  |
# +--------+----------+---------+---------+
# Tot training 3.45 M
# Tot val 3.45 M

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim = 50
kernel_max_norm = 1000.
act_fun = 'relu'
weight_KL_loss = 0.3

# %%
x_DNN_input = Input(shape=(original_dim,), name='Input')
hidden_1 = Dense(intermediate_dim, activation=act_fun, name='Encoder_h1')
aux = hidden_1(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun, kernel_constraint=max_norm(kernel_max_norm), name='Encoder_h2')
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)
aux = hidden_2(aux)

L_z_mean = Dense(latent_dim, name='Latent_mean')
T_z_mean = L_z_mean(aux)

L_z_sigma_preActivation = Dense(latent_dim, name='Latent_sigma_h')
aux = L_z_sigma_preActivation(aux)
L_z_sigma = Lambda(InverseSquareRootLinearUnit, name='Latent_sigma')
T_z_sigma = L_z_sigma(aux)

# %%
L_z_latent = Lambda(sampling, name='Latent_sampling')([T_z_mean, T_z_sigma])
decoder_h1 = Dense(intermediate_dim, 
                   activation=act_fun, 
                   kernel_constraint=max_norm(kernel_max_norm), 
                   name='Decoder_h1')(L_z_latent)

decoder_h2 = Dense(intermediate_dim, activation=act_fun, name='Decoder_h2')(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim, name='Output_par1')(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss, name='par2_h')(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit, name='Output_par2')(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm, name='par3_h')(decoder_h2)
L_par3 = Lambda(ClippedTanh, name='Output_par3')(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(1,
                 kernel_initializer='zeros', 
                 bias_initializer='ones', 
                 trainable=False, 
                 name='h1_prior'
                )(fixed_input)

L_prior_mean = Dense(latent_dim, 
                     kernel_initializer='zeros', 
                     bias_initializer='zeros', 
                     trainable=True, 
                     name='L_prior_mean'
                    )(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim, 
                                    kernel_initializer='zeros', 
                                    bias_initializer='ones', 
                                    trainable=True,
                                    name='L_prior_sigma_preAct'
                                   )(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit, name='L_prior_sigma')(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return 0.5 * K.sum(kl_loss, axis=-1)

# %%
def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return nll_loss

# %%
class CustomRecoProbLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomRecoProbLayer, self).__init__(**kwargs)

    def call(self, inputs):
        x, par1, par2, par3 = inputs    
        return RecoProb_forVAE(x, par1, par2, par3)
    
class CustomKLLossLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomKLLossLayer, self).__init__(**kwargs)

    def call(self, inputs):
        mu, sigma, mu_prior, sigma_prior = inputs
        return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)
    
def IdentityLoss(y_train, NETout):
    return K.mean(NETout)

# %%
L_RecoProb = CustomRecoProbLayer(name='RecoNLL')([x_DNN_input, L_par1, L_par2, L_par3])
L_KLLoss = CustomKLLossLayer(name='KL')([T_z_mean, T_z_sigma, L_prior_mean, L_prior_sigma])
vae = Model(inputs=x_DNN_input, outputs=[L_KLLoss, L_RecoProb])

vae.compile(optimizer='adam', 
            loss=[IdentityLoss, IdentityLoss], 
            loss_weights=[weight_KL_loss, 1.]
            )

print vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 21)           0
# __________________________________________________________________________________________________
# Encoder_h1 (Dense)              (None, 50)           1100        Input[0][0]
# __________________________________________________________________________________________________
# Encoder_h2 (Dense)              (None, 50)           2550        Encoder_h1[0][0]
# __________________________________________________________________________________________________
# Latent_sigma_h (Dense)          (None, 4)            204         Encoder_h2[0][0]
# __________________________________________________________________________________________________
# Latent_mean (Dense)             (None, 4)            204         Encoder_h2[0][0]
# __________________________________________________________________________________________________
# Latent_sigma (Lambda)           (None, 4)            0           Latent_sigma_h[0][0]
# __________________________________________________________________________________________________
# Latent_sampling (Lambda)        (None, 4)            0           Latent_mean[0][0]
#                                                                  Latent_sigma[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 21)           0           Input[0][0]
# __________________________________________________________________________________________________
# Decoder_h1 (Dense)              (None, 50)           250         Latent_sampling[0][0]
# __________________________________________________________________________________________________
# h1_prior (Dense)                (None, 1)            22          lambda_1[0][0]
# __________________________________________________________________________________________________
# Decoder_h2 (Dense)              (None, 50)           2550        Decoder_h1[0][0]
# __________________________________________________________________________________________________
# L_prior_sigma_preAct (Dense)    (None, 4)            8           h1_prior[0][0]
# __________________________________________________________________________________________________
# par2_h (Dense)                  (None, 17)           867         Decoder_h2[0][0]
# __________________________________________________________________________________________________
# par3_h (Dense)                  (None, 10)           510         Decoder_h2[0][0]
# __________________________________________________________________________________________________
# L_prior_mean (Dense)            (None, 4)            8           h1_prior[0][0]
# __________________________________________________________________________________________________
# L_prior_sigma (Lambda)          (None, 4)            0           L_prior_sigma_preAct[0][0]
# __________________________________________________________________________________________________
# Output_par1 (Dense)             (None, 21)           1071        Decoder_h2[0][0]
# __________________________________________________________________________________________________
# Output_par2 (Lambda)            (None, 17)           0           par2_h[0][0]
# __________________________________________________________________________________________________
# Output_par3 (Lambda)            (None, 10)           0           par3_h[0][0]
# __________________________________________________________________________________________________
# KL (CustomKLLossLayer)          [(None, 4), (None, 4 0           Latent_mean[0][0]
#                                                                  Latent_sigma[0][0]
#                                                                  L_prior_mean[0][0]
#                                                                  L_prior_sigma[0][0]
# __________________________________________________________________________________________________
# RecoNLL (CustomRecoProbLayer)   [(None, 21), (None,  0           Input[0][0]
#                                                                  Output_par1[0][0]
#                                                                  Output_par2[0][0]
#                                                                  Output_par3[0][0]
# ==================================================================================================
# Total params: 9,344
# Trainable params: 9,322
# Non-trainable params: 22
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
if do_training:
    existing_tmp = glob('partially_trained_models/VAE_all-in-one_v{}*.hdf5'.format(VAEversion))
    for f in existing_tmp:
        os.remove(f)
    
    fit_report = vae.fit(x=x_train, y=[x_train, x_train],
            validation_data = (x_val, [x_val, x_val]),
            shuffle=True,
            epochs=400,
            batch_size=1000,
            callbacks = [
                            EarlyStopping(monitor='val_loss', patience=20, verbose=1, min_delta=0.005),
                            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=8, epsilon=0.01, verbose=1),
                            TerminateOnNaN(),
                            ModelCheckpoint('partially_trained_models/VAE_all-in-one_v'+VAEversion+'_{epoch:02d}-{val_loss:.4f}.hdf5', 
                                            monitor='val_loss',
                                            mode='auto',
                                            period=1)
                ])
# Out:
# Train on 3450279 samples, validate on 3450277 samples
# Epoch 1/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 30333.5309 - KL_loss: 894.3387 - RecoNLL_loss: 30065.2292 - val_loss: 50.5906 - val_KL_loss: 34.5785 - val_RecoNLL_loss: 40.2170
# Epoch 2/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 43.6153 - KL_loss: 22.2795 - RecoNLL_loss: 36.9315 - val_loss: 38.3557 - val_KL_loss: 15.7647 - val_RecoNLL_loss: 33.6263
# Epoch 3/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 36.2959 - KL_loss: 14.2350 - RecoNLL_loss: 32.0254 - val_loss: 35.4451 - val_KL_loss: 13.0106 - val_RecoNLL_loss: 31.5419
# Epoch 4/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 31.9116 - KL_loss: 12.2181 - RecoNLL_loss: 28.2461 - val_loss: 29.4783 - val_KL_loss: 11.2958 - val_RecoNLL_loss: 26.0895
# Epoch 5/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 28.1135 - KL_loss: 9.9167 - RecoNLL_loss: 25.1385 - val_loss: 26.9248 - val_KL_loss: 8.1593 - val_RecoNLL_loss: 24.4770
# Epoch 6/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 26.4710 - KL_loss: 7.6970 - RecoNLL_loss: 24.1619 - val_loss: 25.4530 - val_KL_loss: 7.5801 - val_RecoNLL_loss: 23.1790
# Epoch 7/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 25.4286 - KL_loss: 7.4972 - RecoNLL_loss: 23.1794 - val_loss: 24.3981 - val_KL_loss: 7.4906 - val_RecoNLL_loss: 22.1509
# Epoch 8/400
# 3450279/3450279 [==============================] - 36s 10us/step - loss: 24.6052 - KL_loss: 7.5794 - RecoNLL_loss: 22.3314 - val_loss: 23.4409 - val_KL_loss: 7.6593 - val_RecoNLL_loss: 21.1431
# Epoch 9/400
# 3450279/3450279 [==============================] - 36s 10us/step - loss: 24.0310 - KL_loss: 7.8691 - RecoNLL_loss: 21.6703 - val_loss: 24.7452 - val_KL_loss: 8.4065 - val_RecoNLL_loss: 22.2233
# Epoch 10/400
# 3450279/3450279 [==============================] - 37s 11us/step - loss: 23.6112 - KL_loss: 7.9178 - RecoNLL_loss: 21.2358 - val_loss: 22.6207 - val_KL_loss: 7.8867 - val_RecoNLL_loss: 20.2547
# Epoch 11/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 23.0757 - KL_loss: 7.9060 - RecoNLL_loss: 20.7039 - val_loss: 21.9860 - val_KL_loss: 7.9558 - val_RecoNLL_loss: 19.5992
# Epoch 12/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 22.5711 - KL_loss: 7.9928 - RecoNLL_loss: 20.1733 - val_loss: 23.2644 - val_KL_loss: 7.9735 - val_RecoNLL_loss: 20.8723
# Epoch 13/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 22.2735 - KL_loss: 8.0482 - RecoNLL_loss: 19.8591 - val_loss: 21.5448 - val_KL_loss: 8.0388 - val_RecoNLL_loss: 19.1332
# Epoch 14/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 43.3440 - KL_loss: 11.7317 - RecoNLL_loss: 39.8245 - val_loss: 81.5253 - val_KL_loss: 19.7988 - val_RecoNLL_loss: 75.5857
# Epoch 15/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 30.3947 - KL_loss: 10.6506 - RecoNLL_loss: 27.1996 - val_loss: 25.6094 - val_KL_loss: 9.1035 - val_RecoNLL_loss: 22.8784
# Epoch 16/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 24.5830 - KL_loss: 8.5492 - RecoNLL_loss: 22.0182 - val_loss: 23.7670 - val_KL_loss: 8.2198 - val_RecoNLL_loss: 21.3011
# Epoch 17/400
# 3450279/3450279 [==============================] - 48s 14us/step - loss: 23.5362 - KL_loss: 8.0470 - RecoNLL_loss: 21.1221 - val_loss: 22.4001 - val_KL_loss: 7.9578 - val_RecoNLL_loss: 20.0128
# Epoch 18/400
# 3450279/3450279 [==============================] - 45s 13us/step - loss: 22.6669 - KL_loss: 7.9086 - RecoNLL_loss: 20.2943 - val_loss: 21.3239 - val_KL_loss: 7.8119 - val_RecoNLL_loss: 18.9804
# Epoch 19/400
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 27.7962 - KL_loss: 9.9715 - RecoNLL_loss: 24.8047 - val_loss: 326.7088 - val_KL_loss: 9.7021 - val_RecoNLL_loss: 323.7982
# Epoch 20/400
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 29.5884 - KL_loss: 9.7441 - RecoNLL_loss: 26.6651 - val_loss: 25.5102 - val_KL_loss: 7.8380 - val_RecoNLL_loss: 23.1588
# Epoch 21/400
# 3450279/3450279 [==============================] - 45s 13us/step - loss: 23.5429 - KL_loss: 7.9150 - RecoNLL_loss: 21.1684 - val_loss: 22.8794 - val_KL_loss: 8.0115 - val_RecoNLL_loss: 20.4759
# Epoch 22/400
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 22.7447 - KL_loss: 7.8414 - RecoNLL_loss: 20.3923 - val_loss: 21.5984 - val_KL_loss: 7.8492 - val_RecoNLL_loss: 19.2436
# Epoch 23/400
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 22.3313 - KL_loss: 7.9441 - RecoNLL_loss: 19.9480 - val_loss: 21.2413 - val_KL_loss: 7.7559 - val_RecoNLL_loss: 18.9145
# Epoch 24/400
# 3450279/3450279 [==============================] - 45s 13us/step - loss: 21.7325 - KL_loss: 8.0151 - RecoNLL_loss: 19.3280 - val_loss: 21.9308 - val_KL_loss: 8.0623 - val_RecoNLL_loss: 19.5121
# Epoch 25/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 21.3075 - KL_loss: 8.1379 - RecoNLL_loss: 18.8662 - val_loss: 23.9579 - val_KL_loss: 8.0827 - val_RecoNLL_loss: 21.5331
# Epoch 26/400
# 3450279/3450279 [==============================] - 43s 12us/step - loss: 20.8331 - KL_loss: 8.1949 - RecoNLL_loss: 18.3746 - val_loss: 20.9975 - val_KL_loss: 8.2510 - val_RecoNLL_loss: 18.5222
# Epoch 27/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 20.5110 - KL_loss: 8.2813 - RecoNLL_loss: 18.0266 - val_loss: 28.2080 - val_KL_loss: 8.3145 - val_RecoNLL_loss: 25.7136
# Epoch 28/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 25.5829 - KL_loss: 9.9048 - RecoNLL_loss: 22.6114 - val_loss: 33.4512 - val_KL_loss: 13.1733 - val_RecoNLL_loss: 29.4992
# Epoch 29/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 26.8681 - KL_loss: 10.2958 - RecoNLL_loss: 23.7794 - val_loss: 24.5405 - val_KL_loss: 8.8314 - val_RecoNLL_loss: 21.8911
# Epoch 30/400
# 3450279/3450279 [==============================] - 43s 12us/step - loss: 24.1942 - KL_loss: 8.1877 - RecoNLL_loss: 21.7379 - val_loss: 24.4580 - val_KL_loss: 7.5163 - val_RecoNLL_loss: 22.2031
# Epoch 31/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 23.3576 - KL_loss: 7.7455 - RecoNLL_loss: 21.0339 - val_loss: 22.6905 - val_KL_loss: 7.7501 - val_RecoNLL_loss: 20.3655
# Epoch 32/400
# 3450279/3450279 [==============================] - 43s 12us/step - loss: 22.6239 - KL_loss: 7.7993 - RecoNLL_loss: 20.2841 - val_loss: 22.1166 - val_KL_loss: 7.6540 - val_RecoNLL_loss: 19.8204
# Epoch 33/400
# 3450279/3450279 [==============================] - 44s 13us/step - loss: 22.1550 - KL_loss: 7.8807 - RecoNLL_loss: 19.7908 - val_loss: 22.7919 - val_KL_loss: 7.8441 - val_RecoNLL_loss: 20.4386
# Epoch 34/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 23.3902 - KL_loss: 8.1971 - RecoNLL_loss: 20.9311 - val_loss: 27.6498 - val_KL_loss: 8.3723 - val_RecoNLL_loss: 25.1381
# Epoch 35/400
# 3449000/3450279 [============================>.] - ETA: 0s - loss: 23.9419 - KL_loss: 7.8079 - RecoNLL_loss: 21.5995
# Epoch 00035: reducing learning rate to 0.00010000000475.
# 3450279/3450279 [==============================] - 43s 12us/step - loss: 23.9413 - KL_loss: 7.8079 - RecoNLL_loss: 21.5989 - val_loss: 22.6341 - val_KL_loss: 7.8220 - val_RecoNLL_loss: 20.2875
# Epoch 36/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 22.1060 - KL_loss: 8.0588 - RecoNLL_loss: 19.6883 - val_loss: 22.4491 - val_KL_loss: 8.2547 - val_RecoNLL_loss: 19.9727
# Epoch 37/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 21.6413 - KL_loss: 8.4048 - RecoNLL_loss: 19.1198 - val_loss: 21.4306 - val_KL_loss: 8.5459 - val_RecoNLL_loss: 18.8668
# Epoch 38/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 21.2468 - KL_loss: 8.5884 - RecoNLL_loss: 18.6703 - val_loss: 21.0953 - val_KL_loss: 8.6508 - val_RecoNLL_loss: 18.5001
# Epoch 39/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 20.9964 - KL_loss: 8.6863 - RecoNLL_loss: 18.3905 - val_loss: 20.8866 - val_KL_loss: 8.7167 - val_RecoNLL_loss: 18.2715
# Epoch 40/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 20.8033 - KL_loss: 8.7623 - RecoNLL_loss: 18.1746 - val_loss: 20.9534 - val_KL_loss: 8.8432 - val_RecoNLL_loss: 18.3004
# Epoch 41/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 20.6275 - KL_loss: 8.8333 - RecoNLL_loss: 17.9775 - val_loss: 20.5044 - val_KL_loss: 8.8768 - val_RecoNLL_loss: 17.8414
# Epoch 42/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 20.4476 - KL_loss: 8.9110 - RecoNLL_loss: 17.7743 - val_loss: 20.7208 - val_KL_loss: 8.9888 - val_RecoNLL_loss: 18.0241
# Epoch 43/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 20.3155 - KL_loss: 8.9748 - RecoNLL_loss: 17.6231 - val_loss: 20.2740 - val_KL_loss: 9.0091 - val_RecoNLL_loss: 17.5713
# Epoch 44/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 20.2051 - KL_loss: 9.0162 - RecoNLL_loss: 17.5003 - val_loss: 20.2741 - val_KL_loss: 9.0909 - val_RecoNLL_loss: 17.5469
# Epoch 45/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 20.1146 - KL_loss: 9.0523 - RecoNLL_loss: 17.3989 - val_loss: 20.1509 - val_KL_loss: 9.0431 - val_RecoNLL_loss: 17.4379
# Epoch 46/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 20.0489 - KL_loss: 9.0872 - RecoNLL_loss: 17.3227 - val_loss: 20.2445 - val_KL_loss: 9.1232 - val_RecoNLL_loss: 17.5076
# Epoch 47/400
# 3450279/3450279 [==============================] - 47s 14us/step - loss: 19.9706 - KL_loss: 9.1048 - RecoNLL_loss: 17.2392 - val_loss: 20.0086 - val_KL_loss: 9.1024 - val_RecoNLL_loss: 17.2779
# Epoch 48/400
# 3450279/3450279 [==============================] - 45s 13us/step - loss: 19.9070 - KL_loss: 9.1140 - RecoNLL_loss: 17.1727 - val_loss: 20.3666 - val_KL_loss: 9.1268 - val_RecoNLL_loss: 17.6285
# Epoch 49/400
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 66.2984 - KL_loss: 9.2093 - RecoNLL_loss: 63.5357 - val_loss: 21.3088 - val_KL_loss: 9.2281 - val_RecoNLL_loss: 18.5404
# Epoch 50/400
# 3450279/3450279 [==============================] - 47s 14us/step - loss: 20.5923 - KL_loss: 9.2526 - RecoNLL_loss: 17.8165 - val_loss: 20.4206 - val_KL_loss: 9.2568 - val_RecoNLL_loss: 17.6436
# Epoch 51/400
# 3450279/3450279 [==============================] - 47s 14us/step - loss: 20.2138 - KL_loss: 9.2405 - RecoNLL_loss: 17.4417 - val_loss: 20.1293 - val_KL_loss: 9.2326 - val_RecoNLL_loss: 17.3595
# Epoch 52/400
# 3450279/3450279 [==============================] - 47s 13us/step - loss: 20.0767 - KL_loss: 9.2353 - RecoNLL_loss: 17.3061 - val_loss: 20.1577 - val_KL_loss: 9.2510 - val_RecoNLL_loss: 17.3825
# Epoch 53/400
# 3450279/3450279 [==============================] - 47s 14us/step - loss: 19.9705 - KL_loss: 9.2353 - RecoNLL_loss: 17.1999 - val_loss: 20.5263 - val_KL_loss: 9.2152 - val_RecoNLL_loss: 17.7618
# Epoch 54/400
# 3450279/3450279 [==============================] - 47s 14us/step - loss: 19.8755 - KL_loss: 9.1955 - RecoNLL_loss: 17.1169 - val_loss: 20.3440 - val_KL_loss: 9.1833 - val_RecoNLL_loss: 17.5890
# Epoch 55/400
# 3450279/3450279 [==============================] - 48s 14us/step - loss: 27.3947 - KL_loss: 9.2299 - RecoNLL_loss: 24.6257 - val_loss: 20.7109 - val_KL_loss: 9.3023 - val_RecoNLL_loss: 17.9202
# Epoch 56/400
# 3447000/3450279 [============================>.] - ETA: 0s - loss: 20.2346 - KL_loss: 9.2357 - RecoNLL_loss: 17.4639
# Epoch 00056: reducing learning rate to 1.0000000475e-05.
# 3450279/3450279 [==============================] - 46s 13us/step - loss: 20.2344 - KL_loss: 9.2356 - RecoNLL_loss: 17.4637 - val_loss: 20.0872 - val_KL_loss: 9.2197 - val_RecoNLL_loss: 17.3213
# Epoch 57/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 19.9840 - KL_loss: 9.2082 - RecoNLL_loss: 17.2215 - val_loss: 19.9842 - val_KL_loss: 9.2068 - val_RecoNLL_loss: 17.2221
# Epoch 58/400
# 3450279/3450279 [==============================] - 48s 14us/step - loss: 19.9425 - KL_loss: 9.2023 - RecoNLL_loss: 17.1819 - val_loss: 19.9337 - val_KL_loss: 9.2122 - val_RecoNLL_loss: 17.1700
# Epoch 59/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 19.8839 - KL_loss: 9.1993 - RecoNLL_loss: 17.1242 - val_loss: 19.8641 - val_KL_loss: 9.2184 - val_RecoNLL_loss: 17.0986
# Epoch 60/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 19.8101 - KL_loss: 9.1959 - RecoNLL_loss: 17.0514 - val_loss: 19.7956 - val_KL_loss: 9.1915 - val_RecoNLL_loss: 17.0381
# Epoch 61/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 19.7851 - KL_loss: 9.1755 - RecoNLL_loss: 17.0324 - val_loss: 19.7578 - val_KL_loss: 9.1819 - val_RecoNLL_loss: 17.0032
# Epoch 62/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 21.9018 - KL_loss: 9.1774 - RecoNLL_loss: 19.1486 - val_loss: 19.8170 - val_KL_loss: 9.1720 - val_RecoNLL_loss: 17.0654
# Epoch 63/400
# 3450279/3450279 [==============================] - 43s 13us/step - loss: 19.7731 - KL_loss: 9.1646 - RecoNLL_loss: 17.0238 - val_loss: 19.7862 - val_KL_loss: 9.1677 - val_RecoNLL_loss: 17.0358
# Epoch 64/400
# 3450279/3450279 [==============================] - 39s 11us/step - loss: 19.7397 - KL_loss: 9.1661 - RecoNLL_loss: 16.9898 - val_loss: 19.7460 - val_KL_loss: 9.1828 - val_RecoNLL_loss: 16.9912
# Epoch 65/400
# 3450279/3450279 [==============================] - 44s 13us/step - loss: 19.7138 - KL_loss: 9.1778 - RecoNLL_loss: 16.9604 - val_loss: 19.7369 - val_KL_loss: 9.1957 - val_RecoNLL_loss: 16.9782
# Epoch 66/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 19.6867 - KL_loss: 9.1885 - RecoNLL_loss: 16.9302 - val_loss: 19.6945 - val_KL_loss: 9.2010 - val_RecoNLL_loss: 16.9342
# Epoch 67/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 19.6612 - KL_loss: 9.1985 - RecoNLL_loss: 16.9017 - val_loss: 19.6814 - val_KL_loss: 9.1946 - val_RecoNLL_loss: 16.9230
# Epoch 68/400
# 3450279/3450279 [==============================] - 37s 11us/step - loss: 19.6342 - KL_loss: 9.1813 - RecoNLL_loss: 16.8798 - val_loss: 19.6624 - val_KL_loss: 9.1988 - val_RecoNLL_loss: 16.9028
# Epoch 69/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 19.6138 - KL_loss: 9.1890 - RecoNLL_loss: 16.8571 - val_loss: 19.6257 - val_KL_loss: 9.1981 - val_RecoNLL_loss: 16.8662
# Epoch 70/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 19.6025 - KL_loss: 9.1926 - RecoNLL_loss: 16.8447 - val_loss: 19.6351 - val_KL_loss: 9.1998 - val_RecoNLL_loss: 16.8752
# Epoch 71/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 19.5878 - KL_loss: 9.1995 - RecoNLL_loss: 16.8280 - val_loss: 19.6084 - val_KL_loss: 9.2004 - val_RecoNLL_loss: 16.8483
# Epoch 72/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 19.5674 - KL_loss: 9.1905 - RecoNLL_loss: 16.8102 - val_loss: 19.5902 - val_KL_loss: 9.1830 - val_RecoNLL_loss: 16.8353
# Epoch 73/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 19.5543 - KL_loss: 9.1837 - RecoNLL_loss: 16.7992 - val_loss: 19.6432 - val_KL_loss: 9.1908 - val_RecoNLL_loss: 16.8859
# Epoch 74/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 19.5418 - KL_loss: 9.1806 - RecoNLL_loss: 16.7877 - val_loss: 19.5622 - val_KL_loss: 9.1983 - val_RecoNLL_loss: 16.8027
# Epoch 75/400
# 3450279/3450279 [==============================] - 42s 12us/step - loss: 25.8819 - KL_loss: 9.1886 - RecoNLL_loss: 23.1253 - val_loss: 19.6874 - val_KL_loss: 9.1859 - val_RecoNLL_loss: 16.9317
# Epoch 76/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 19.5787 - KL_loss: 9.1628 - RecoNLL_loss: 16.8298 - val_loss: 19.5768 - val_KL_loss: 9.1720 - val_RecoNLL_loss: 16.8252
# Epoch 77/400
# 3450279/3450279 [==============================] - 41s 12us/step - loss: 19.5336 - KL_loss: 9.1744 - RecoNLL_loss: 16.7813 - val_loss: 19.5471 - val_KL_loss: 9.1795 - val_RecoNLL_loss: 16.7933
# Epoch 78/400
# 3450279/3450279 [==============================] - 38s 11us/step - loss: 19.5157 - KL_loss: 9.1835 - RecoNLL_loss: 16.7606 - val_loss: 19.5488 - val_KL_loss: 9.1878 - val_RecoNLL_loss: 16.7924
# Epoch 79/400
# 3450279/3450279 [==============================] - 39s 11us/step - loss: 19.6460 - KL_loss: 9.1812 - RecoNLL_loss: 16.8917 - val_loss: 19.6096 - val_KL_loss: 9.1745 - val_RecoNLL_loss: 16.8572
# Epoch 80/400
# 3450279/3450279 [==============================] - 39s 11us/step - loss: 19.5145 - KL_loss: 9.1785 - RecoNLL_loss: 16.7609 - val_loss: 19.5238 - val_KL_loss: 9.1923 - val_RecoNLL_loss: 16.7661
# Epoch 81/400
# 3450279/3450279 [==============================] - 40s 12us/step - loss: 19.4886 - KL_loss: 9.1878 - RecoNLL_loss: 16.7322 - val_loss: 19.5122 - val_KL_loss: 9.1928 - val_RecoNLL_loss: 16.7544
# Epoch 82/400
# 3450279/3450279 [==============================] - 37s 11us/step - loss: 23.2676 - KL_loss: 9.1829 - RecoNLL_loss: 20.5127 - val_loss: 19.5722 - val_KL_loss: 9.1731 - val_RecoNLL_loss: 16.8202
# Epoch 83/400
# 3450279/3450279 [==============================] - 37s 11us/step - loss: 19.5112 - KL_loss: 9.1691 - RecoNLL_loss: 16.7605 - val_loss: 19.5181 - val_KL_loss: 9.1845 - val_RecoNLL_loss: 16.7627
# Epoch 84/400
# 3450279/3450279 [==============================] - 39s 11us/step - loss: 19.4837 - KL_loss: 9.1804 - RecoNLL_loss: 16.7296 - val_loss: 19.5031 - val_KL_loss: 9.1817 - val_RecoNLL_loss: 16.7486
# Epoch 85/400
# 3450279/3450279 [==============================] - 44s 13us/step - loss: 19.4678 - KL_loss: 9.1847 - RecoNLL_loss: 16.7124 - val_loss: 19.4917 - val_KL_loss: 9.1903 - val_RecoNLL_loss: 16.7346
# Epoch 86/400
# 3450279/3450279 [==============================] - 38s 11us/step - loss: 19.4569 - KL_loss: 9.1915 - RecoNLL_loss: 16.6994 - val_loss: 19.4812 - val_KL_loss: 9.1916 - val_RecoNLL_loss: 16.7237
# Epoch 87/400
# 3450279/3450279 [==============================] - 36s 10us/step - loss: 19.4443 - KL_loss: 9.1871 - RecoNLL_loss: 16.6882 - val_loss: 19.4620 - val_KL_loss: 9.2080 - val_RecoNLL_loss: 16.6996
# Epoch 88/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.4359 - KL_loss: 9.1975 - RecoNLL_loss: 16.6767 - val_loss: 19.4488 - val_KL_loss: 9.1977 - val_RecoNLL_loss: 16.6894
# Epoch 89/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.4197 - KL_loss: 9.1909 - RecoNLL_loss: 16.6624 - val_loss: 19.4491 - val_KL_loss: 9.2022 - val_RecoNLL_loss: 16.6884
# Epoch 90/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.4127 - KL_loss: 9.1916 - RecoNLL_loss: 16.6552 - val_loss: 19.4391 - val_KL_loss: 9.2002 - val_RecoNLL_loss: 16.6791
# Epoch 91/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3973 - KL_loss: 9.1845 - RecoNLL_loss: 16.6419 - val_loss: 19.4332 - val_KL_loss: 9.1881 - val_RecoNLL_loss: 16.6768
# Epoch 92/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3871 - KL_loss: 9.1809 - RecoNLL_loss: 16.6328 - val_loss: 19.4282 - val_KL_loss: 9.1982 - val_RecoNLL_loss: 16.6687
# Epoch 93/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3762 - KL_loss: 9.1826 - RecoNLL_loss: 16.6214 - val_loss: 21.3973 - val_KL_loss: 9.1907 - val_RecoNLL_loss: 18.6401
# Epoch 94/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.4664 - KL_loss: 9.1676 - RecoNLL_loss: 16.7161 - val_loss: 19.4189 - val_KL_loss: 9.1476 - val_RecoNLL_loss: 16.6746
# Epoch 95/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.3653 - KL_loss: 9.1623 - RecoNLL_loss: 16.6166 - val_loss: 19.3944 - val_KL_loss: 9.1789 - val_RecoNLL_loss: 16.6407
# Epoch 96/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3529 - KL_loss: 9.1855 - RecoNLL_loss: 16.5973 - val_loss: 19.3842 - val_KL_loss: 9.1956 - val_RecoNLL_loss: 16.6255
# Epoch 97/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3456 - KL_loss: 9.1899 - RecoNLL_loss: 16.5886 - val_loss: 19.5865 - val_KL_loss: 9.2003 - val_RecoNLL_loss: 16.8264
# Epoch 98/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3368 - KL_loss: 9.1828 - RecoNLL_loss: 16.5820 - val_loss: 30.7776 - val_KL_loss: 9.1817 - val_RecoNLL_loss: 28.0231
# Epoch 99/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3272 - KL_loss: 9.1803 - RecoNLL_loss: 16.5731 - val_loss: 19.3531 - val_KL_loss: 9.1900 - val_RecoNLL_loss: 16.5961
# Epoch 100/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.3212 - KL_loss: 9.1836 - RecoNLL_loss: 16.5661 - val_loss: 19.3614 - val_KL_loss: 9.2073 - val_RecoNLL_loss: 16.5992
# Epoch 101/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.3099 - KL_loss: 9.1835 - RecoNLL_loss: 16.5548 - val_loss: 19.3727 - val_KL_loss: 9.1825 - val_RecoNLL_loss: 16.6180
# Epoch 102/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.3013 - KL_loss: 9.1792 - RecoNLL_loss: 16.5475 - val_loss: 26.8197 - val_KL_loss: 9.1804 - val_RecoNLL_loss: 24.0656
# Epoch 103/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.3015 - KL_loss: 9.1853 - RecoNLL_loss: 16.5459 - val_loss: 19.3548 - val_KL_loss: 9.2083 - val_RecoNLL_loss: 16.5923
# Epoch 104/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.3386 - KL_loss: 9.1975 - RecoNLL_loss: 16.5794 - val_loss: 20.9685 - val_KL_loss: 9.2024 - val_RecoNLL_loss: 18.2078
# Epoch 105/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.2831 - KL_loss: 9.1972 - RecoNLL_loss: 16.5240 - val_loss: 19.3227 - val_KL_loss: 9.1944 - val_RecoNLL_loss: 16.5644
# Epoch 106/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2747 - KL_loss: 9.1886 - RecoNLL_loss: 16.5181 - val_loss: 19.3091 - val_KL_loss: 9.1812 - val_RecoNLL_loss: 16.5548
# Epoch 107/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2695 - KL_loss: 9.1789 - RecoNLL_loss: 16.5158 - val_loss: 19.3046 - val_KL_loss: 9.2023 - val_RecoNLL_loss: 16.5439
# Epoch 108/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2618 - KL_loss: 9.1800 - RecoNLL_loss: 16.5078 - val_loss: 19.3242 - val_KL_loss: 9.1966 - val_RecoNLL_loss: 16.5652
# Epoch 109/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2743 - KL_loss: 9.1769 - RecoNLL_loss: 16.5212 - val_loss: 19.3290 - val_KL_loss: 9.1910 - val_RecoNLL_loss: 16.5717
# Epoch 110/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.2501 - KL_loss: 9.1948 - RecoNLL_loss: 16.4916 - val_loss: 19.2993 - val_KL_loss: 9.2009 - val_RecoNLL_loss: 16.5390
# Epoch 111/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2426 - KL_loss: 9.1902 - RecoNLL_loss: 16.4856 - val_loss: 19.2877 - val_KL_loss: 9.1836 - val_RecoNLL_loss: 16.5326
# Epoch 112/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2379 - KL_loss: 9.1790 - RecoNLL_loss: 16.4842 - val_loss: 19.2779 - val_KL_loss: 9.1855 - val_RecoNLL_loss: 16.5222
# Epoch 113/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2298 - KL_loss: 9.1743 - RecoNLL_loss: 16.4775 - val_loss: 19.2589 - val_KL_loss: 9.1711 - val_RecoNLL_loss: 16.5075
# Epoch 114/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2227 - KL_loss: 9.1759 - RecoNLL_loss: 16.4699 - val_loss: 19.2567 - val_KL_loss: 9.1761 - val_RecoNLL_loss: 16.5039
# Epoch 115/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2167 - KL_loss: 9.1768 - RecoNLL_loss: 16.4637 - val_loss: 19.2576 - val_KL_loss: 9.1800 - val_RecoNLL_loss: 16.5036
# Epoch 116/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2075 - KL_loss: 9.1743 - RecoNLL_loss: 16.4552 - val_loss: 19.2776 - val_KL_loss: 9.1764 - val_RecoNLL_loss: 16.5246
# Epoch 117/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2020 - KL_loss: 9.1726 - RecoNLL_loss: 16.4503 - val_loss: 19.2822 - val_KL_loss: 9.1796 - val_RecoNLL_loss: 16.5284
# Epoch 118/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.2067 - KL_loss: 9.1715 - RecoNLL_loss: 16.4552 - val_loss: 19.2313 - val_KL_loss: 9.1775 - val_RecoNLL_loss: 16.4780
# Epoch 119/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.1904 - KL_loss: 9.1733 - RecoNLL_loss: 16.4385 - val_loss: 19.2389 - val_KL_loss: 9.1828 - val_RecoNLL_loss: 16.4840
# Epoch 120/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.1869 - KL_loss: 9.1731 - RecoNLL_loss: 16.4349 - val_loss: 19.2224 - val_KL_loss: 9.1736 - val_RecoNLL_loss: 16.4703
# Epoch 121/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1790 - KL_loss: 9.1691 - RecoNLL_loss: 16.4282 - val_loss: 19.3367 - val_KL_loss: 9.1756 - val_RecoNLL_loss: 16.5840
# Epoch 122/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.1748 - KL_loss: 9.1694 - RecoNLL_loss: 16.4240 - val_loss: 19.2492 - val_KL_loss: 9.1813 - val_RecoNLL_loss: 16.4948
# Epoch 123/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.2423 - KL_loss: 9.1832 - RecoNLL_loss: 16.4874 - val_loss: 19.2118 - val_KL_loss: 9.1903 - val_RecoNLL_loss: 16.4547
# Epoch 124/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.1659 - KL_loss: 9.1843 - RecoNLL_loss: 16.4106 - val_loss: 19.2212 - val_KL_loss: 9.1930 - val_RecoNLL_loss: 16.4633
# Epoch 125/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1603 - KL_loss: 9.1824 - RecoNLL_loss: 16.4056 - val_loss: 19.2151 - val_KL_loss: 9.1881 - val_RecoNLL_loss: 16.4586
# Epoch 126/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.1599 - KL_loss: 9.1752 - RecoNLL_loss: 16.4073 - val_loss: 19.1989 - val_KL_loss: 9.1814 - val_RecoNLL_loss: 16.4445
# Epoch 127/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1538 - KL_loss: 9.1737 - RecoNLL_loss: 16.4017 - val_loss: 19.1824 - val_KL_loss: 9.1801 - val_RecoNLL_loss: 16.4283
# Epoch 128/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1456 - KL_loss: 9.1717 - RecoNLL_loss: 16.3941 - val_loss: 19.1912 - val_KL_loss: 9.1853 - val_RecoNLL_loss: 16.4356
# Epoch 129/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1406 - KL_loss: 9.1724 - RecoNLL_loss: 16.3889 - val_loss: 19.2373 - val_KL_loss: 9.1850 - val_RecoNLL_loss: 16.4817
# Epoch 130/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.1381 - KL_loss: 9.1775 - RecoNLL_loss: 16.3848 - val_loss: 19.2426 - val_KL_loss: 9.1689 - val_RecoNLL_loss: 16.4920
# Epoch 131/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1321 - KL_loss: 9.1775 - RecoNLL_loss: 16.3788 - val_loss: 19.2280 - val_KL_loss: 9.1941 - val_RecoNLL_loss: 16.4697
# Epoch 132/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.1326 - KL_loss: 9.1760 - RecoNLL_loss: 16.3798 - val_loss: 19.2160 - val_KL_loss: 9.1786 - val_RecoNLL_loss: 16.4624
# Epoch 133/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1264 - KL_loss: 9.1762 - RecoNLL_loss: 16.3735 - val_loss: 19.1562 - val_KL_loss: 9.1869 - val_RecoNLL_loss: 16.4001
# Epoch 134/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1182 - KL_loss: 9.1860 - RecoNLL_loss: 16.3624 - val_loss: 19.1818 - val_KL_loss: 9.1996 - val_RecoNLL_loss: 16.4219
# Epoch 135/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 19.1161 - KL_loss: 9.1876 - RecoNLL_loss: 16.3598 - val_loss: 19.1958 - val_KL_loss: 9.1876 - val_RecoNLL_loss: 16.4395
# Epoch 136/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.1032 - KL_loss: 9.1832 - RecoNLL_loss: 16.3482 - val_loss: 19.2128 - val_KL_loss: 9.1992 - val_RecoNLL_loss: 16.4530
# Epoch 137/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0998 - KL_loss: 9.1905 - RecoNLL_loss: 16.3426 - val_loss: 19.1895 - val_KL_loss: 9.2014 - val_RecoNLL_loss: 16.4290
# Epoch 138/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.1254 - KL_loss: 9.1829 - RecoNLL_loss: 16.3705 - val_loss: 19.1645 - val_KL_loss: 9.1836 - val_RecoNLL_loss: 16.4094
# Epoch 139/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.2654 - KL_loss: 9.1869 - RecoNLL_loss: 16.5093 - val_loss: 19.1627 - val_KL_loss: 9.2009 - val_RecoNLL_loss: 16.4025
# Epoch 140/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0984 - KL_loss: 9.2054 - RecoNLL_loss: 16.3368 - val_loss: 19.1506 - val_KL_loss: 9.2048 - val_RecoNLL_loss: 16.3891
# Epoch 141/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0848 - KL_loss: 9.2034 - RecoNLL_loss: 16.3238 - val_loss: 19.1805 - val_KL_loss: 9.2181 - val_RecoNLL_loss: 16.4150
# Epoch 142/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0899 - KL_loss: 9.2090 - RecoNLL_loss: 16.3272 - val_loss: 19.1324 - val_KL_loss: 9.2128 - val_RecoNLL_loss: 16.3686
# Epoch 143/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0790 - KL_loss: 9.1991 - RecoNLL_loss: 16.3192 - val_loss: 19.1473 - val_KL_loss: 9.2143 - val_RecoNLL_loss: 16.3830
# Epoch 144/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0831 - KL_loss: 9.2099 - RecoNLL_loss: 16.3201 - val_loss: 19.1128 - val_KL_loss: 9.2026 - val_RecoNLL_loss: 16.3520
# Epoch 145/400
# 3450279/3450279 [==============================] - 36s 10us/step - loss: 19.0756 - KL_loss: 9.1982 - RecoNLL_loss: 16.3161 - val_loss: 19.1167 - val_KL_loss: 9.2007 - val_RecoNLL_loss: 16.3565
# Epoch 146/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0669 - KL_loss: 9.1994 - RecoNLL_loss: 16.3071 - val_loss: 19.1531 - val_KL_loss: 9.2119 - val_RecoNLL_loss: 16.3895
# Epoch 147/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0658 - KL_loss: 9.2026 - RecoNLL_loss: 16.3050 - val_loss: 19.1455 - val_KL_loss: 9.2177 - val_RecoNLL_loss: 16.3802
# Epoch 148/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0653 - KL_loss: 9.2053 - RecoNLL_loss: 16.3037 - val_loss: 19.1604 - val_KL_loss: 9.2120 - val_RecoNLL_loss: 16.3968
# Epoch 149/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.0542 - KL_loss: 9.2104 - RecoNLL_loss: 16.2911 - val_loss: 19.1930 - val_KL_loss: 9.2176 - val_RecoNLL_loss: 16.4277
# Epoch 150/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0499 - KL_loss: 9.2148 - RecoNLL_loss: 16.2854 - val_loss: 19.1686 - val_KL_loss: 9.2106 - val_RecoNLL_loss: 16.4055
# Epoch 151/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0458 - KL_loss: 9.2165 - RecoNLL_loss: 16.2808 - val_loss: 19.1513 - val_KL_loss: 9.2292 - val_RecoNLL_loss: 16.3825
# Epoch 152/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 19.5091 - KL_loss: 9.2122 - RecoNLL_loss: 16.7455 - val_loss: 19.1258 - val_KL_loss: 9.2154 - val_RecoNLL_loss: 16.3612
# Epoch 153/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0542 - KL_loss: 9.2275 - RecoNLL_loss: 16.2860 - val_loss: 19.0895 - val_KL_loss: 9.2425 - val_RecoNLL_loss: 16.3167
# Epoch 154/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0433 - KL_loss: 9.2359 - RecoNLL_loss: 16.2725 - val_loss: 19.0653 - val_KL_loss: 9.2279 - val_RecoNLL_loss: 16.2969
# Epoch 155/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0360 - KL_loss: 9.2288 - RecoNLL_loss: 16.2674 - val_loss: 19.0997 - val_KL_loss: 9.2381 - val_RecoNLL_loss: 16.3282
# Epoch 156/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0346 - KL_loss: 9.2322 - RecoNLL_loss: 16.2649 - val_loss: 19.0705 - val_KL_loss: 9.2362 - val_RecoNLL_loss: 16.2997
# Epoch 157/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0315 - KL_loss: 9.2317 - RecoNLL_loss: 16.2620 - val_loss: 19.0610 - val_KL_loss: 9.2236 - val_RecoNLL_loss: 16.2940
# Epoch 158/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0231 - KL_loss: 9.2310 - RecoNLL_loss: 16.2538 - val_loss: 19.0669 - val_KL_loss: 9.2391 - val_RecoNLL_loss: 16.2951
# Epoch 159/400
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 19.0158 - KL_loss: 9.2344 - RecoNLL_loss: 16.2455 - val_loss: 19.1258 - val_KL_loss: 9.2524 - val_RecoNLL_loss: 16.3501
# Epoch 160/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.0152 - KL_loss: 9.2448 - RecoNLL_loss: 16.2417 - val_loss: 19.0527 - val_KL_loss: 9.2436 - val_RecoNLL_loss: 16.2796
# Epoch 161/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0111 - KL_loss: 9.2416 - RecoNLL_loss: 16.2386 - val_loss: 19.0889 - val_KL_loss: 9.2515 - val_RecoNLL_loss: 16.3135
# Epoch 162/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 19.0082 - KL_loss: 9.2515 - RecoNLL_loss: 16.2327 - val_loss: 19.0675 - val_KL_loss: 9.2414 - val_RecoNLL_loss: 16.2951
# Epoch 163/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 19.0022 - KL_loss: 9.2433 - RecoNLL_loss: 16.2292 - val_loss: 19.0905 - val_KL_loss: 9.2501 - val_RecoNLL_loss: 16.3155
# Epoch 164/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9969 - KL_loss: 9.2525 - RecoNLL_loss: 16.2211 - val_loss: 19.0537 - val_KL_loss: 9.2548 - val_RecoNLL_loss: 16.2773
# Epoch 165/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 18.9970 - KL_loss: 9.2506 - RecoNLL_loss: 16.2218 - val_loss: 19.0906 - val_KL_loss: 9.2697 - val_RecoNLL_loss: 16.3097
# Epoch 166/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9954 - KL_loss: 9.2603 - RecoNLL_loss: 16.2173 - val_loss: 19.0642 - val_KL_loss: 9.2488 - val_RecoNLL_loss: 16.2895
# Epoch 167/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9877 - KL_loss: 9.2518 - RecoNLL_loss: 16.2122 - val_loss: 19.1268 - val_KL_loss: 9.2581 - val_RecoNLL_loss: 16.3494
# Epoch 168/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 18.9847 - KL_loss: 9.2573 - RecoNLL_loss: 16.2075 - val_loss: 19.1368 - val_KL_loss: 9.2751 - val_RecoNLL_loss: 16.3543
# Epoch 169/400
# 3448000/3450279 [============================>.] - ETA: 0s - loss: 18.9821 - KL_loss: 9.2627 - RecoNLL_loss: 16.2033
# Epoch 00169: reducing learning rate to 1.00000006569e-06.
# 3450279/3450279 [==============================] - 35s 10us/step - loss: 18.9822 - KL_loss: 9.2627 - RecoNLL_loss: 16.2034 - val_loss: 19.0647 - val_KL_loss: 9.2718 - val_RecoNLL_loss: 16.2832
# Epoch 170/400
# 3450279/3450279 [==============================] - 34s 10us/step - loss: 18.9625 - KL_loss: 9.2681 - RecoNLL_loss: 16.1820 - val_loss: 19.0643 - val_KL_loss: 9.2727 - val_RecoNLL_loss: 16.2825
# Epoch 171/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 18.9630 - KL_loss: 9.2697 - RecoNLL_loss: 16.1821 - val_loss: 19.0812 - val_KL_loss: 9.2744 - val_RecoNLL_loss: 16.2989
# Epoch 172/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9627 - KL_loss: 9.2701 - RecoNLL_loss: 16.1817 - val_loss: 19.0982 - val_KL_loss: 9.2776 - val_RecoNLL_loss: 16.3149
# Epoch 173/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9621 - KL_loss: 9.2724 - RecoNLL_loss: 16.1804 - val_loss: 19.0973 - val_KL_loss: 9.2791 - val_RecoNLL_loss: 16.3136
# Epoch 174/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9609 - KL_loss: 9.2739 - RecoNLL_loss: 16.1788 - val_loss: 19.1082 - val_KL_loss: 9.2793 - val_RecoNLL_loss: 16.3244
# Epoch 175/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 18.9621 - KL_loss: 9.2769 - RecoNLL_loss: 16.1790 - val_loss: 19.0990 - val_KL_loss: 9.2801 - val_RecoNLL_loss: 16.3150
# Epoch 176/400
# 3450279/3450279 [==============================] - 33s 9us/step - loss: 18.9785 - KL_loss: 9.2755 - RecoNLL_loss: 16.1958 - val_loss: 19.0646 - val_KL_loss: 9.2825 - val_RecoNLL_loss: 16.2798
# Epoch 177/400
# 3443000/3450279 [============================>.] - ETA: 0s - loss: 18.9627 - KL_loss: 9.2775 - RecoNLL_loss: 16.1794
# Epoch 00177: reducing learning rate to 1.00000011116e-07.
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9627 - KL_loss: 9.2775 - RecoNLL_loss: 16.1795 - val_loss: 19.0711 - val_KL_loss: 9.2824 - val_RecoNLL_loss: 16.2864
# Epoch 178/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9637 - KL_loss: 9.2773 - RecoNLL_loss: 16.1805 - val_loss: 19.0667 - val_KL_loss: 9.2818 - val_RecoNLL_loss: 16.2822
# Epoch 179/400
# 3450279/3450279 [==============================] - 32s 9us/step - loss: 18.9660 - KL_loss: 9.2772 - RecoNLL_loss: 16.1829 - val_loss: 19.0794 - val_KL_loss: 9.2824 - val_RecoNLL_loss: 16.2947
# Epoch 180/400
# 3450279/3450279 [==============================] - 33s 10us/step - loss: 18.9683 - KL_loss: 9.2781 - RecoNLL_loss: 16.1849 - val_loss: 19.0903 - val_KL_loss: 9.2834 - val_RecoNLL_loss: 16.3053
# Epoch 00180: early stopping
# 2018-11-18 20:38:47.357425: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.2 AVX AVX2 FMA

# %%
if do_training:
    f = plt.figure(figsize=(16,8))
    style = {'loss':'--', 'RecoNLL_loss': 'o', 'KL_loss': '--'}
    for item in style.keys():
        plt.plot(fit_report.history[item][1:], style[item], label=item)
        plt.plot(fit_report.history['val_'+item][1:], style[item], label='val_'+item)

    plt.xlabel('Epoch')
    plt.grid()
    plt.legend(loc='best')
    plt.yscale('log')
    f.savefig('plots/TrainingHistory_VAE_all-in-one_v'+VAEversion+'.png')
    
    f = open('TrainingHistory_VAE_all-in-one_v'+VAEversion+'.pkl', 'w')
    pickle.dump(fit_report.history, f, pickle.HIGHEST_PROTOCOL)
    f.close()

# %%
if do_training:
    vae.save('VAE_all-in-one_v'+VAEversion+'.h5')
else:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'CustomKLLossLayer' : CustomKLLossLayer,
        'CustomRecoProbLayer' : CustomRecoProbLayer,
        'IdentityLoss' : IdentityLoss
    }
    
    vae = load_model('VAE_all-in-one_v'+VAEversion+'.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if do_training:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save('prior_all-in-one_v'+VAEversion+'.h5')
else:
    Prior_Dumper = load_model('prior_all-in-one_v'+VAEversion+'.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [-8.715099   9.79925    5.4762726 -3.6526356]
# [4.826843  5.486205  8.561018  3.3479123]

# %%
if do_training:
    encoder = Model(inputs=x_DNN_input, outputs=[T_z_mean, T_z_sigma])
    encoder.save('encoder_all-in-one_v'+VAEversion+'.h5')
else:
    encoder = load_model('encoder_all-in-one_v'+VAEversion+'.h5', custom_objects=custom_objects)

# %%
if do_training:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('autoencoder_all-in-one_v'+VAEversion+'.h5')
else:
    autoencoder = load_model('autoencoder_all-in-one_v'+VAEversion+'.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
x_sig = {}
for n in BSM_samples+TrainSamplesName:
    s = np.load(data_folder+n+'_sample.npy')
    x_sig[n] = s[:N_train_max, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_val_encoded = np.array(encoder.predict(x_val, batch_size=2000))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    x_sig_encoded[k] = np.array(encoder.predict(v, batch_size=2000))

# %% [markdown]
# Latent space mean distribution

# %%
histos = []
canvases = []
N_bins = 100
rt.gStyle.SetOptTitle(0)

for kk in range(latent_dim):
    print 'Plotting dim', kk, '...'
    canvas = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)
    canvas.SetLeftMargin(0.16)
    canvas.SetBottomMargin(0.16)
    canvas.SetRightMargin(0.02)
    canvas.SetTopMargin(0.02)

    l_bound = mu_prior[kk] - 6*sigma_prior[kk]
    u_bound = mu_prior[kk] + 6*sigma_prior[kk]
    bin_width = (u_bound - l_bound)/N_bins
    z = np.arange(l_bound, u_bound, bin_width)
    
    bin_content = sum_of_gaussians(z, x_val_encoded[0, :, kk], x_val_encoded[1, :, kk])*bin_width
    print '\t SMMix coverage: {:.3f}'.format(np.sum(bin_content))
    h = rt.TH1F('h_SMMix_{}'.format(kk), 'SMMix', N_bins, l_bound-bin_width/2., u_bound+bin_width/2.)
    for i,c in enumerate(bin_content): 
        h.SetBinContent(i+1, c)
    h.GetYaxis().SetRangeUser(1e-5, 0.9)
    h.SetStats(0)
    h.SetLineWidth(0)
    h.SetFillColorAlpha(rt.kGreen+2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetXTitle('z_{'+str(kk)+'}')
    h.GetXaxis().SetTitleSize(0.06)
    h.GetXaxis().SetLabelSize(0.06)
    h.SetYTitle('p.d.f.')
    h.GetYaxis().SetTitleSize(0.06)
    h.GetYaxis().SetTitleOffset(1.16)
    h.GetYaxis().SetLabelSize(0.06)    
    
    h.Draw('Bar')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8,46, 30, 40]
    # fill
    for i, n in enumerate(x_sig.keys()):
        bin_content = sum_of_gaussians(z, x_sig_encoded[n][0, :, kk], x_sig_encoded[n][1, :, kk])*bin_width
        print '\t {} coverage: {:.3f}'.format(n, np.sum(bin_content))
        h = rt.TH1F('h_{}_{}'.format(n, kk), n, N_bins, l_bound-bin_width/2., u_bound+bin_width/2.)
        for j,c in enumerate(bin_content): 
            h.SetBinContent(j+1, c)

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)
    leg = canvas.BuildLegend(0.8, 0.6, 0.99, 0.99, '','lf')
        
    line = rt.TLine()
    line.SetLineWidth(2)
    line.SetLineStyle(9)
    line.SetLineColor(9)
    l = line.DrawLine(mu_prior[kk], 1e-5, mu_prior[kk], 0.9)
    leg.AddEntry(l, 'Prior Mean', 'l')
    line.SetLineColor(40)
    l = line.DrawLine(mu_prior[kk]-sigma_prior[kk], 1e-5, mu_prior[kk]-sigma_prior[kk], 0.9)
    leg.AddEntry(l, 'Prior Sigma', 'l')
    
    line.DrawLine(mu_prior[kk]+sigma_prior[kk], 1e-5, mu_prior[kk]+sigma_prior[kk], 0.9)
    
    canvas.SetGrid()
    canvas.SetLogy()
    canvas.Draw()
    canvas.Update()
    canvases.append(canvas)
    
fout = rt.TFile('plots/all-in-one_v'+VAEversion+'_Zpdf.root', 'RECREATE')
for obj in canvases + histos:
    obj.Write()

fout.Close()
# Out:
# Plotting dim 0 ...
# 	 SMMix coverage: 1.004
# 	 hToTauTau coverage: 0.996
# 	 Zll coverage: 0.998
# 	 qcd coverage: 1.007
# 	 Wlnu coverage: 1.000
# 	 hChToTauNu coverage: 0.984
# 	 Wprime coverage: 1.005
# 	 Ato4l coverage: 1.001
# 	 leptoquark coverage: 0.995
# 	 Zprime coverage: 0.997
# 	 ttbar coverage: 0.981
# Plotting dim 1 ...
# 	 SMMix coverage: 1.006
# 	 hToTauTau coverage: 0.993
# 	 Zll coverage: 0.995
# 	 qcd coverage: 1.009
# 	 Wlnu coverage: 1.006
# 	 hChToTauNu coverage: 0.979
# 	 Wprime coverage: 1.009
# 	 Ato4l coverage: 0.997
# 	 leptoquark coverage: 0.997
# 	 Zprime coverage: 0.978
# 	 ttbar coverage: 0.969
# Plotting dim 2 ...
# 	 SMMix coverage: 0.948
# 	 hToTauTau coverage: 0.955
# 	 Zll coverage: 1.016
# 	 qcd coverage: 1.009
# 	 Wlnu coverage: 0.904
# 	 hChToTauNu coverage: 0.920
# 	 Wprime coverage: 0.884
# 	 Ato4l coverage: 0.996
# 	 leptoquark coverage: 0.968
# 	 Zprime coverage: 1.011
# 	 ttbar coverage: 0.867
# Plotting dim 3 ...
# 	 SMMix coverage: 1.000
# 	 hToTauTau coverage: 0.997
# 	 Zll coverage: 1.000
# 	 qcd coverage: 1.000
# 	 Wlnu coverage: 1.000
# 	 hChToTauNu coverage: 0.992
# 	 Wprime coverage: 0.999
# 	 Ato4l coverage: 0.999
# 	 leptoquark coverage: 0.998
# 	 Zprime coverage: 1.002
# 	 ttbar coverage: 0.984

# %% [markdown]
# ## Recostruction sum of pdf

# %%
pars_ae_val = autoencoder.predict(x_val, batch_size=2000)

# %%
f, ax_arr = plt.subplots(int(len(active_hlf_features)/3.),3 , figsize=(18,36))
N_bins = 100
for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
    
    #Plot distribution of the variable
    x_aux = x_val[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=N_bins, range=histo_range)
        if np.sum(bin_edges>clip_x_to0) > 0:
            i_aux = np.argmin(bin_edges<clip_x_to0)
            bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[i_aux:]))
        else:
            bin_edges = np.array([0, clip_x_to0])
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bin_edges[1:] - bin_edges[:-1]
        bin_width[0] = 1.

        mu_vec = pars_ae_val[0][:, i]
        sigma_vec = pars_ae_val[1][:, i]
        f_vec = pars_ae_val[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=N_bins, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_val[0][:, i]
        sigma_vec = pars_ae_val[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=N_bins, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_val[0][:, i]
        sigma_vec = pars_ae_val[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_val[0][:, i]
        sigma_vec = pars_ae_val[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_val[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.5))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_val[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].ticklabel_format(axis='y', style='sci')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - SMMix')        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
        
f.savefig('plots/SMMix_SumOfPdfs_v'+VAEversion+'.pdf')        
plt.show()
# Out:
# HT
# allJetMass
# allMuPt
# allMuMass
# allElePt
# allEleMass
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# METp
# METo
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad

# %% [markdown]
# # Test Statistics with Losses

# %%
print 'SMMix', x_train.shape
out = vae.predict(x_train, batch_size=2000)
loss_train = np.column_stack((weight_KL_loss*out[0]+out[1], out[1], out[0])).T

loss_sig = {}
for n in x_sig.keys():
    print n, x_sig[n].shape
    aux = vae.predict(x_sig[n], batch_size=2000)
    loss_sig[n] = np.column_stack((weight_KL_loss*aux[0]+aux[1], aux[1], aux[0])).T
# Out:
# SMMix (3450279, 21)
# hToTauTau (344917, 21)
# Zll (1777383, 21)
# qcd (1166195, 21)
# Wlnu (8000082, 21)
# hChToTauNu (339018, 21)
# Wprime (605662, 21)
# Ato4l (652070, 21)
# leptoquark (583043, 21)
# Zprime (55362, 21)
# ttbar (5001726, 21)

# %%
histos = []
canvases = []
Ytitles = ['Loss Tot', 'NLL(reco prob)', 'KL divergence']

eff_SMMix = 8.06e-6

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-1e-6))]
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)

    h = rt.TH1F('h_loss_SMMix_{}'.format(loss_piece), 'SMMix', binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])
    h.SetStats(0)
    h.SetLineWidth(0)
    h.SetFillColorAlpha(rt.kGreen+2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-eff_SMMix))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(eff_SMMix))


    colors = [1,2,4,rt.kYellow+2,6,7,8,46, 30, 40]
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
        h1 = rt.TH1F('h_loss_{}_{}'.format(n, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend(0.8, 0.6, 0.99, 0.99, '','lf')
    h.SetTitle('')
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)
    
fout = rt.TFile('plots/all-in-one_v'+VAEversion+'_losses.root', 'RECREATE')
for obj in canvases + histos:
    obj.Write()

fout.Close()

# %%
SM_evts_per_month = 1000
SM_tot_xsec = 37.205e6 #fb

lumi_per_yr = 40 #fb^-1
DataColl_month = 8.

eff_SMMix = SM_evts_per_month/(SM_tot_xsec * lumi_per_yr/DataColl_month)
print 'Ideal Eff SM --->> {:.2e}\n\n\n'.format(eff_SMMix)

for ll in range(3):
    cut = np.percentile(loss_train[ll], 100*(1-eff_SMMix))
    
    print '----------------',Ytitles[ll], '----------------'
    table_SM = PrettyTable(['Sample', 'VAE Eff','Events fraction', 'evts/month'])
    table_BSM = PrettyTable(['Sample', 'VAE Eff', 'xsec (100 evts/month) [fb]', 'xsec (S/B = 0.3) [fb]'])
    
    N_SM_imp = 0
    dN_SM_imp = 0
    effSM_imp = 0
    deffSM_imp = 0
    for n, lss in loss_sig.items():
        if n in TrainSamplesName:
            aux = np.greater(lss[ll,:], cut)
            selected = np.sum(aux)
            eff = float(selected)/lss.shape[1]
            d_eff = np.sqrt(eff*(1-eff)/lss.shape[1])

            idx = TrainSamplesName.index(n)
            
            effSM_imp += fraction[idx]*eff
            deffSM_imp += (fraction[idx]*d_eff)**2
            
            N_evts = SM_tot_xsec*fraction[idx]*eff*lumi_per_yr/DataColl_month
            d_N_evts = N_evts*d_eff/eff
            N_SM_imp += N_evts
            dN_SM_imp += d_N_evts**2
            
    dN_SM_imp = np.sqrt(dN_SM_imp)
    deffSM_imp = np.sqrt(deffSM_imp)
    
    
    for n, lss in loss_sig.items():
        aux = np.greater(lss[ll,:], cut)
        selected = np.sum(aux)
        eff = float(selected)/lss.shape[1]
        d_eff = np.sqrt(eff*(1-eff)/lss.shape[1])
        
        if n in TrainSamplesName:
            idx = TrainSamplesName.index(n)
            N_evts = SM_tot_xsec*fraction[idx]*eff*lumi_per_yr/DataColl_month
            d_N_evts = N_evts*d_eff/eff
            table_SM.add_row([n,
                              '{:1.1e} +/- {:1.1e}'.format(eff, d_eff), 
                              '{:.2f} %'.format(100*float(N_evts/N_SM_imp)),
                              '{:.0f} +/- {:.0f}'.format(N_evts, d_N_evts)])
        else:
            if eff == 0:
                print n, eff
                continue
            x_sec_lim = 100. * DataColl_month/(lumi_per_yr * eff)
            x_sec_SoB = 0.3 * N_SM_imp * DataColl_month/(lumi_per_yr * eff)
            table_BSM.add_row([n, 
                               '{:1.1e} +/- {:1.1e}'.format(eff, d_eff), 
                               '{:.1f}'.format(x_sec_lim), 
                               '{:1.1e}'.format(x_sec_SoB)])


    print table_SM
    print 'Eff VAE SM: {:.2e} +/- {:.2e}'.format(effSM_imp, deffSM_imp)
    print 'Expected SM evts/month: {:.0f} +/- {:.0f}'.format(N_SM_imp , dN_SM_imp)
    print table_BSM
    print '\n\n'
# Out:
# Ideal Eff SM --->> 5.38e-06
#
#
#
# ---------------- Loss Tot ----------------
# Zprime 0.0
# +--------+---------------------+-----------------+-------------+
# | Sample |       VAE Eff       | Events fraction |  evts/month |
# +--------+---------------------+-----------------+-------------+
# |  Zll   | 1.7e-05 +/- 3.1e-06 |     18.67 %     |  210 +/- 38 |
# |  Wlnu  | 5.4e-06 +/- 8.2e-07 |     52.52 %     |  592 +/- 90 |
# |  qcd   | 4.3e-06 +/- 1.9e-06 |     23.92 %     | 270 +/- 121 |
# | ttbar  | 9.9e-05 +/- 4.4e-06 |      4.89 %     |   55 +/- 2  |
# +--------+---------------------+-----------------+-------------+
# Eff VAE SM: 6.06e-06 +/- 8.36e-07
# Expected SM evts/month: 1127 +/- 155
# +------------+---------------------+----------------------------+-----------------------+
# |   Sample   |       VAE Eff       | xsec (100 evts/month) [fb] | xsec (S/B = 0.3) [fb] |
# +------------+---------------------+----------------------------+-----------------------+
# | hToTauTau  | 9.6e-05 +/- 1.7e-05 |          209040.6          |        7.1e+05        |
# |   Ato4l    | 1.6e-03 +/- 4.9e-05 |          12723.3           |        4.3e+04        |
# | hChToTauNu | 1.5e-04 +/- 2.1e-05 |          135607.2          |        4.6e+05        |
# |   Wprime   | 3.3e-06 +/- 2.3e-06 |         6056620.0          |        2.0e+07        |
# | leptoquark | 1.9e-04 +/- 1.8e-05 |          104114.8          |        3.5e+05        |
# +------------+---------------------+----------------------------+-----------------------+
#
#
#
# ---------------- NLL(reco prob) ----------------
# Zprime 0.0
# +--------+---------------------+-----------------+-------------+
# | Sample |       VAE Eff       | Events fraction |  evts/month |
# +--------+---------------------+-----------------+-------------+
# |  Zll   | 1.6e-05 +/- 3.0e-06 |     18.16 %     |  203 +/- 38 |
# |  Wlnu  | 5.4e-06 +/- 8.2e-07 |     52.87 %     |  592 +/- 90 |
# |  qcd   | 4.3e-06 +/- 1.9e-06 |     24.08 %     | 270 +/- 121 |
# | ttbar  | 9.8e-05 +/- 4.4e-06 |      4.89 %     |   55 +/- 2  |
# +--------+---------------------+-----------------+-------------+
# Eff VAE SM: 6.02e-06 +/- 8.35e-07
# Expected SM evts/month: 1120 +/- 155
# +------------+---------------------+----------------------------+-----------------------+
# |   Sample   |       VAE Eff       | xsec (100 evts/month) [fb] | xsec (S/B = 0.3) [fb] |
# +------------+---------------------+----------------------------+-----------------------+
# | hToTauTau  | 9.6e-05 +/- 1.7e-05 |          209040.6          |        7.0e+05        |
# |   Ato4l    | 1.6e-03 +/- 4.9e-05 |          12760.7           |        4.3e+04        |
# | hChToTauNu | 1.4e-04 +/- 2.1e-05 |          138374.7          |        4.6e+05        |
# |   Wprime   | 3.3e-06 +/- 2.3e-06 |         6056620.0          |        2.0e+07        |
# | leptoquark | 1.9e-04 +/- 1.8e-05 |          104114.8          |        3.5e+05        |
# +------------+---------------------+----------------------------+-----------------------+
#
#
#
# ---------------- KL divergence ----------------
# Zprime 0.0
# +--------+---------------------+-----------------+------------+
# | Sample |       VAE Eff       | Events fraction | evts/month |
# +--------+---------------------+-----------------+------------+
# |  Zll   | 9.6e-06 +/- 2.3e-06 |     12.32 %     | 119 +/- 29 |
# |  Wlnu  | 4.6e-06 +/- 7.6e-07 |     52.66 %     | 509 +/- 84 |
# |  qcd   | 1.7e-06 +/- 1.2e-06 |     11.15 %     | 108 +/- 76 |
# | ttbar  | 4.1e-04 +/- 9.1e-06 |     23.87 %     | 231 +/- 5  |
# +--------+---------------------+-----------------+------------+
# Eff VAE SM: 5.20e-06 +/- 6.29e-07
# Expected SM evts/month: 967 +/- 117
# +------------+---------------------+----------------------------+-----------------------+
# |   Sample   |       VAE Eff       | xsec (100 evts/month) [fb] | xsec (S/B = 0.3) [fb] |
# +------------+---------------------+----------------------------+-----------------------+
# | hToTauTau  | 8.1e-05 +/- 1.5e-05 |          246369.3          |        7.1e+05        |
# |   Ato4l    | 4.6e-05 +/- 8.4e-06 |          434713.3          |        1.3e+06        |
# | hChToTauNu | 2.2e-04 +/- 2.6e-05 |          89215.3           |        2.6e+05        |
# |   Wprime   | 3.3e-06 +/- 2.3e-06 |         6056620.0          |        1.8e+07        |
# | leptoquark | 5.1e-06 +/- 3.0e-06 |         3886953.3          |        1.1e+07        |
# +------------+---------------------+----------------------------+-----------------------+

# %% [markdown]
# ## ROC Curves

# %%
print i_min
# Out:
# 1

# %%
l = np.zeros(4)
for i,n in enumerate(TrainSamplesName):
    l[i] = loss_sig[n].shape[1]
    
i_min = np.argmin(l/fraction)
print 'Limiting stat. sample: {} ({:.2f}M)'.format(TrainSamplesName[i_min], l[i_min]*1e-6)

weight = []
for i,n in enumerate(TrainSamplesName):
    w = np.float128(fraction[i]/ fraction[i_min]) * np.float128(l[i_min]/l[i])
    weight.append(w)
weight
# Out:
# Limiting stat. sample: qcd (1.17M)
# [0.2553181818052045295, 1.0, 0.13006134938893120572, 0.0020694542634415144572]

# %%
p_SM = np.logspace(base=10, start=-7, stop=0, num=100)
p_SM[-1] = 0.999

for ll in range(3):
    f_ROC, ax_arr_ROC = plt.subplots(1,1, figsize=(10,10))
    ax_arr_ROC.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax_arr_ROC.plot([eff_SMMix, eff_SMMix], [1e-6, 1.05], color='red', lw=2, linestyle='--', label='1000 SM evts/month')
    ax_arr_ROC.set_xlim([1e-6, 1.0])
    ax_arr_ROC.set_ylim([1e-6, 1.05])
    ax_arr_ROC.set_xlabel('SM efficiency', fontdict={'size': 16})
    ax_arr_ROC.ticklabel_format()
    ax_arr_ROC.set_ylabel('BSM efficiency', fontdict={'size': 16})
    ax_arr_ROC.set_title('ROC VAE ' + Ytitles[ll], fontdict={'size': 16})
    ax_arr_ROC.set_yscale('log')
    ax_arr_ROC.set_xscale('log')
    ax_arr_ROC.grid()

    t_SM = np.concatenate((loss_sig['Wlnu'][ll], 
                           loss_sig['qcd'][ll],
                           loss_sig['Zll'][ll],
                           loss_sig['ttbar'][ll]
                          ))
    
    w_SM = np.concatenate((np.full_like(loss_sig['Wlnu'][ll], weight[0], np.float128),
                           np.full_like(loss_sig['qcd'][ll], weight[1], np.float128),
                           np.full_like(loss_sig['Zll'][ll], weight[2], np.float128),
                           np.full_like(loss_sig['ttbar'][ll], weight[3], np.float128)
                          ))
    
    i_sort = np.argsort(t_SM)
    
    t_SM = t_SM[i_sort]
    w_SM = w_SM[i_sort]
    
    cum_sum = np.cumsum(w_SM, dtype=np.float128)/np.float128(l[i_min]/fraction[i_min])
    print 'CumSum accuracy:', cum_sum[-1]
    
    idx_q = np.argmax(cum_sum>np.atleast_2d(1-p_SM).T, axis=1)
    q_SM = t_SM[idx_q]
    
    for n in BSM_samples:
        out = loss_sig[n][ll] > np.atleast_2d(q_SM).T
        p_BSM = np.float64(np.sum(out, axis=1, dtype=np.float128)/loss_sig[n].shape[1])
        
        roc_auc = np.trapz(p_BSM, p_SM)
        
        dic2save = {'eff_BSM':p_BSM, 'eff_SM':p_SM, 'roc_auc':roc_auc}
        fileout = open('VAE_all-in-one_v{}_ROC{}_dict_{}.pkl'.format(VAEversion, ll, n), 'w')
        pickle.dump(file=fileout, obj=dic2save)
        fileout.close()
    
        ax_arr_ROC.plot(p_SM, p_BSM, label='{} (area = {:0.2f})'.format(n, roc_auc))
        
    ax_arr_ROC.legend(loc="lower right")
    f_ROC.savefig('plots/ROC_VAE'+str(ll)+'.png')
# Out:
# CumSum accuracy: 0.99999999999994777404
# CumSum accuracy: 0.99999999999994785334
# CumSum accuracy: 0.999999999999963786
