# %% [markdown]
# VampPrior
#
# - Tried with 10 hidden dim -> not converged
# - Tried to add allLepMass and hidden from 4 to 5 -> Eff improve (~70% for Zprime) but reco is a shit
# - If remove VampEff decrease
# - When VampPrior 4 nodes and AllLepMass -> Reco converging, eff is smaller on KL but good on reco prob (~50% for Zprime)

# %%
from glob import glob
import sys, scipy
from scipy.stats import chi2, poisson

import matplotlib.pyplot as plt
import numpy as np

# %%
import ROOT as rt
import root_numpy as rtnp
# Out:
# Welcome to JupyROOT 6.10/08

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
from keras.layers import Input, Dense, Lambda, Layer
from keras.models import Model
from keras import backend as K
from keras import layers as KL
from keras import metrics
from keras import optimizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
import keras
print keras.__version__
# Out:
# /Users/olmo/programs/root-6.10.08/lib/ROOT.py:318: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   return _orig_ihook( name, *args, **kwds )
# Using TensorFlow backend.
# 2.1.2

# %% [markdown]
# # Get the samples

# %%
hlf_features = ['HT', 'MET', 'DPhiMETLep', 'MT', 'nJets', 
                'bJets', 'allJetMass', 'LepPt', 'LepEta', 
                'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu', 'LepCharge', 
                'LepIsEle', 'nMu', 'allMuMass', 'allMuPt', 'nEle', 
                'allEleMass', 'allElePt', 'nChHad', 'nNeuHad', 'nPhoton']

active_hlf_features = ['HT', 'allJetMass',
                       'allMuPt','allElePt','allEleMass', 'allMuMass',
                       'LepPt', 'LepIsoCh', 'LepIsoGamma', 'LepIsoNeu',
                       
                       'LepEta', 'DPhiMETLep',
                       
                       'MT', 'MET',
                       
                       'nMu', 'nJets', 'bJets', 'nEle', 
                       
                       'LepCharge','LepIsEle', 
                       
                       'nChHad', 'nNeuHad', 'nPhoton']

Nf_lognorm = 11
Nf_gauss = 2
Nf_Pgauss = 2
Nf_PDgauss = 4
Nf_binomial = 2
Nf_poisson = 3

# %%
sel = []
for a in active_hlf_features:
    for i,f in enumerate(hlf_features):
        if a == f:
            sel.append(i)

print 'Activated HLF:'
for n in np.array(hlf_features)[sel]:
    print '\t', n
# Out:
# Activated HLF:
# 	HT
# 	MET
# 	allJetMass
# 	allMuPt
# 	allElePt
# 	allEleMass
# 	allMuMass
# 	LepPt
# 	LepIsoCh
# 	LepIsoGamma
# 	LepIsoNeu
# 	LepEta
# 	DPhiMETLep
# 	MT
# 	nMu
# 	nJets
# 	bJets
# 	nEle
# 	LepCharge
# 	LepIsEle
# 	nChHad
# 	nNeuHad
# 	nPhoton

# %%
data_folder = '../../data/HLF_ONLY/'
SampleName = 'Wlnu'
N_train = int(2e6)


raw_sample = np.load(data_folder+SampleName+'_lepFilter_13TeV_sample.npy')
x_train = raw_sample[:N_train, sel]

print raw_sample.shape, x_train.shape
# Out:
# (10000904, 23) (2000000, 23)

# %% [markdown]
# # Start the VAE declaration

# %%
original_dim = x_train.shape[1]
latent_dim = 4
intermediate_dim = 50
act_fun = 'relu'
clip_x_to0 = 1e-4

# %%
def InverseSquareRootLinearUnit(args, min_value = 5e-3):
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def ClippedTanh(x):
    return 0.5*(1+0.999*K.tanh(x))

def SmashTo0(x):
    return 0*x

# %%
x_DNN_input = Input(shape=(original_dim,))
hidden_1 = Dense(intermediate_dim, activation=act_fun)(x_DNN_input)
hidden_2 = Dense(intermediate_dim, activation=act_fun)(hidden_1)
# hidden_3 = Dense(intermediate_dim, activation=act_fun)(hidden_2)

L_z_mean = Dense(latent_dim)(hidden_2)

L_z_sigma_preActivation = Dense(latent_dim)(hidden_2)
L_z_sigma = Lambda(InverseSquareRootLinearUnit)(L_z_sigma_preActivation)

# %%
def sampling(args):
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.,
                              stddev=1.)
    return z_mean + z_sigma * epsilon

L_z_latent_DNN = Lambda(sampling)([L_z_mean, L_z_sigma])

# %%
decoder_h1 = Dense(intermediate_dim, activation=act_fun)(L_z_latent_DNN)
decoder_h2 = Dense(intermediate_dim, activation=act_fun)(decoder_h1)
# decoder_h3 = Dense(intermediate_dim, activation=act_fun)(decoder_h2)
L_par1 = Dense(original_dim)(decoder_h2)

L_par2_preActivation = Dense(Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss)(decoder_h2)
L_par2 = Lambda(InverseSquareRootLinearUnit)(L_par2_preActivation)

L_par3_preActivation = Dense(Nf_lognorm)(decoder_h2)
L_par3 = Lambda(ClippedTanh)(L_par3_preActivation)

# %% [markdown]
# Create Prior Layer

# %%
fixed_input = Lambda(SmashTo0)(x_DNN_input)
h1_prior = Dense(20, kernel_initializer='zeros', bias_initializer='ones', trainable=False)(fixed_input)
# h2_prior = Dense(100, activation=act_fun)(h1_prior)

L_prior_mean = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='zeros', trainable=True)(h1_prior)

L_prior_sigma_preActivation = Dense(latent_dim, kernel_initializer='zeros', bias_initializer='ones', trainable=True)(h1_prior)
L_prior_sigma = Lambda(InverseSquareRootLinearUnit)(L_prior_sigma_preActivation)

# %% [markdown]
# Custom loss function

# %%
def KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior):
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return K.mean(0.5 * K.sum(kl_loss, axis=-1))

def RecoProb_forVAE(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = K.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = K.tf.where(K.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -K.log(fraction),
                                -K.log(1-fraction)
                                + K.log(sigma) 
                                + K.log(x_clipped)
                                + 0.5*K.square(K.tf.divide(K.log(x_clipped) - mu, sigma))
                           )
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_gauss] - mu, sigma)
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = K.tf.divide(x[:,N:N+Nf_Pgauss] - mu, sigma)

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + K.tf.erf(K.tf.divide(- mu, sigma)/sqrt2))
    
    single_NLL = K.log(sigma) + 0.5*K.square(norm_x) - K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = K.tf.divide(x[:,N:N+Nf_PDgauss] + 0.5 - mu, sigma)
    norm_xm = K.tf.divide(x[:,N:N+Nf_PDgauss] - 0.5 - mu, sigma)
    sqrt2 = 1.4142135624
    single_LL = 0.5*(K.tf.erf(norm_xp/sqrt2) - K.tf.erf(norm_xm/sqrt2))
    
    norm_0 = K.tf.divide(-0.5 - mu, sigma)
    aNorm = 1 + 0.5*(1 + K.tf.erf(norm_0/sqrt2))
    
    single_NLL = -K.log(K.clip(single_LL, 1e-10, 1e40)) -K.log(aNorm)
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*K.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -K.tf.where(K.equal(x[:, N: N+Nf_binomial],1), K.log(p), K.log(1-p))
    nll_loss += K.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + K.tf.where(K.tf.greater(aux, 0), aux, K.tf.divide(aux, K.sqrt(1+K.square(aux))))
    single_NLL = K.tf.lgamma(x[:, N:]+1) - x[:, N:]*K.log(mu) + mu
    nll_loss += K.sum(single_NLL, axis=-1)
    
    return K.mean(nll_loss)

def LossVAE(y_train, NETout):
    mu = NETout[:, :latent_dim]
    N = latent_dim
    
    sigma = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    mu_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    sigma_prior = NETout[:, N: N+latent_dim]
    N += latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior) + RecoProb_forVAE(y_train, par1, par2, par3)

# %%
def RecoProb_metric(y_train, NETout):
    N = 4*latent_dim
    
    par1 = NETout[:, N: N+original_dim]
    N += original_dim
    
    par2 = NETout[:, N: N+Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss]
    N += Nf_lognorm+Nf_gauss+Nf_Pgauss+Nf_PDgauss
    
    par3 = NETout[:, N:N+Nf_lognorm]
    
    return RecoProb_forVAE(y_train, par1, par2, par3)

def KL_loss_metric(y_train, NETout):
    mu = NETout[:, :latent_dim]
    sigma = NETout[:, latent_dim: 2*latent_dim]
    mu_prior = NETout[:, 2*latent_dim: 3*latent_dim]
    sigma_prior = NETout[:, 3*latent_dim: 4*latent_dim]
    return KL_loss_forVAE(mu, sigma, mu_prior, sigma_prior)

# %%
global_outputs = KL.concatenate([L_z_mean, L_z_sigma, L_prior_mean, L_prior_sigma, L_par1, L_par2, L_par3])

vae = Model(inputs=x_DNN_input, outputs=global_outputs)
# rms_prop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
vae.compile(optimizer='adam', loss=LossVAE, metrics=[RecoProb_metric, KL_loss_metric])
print vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 23)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           1200        input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           2550        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            204         dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4)            0           dense_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 23)           0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 50)           250         lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 20)           480         lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 50)           2550        dense_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 18)           918         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 11)           561         dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 4)            84          dense_10[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 4)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 23)           1173        dense_6[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 18)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 11)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 68)           0           dense_3[0][0]
#                                                                  lambda_1[0][0]
#                                                                  dense_11[0][0]
#                                                                  lambda_6[0][0]
#                                                                  dense_7[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
# ==================================================================================================
# Total params: 10,258
# Trainable params: 9,778
# Non-trainable params: 480
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Training

# %%
fit_report = vae.fit(x=x_train, y=x_train,
        validation_split = 0.2,
        shuffle=True,
        epochs=100,
        batch_size=400,
        callbacks = [
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1, min_delta=0.05),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4, epsilon=0.1, verbose=1),
                        TerminateOnNaN()
            ])
# Out:
# Train on 1600000 samples, validate on 400000 samples
# Epoch 1/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 37.2546 - RecoProb_metric: 30.5949 - KL_loss_metric: 6.6597 - val_loss: 36.0226 - val_RecoProb_metric: 29.7758 - val_KL_loss_metric: 6.2468
# Epoch 2/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 35.1619 - RecoProb_metric: 29.1540 - KL_loss_metric: 6.0079 - val_loss: 34.3344 - val_RecoProb_metric: 28.5213 - val_KL_loss_metric: 5.8131
# Epoch 3/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 33.9184 - RecoProb_metric: 28.1404 - KL_loss_metric: 5.7780 - val_loss: 33.5405 - val_RecoProb_metric: 27.7643 - val_KL_loss_metric: 5.7761
# Epoch 4/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 33.2875 - RecoProb_metric: 27.5850 - KL_loss_metric: 5.7025 - val_loss: 32.9719 - val_RecoProb_metric: 27.3137 - val_KL_loss_metric: 5.6582
# Epoch 5/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 32.8091 - RecoProb_metric: 27.1577 - KL_loss_metric: 5.6514 - val_loss: 32.7288 - val_RecoProb_metric: 27.0293 - val_KL_loss_metric: 5.6995
# Epoch 6/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 32.4423 - RecoProb_metric: 26.8210 - KL_loss_metric: 5.6213 - val_loss: 32.3507 - val_RecoProb_metric: 26.6376 - val_KL_loss_metric: 5.7131
# Epoch 7/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 32.1451 - RecoProb_metric: 26.5707 - KL_loss_metric: 5.5744 - val_loss: 31.9632 - val_RecoProb_metric: 26.4246 - val_KL_loss_metric: 5.5387
# Epoch 8/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 31.9189 - RecoProb_metric: 26.3853 - KL_loss_metric: 5.5337 - val_loss: 31.7446 - val_RecoProb_metric: 26.2451 - val_KL_loss_metric: 5.4995
# Epoch 9/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 31.7176 - RecoProb_metric: 26.2238 - KL_loss_metric: 5.4938 - val_loss: 31.5376 - val_RecoProb_metric: 26.0591 - val_KL_loss_metric: 5.4784
# Epoch 10/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 31.5667 - RecoProb_metric: 26.1160 - KL_loss_metric: 5.4507 - val_loss: 31.5508 - val_RecoProb_metric: 26.1110 - val_KL_loss_metric: 5.4398
# Epoch 11/100
# 1600000/1600000 [==============================] - 22s 14us/step - loss: 31.4509 - RecoProb_metric: 25.9953 - KL_loss_metric: 5.4556 - val_loss: 31.2288 - val_RecoProb_metric: 25.8542 - val_KL_loss_metric: 5.3745
# Epoch 12/100
# 1600000/1600000 [==============================] - 22s 14us/step - loss: 31.2739 - RecoProb_metric: 25.8802 - KL_loss_metric: 5.3937 - val_loss: 31.1546 - val_RecoProb_metric: 25.8317 - val_KL_loss_metric: 5.3229
# Epoch 13/100
# 1600000/1600000 [==============================] - 22s 13us/step - loss: 31.1761 - RecoProb_metric: 25.8032 - KL_loss_metric: 5.3729 - val_loss: 31.0749 - val_RecoProb_metric: 25.7132 - val_KL_loss_metric: 5.3617
# Epoch 14/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 31.1086 - RecoProb_metric: 25.7374 - KL_loss_metric: 5.3711 - val_loss: 31.0140 - val_RecoProb_metric: 25.6988 - val_KL_loss_metric: 5.3152
# Epoch 15/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 31.0088 - RecoProb_metric: 25.6546 - KL_loss_metric: 5.3543 - val_loss: 30.9100 - val_RecoProb_metric: 25.5728 - val_KL_loss_metric: 5.3372
# Epoch 16/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.9475 - RecoProb_metric: 25.5996 - KL_loss_metric: 5.3479 - val_loss: 30.9432 - val_RecoProb_metric: 25.5325 - val_KL_loss_metric: 5.4107
# Epoch 17/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.8409 - RecoProb_metric: 25.5325 - KL_loss_metric: 5.3084 - val_loss: 30.7338 - val_RecoProb_metric: 25.4613 - val_KL_loss_metric: 5.2725
# Epoch 18/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.7779 - RecoProb_metric: 25.4560 - KL_loss_metric: 5.3219 - val_loss: 30.6261 - val_RecoProb_metric: 25.3187 - val_KL_loss_metric: 5.3074
# Epoch 19/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.7498 - RecoProb_metric: 25.4250 - KL_loss_metric: 5.3248 - val_loss: 30.6563 - val_RecoProb_metric: 25.3653 - val_KL_loss_metric: 5.2909
# Epoch 20/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.6193 - RecoProb_metric: 25.3091 - KL_loss_metric: 5.3103 - val_loss: 30.5050 - val_RecoProb_metric: 25.2019 - val_KL_loss_metric: 5.3031
# Epoch 21/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.5777 - RecoProb_metric: 25.2150 - KL_loss_metric: 5.3627 - val_loss: 30.6552 - val_RecoProb_metric: 25.2394 - val_KL_loss_metric: 5.4158
# Epoch 22/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.4380 - RecoProb_metric: 25.0745 - KL_loss_metric: 5.3635 - val_loss: 31.2369 - val_RecoProb_metric: 25.6244 - val_KL_loss_metric: 5.6125
# Epoch 23/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 30.4245 - RecoProb_metric: 24.9864 - KL_loss_metric: 5.4380 - val_loss: 30.5279 - val_RecoProb_metric: 24.8666 - val_KL_loss_metric: 5.6614
# Epoch 24/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 30.2829 - RecoProb_metric: 24.8438 - KL_loss_metric: 5.4391 - val_loss: 30.1415 - val_RecoProb_metric: 24.7032 - val_KL_loss_metric: 5.4383
# Epoch 25/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.2485 - RecoProb_metric: 24.7922 - KL_loss_metric: 5.4563 - val_loss: 30.1565 - val_RecoProb_metric: 24.7318 - val_KL_loss_metric: 5.4247
# Epoch 26/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.1559 - RecoProb_metric: 24.6959 - KL_loss_metric: 5.4600 - val_loss: 30.0105 - val_RecoProb_metric: 24.5609 - val_KL_loss_metric: 5.4496
# Epoch 27/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.1194 - RecoProb_metric: 24.6564 - KL_loss_metric: 5.4631 - val_loss: 30.3153 - val_RecoProb_metric: 24.8307 - val_KL_loss_metric: 5.4846
# Epoch 28/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.0996 - RecoProb_metric: 24.6260 - KL_loss_metric: 5.4736 - val_loss: 29.9791 - val_RecoProb_metric: 24.5301 - val_KL_loss_metric: 5.4491
# Epoch 29/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.0585 - RecoProb_metric: 24.5801 - KL_loss_metric: 5.4784 - val_loss: 29.9433 - val_RecoProb_metric: 24.4922 - val_KL_loss_metric: 5.4512
# Epoch 30/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.0226 - RecoProb_metric: 24.5412 - KL_loss_metric: 5.4814 - val_loss: 29.8346 - val_RecoProb_metric: 24.3862 - val_KL_loss_metric: 5.4484
# Epoch 31/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 30.0175 - RecoProb_metric: 24.5295 - KL_loss_metric: 5.4880 - val_loss: 30.0635 - val_RecoProb_metric: 24.5395 - val_KL_loss_metric: 5.5240
# Epoch 32/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 29.8827 - RecoProb_metric: 24.4179 - KL_loss_metric: 5.4649 - val_loss: 29.7622 - val_RecoProb_metric: 24.3131 - val_KL_loss_metric: 5.4491
# Epoch 33/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 29.8757 - RecoProb_metric: 24.3721 - KL_loss_metric: 5.5037 - val_loss: 29.7676 - val_RecoProb_metric: 24.2724 - val_KL_loss_metric: 5.4951
# Epoch 34/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 29.7838 - RecoProb_metric: 24.2836 - KL_loss_metric: 5.5002 - val_loss: 29.6028 - val_RecoProb_metric: 24.0636 - val_KL_loss_metric: 5.5392
# Epoch 35/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.7618 - RecoProb_metric: 24.2291 - KL_loss_metric: 5.5327 - val_loss: 29.5713 - val_RecoProb_metric: 24.0376 - val_KL_loss_metric: 5.5336
# Epoch 36/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.6344 - RecoProb_metric: 24.0892 - KL_loss_metric: 5.5451 - val_loss: 29.7406 - val_RecoProb_metric: 24.0979 - val_KL_loss_metric: 5.6426
# Epoch 37/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 29.8534 - RecoProb_metric: 24.1191 - KL_loss_metric: 5.7343 - val_loss: 29.5875 - val_RecoProb_metric: 23.9566 - val_KL_loss_metric: 5.6308
# Epoch 38/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.5625 - RecoProb_metric: 23.9353 - KL_loss_metric: 5.6271 - val_loss: 29.4435 - val_RecoProb_metric: 23.7762 - val_KL_loss_metric: 5.6673
# Epoch 39/100
# 1600000/1600000 [==============================] - 20s 13us/step - loss: 29.4239 - RecoProb_metric: 23.7649 - KL_loss_metric: 5.6590 - val_loss: 29.2833 - val_RecoProb_metric: 23.6095 - val_KL_loss_metric: 5.6738
# Epoch 40/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 29.7255 - RecoProb_metric: 23.6852 - KL_loss_metric: 6.0403 - val_loss: 29.2723 - val_RecoProb_metric: 23.4737 - val_KL_loss_metric: 5.7986
# Epoch 41/100
# 1600000/1600000 [==============================] - 18s 12us/step - loss: 29.3787 - RecoProb_metric: 23.6509 - KL_loss_metric: 5.7278 - val_loss: 29.9048 - val_RecoProb_metric: 24.1311 - val_KL_loss_metric: 5.7736
# Epoch 42/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.3441 - RecoProb_metric: 23.6439 - KL_loss_metric: 5.7001 - val_loss: 29.1617 - val_RecoProb_metric: 23.4728 - val_KL_loss_metric: 5.6889
# Epoch 43/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.3108 - RecoProb_metric: 23.5925 - KL_loss_metric: 5.7183 - val_loss: 30.4553 - val_RecoProb_metric: 24.7681 - val_KL_loss_metric: 5.6872
# Epoch 44/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.2282 - RecoProb_metric: 23.4960 - KL_loss_metric: 5.7321 - val_loss: 33.0784 - val_RecoProb_metric: 27.4115 - val_KL_loss_metric: 5.6669
# Epoch 45/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 29.1871 - RecoProb_metric: 23.4504 - KL_loss_metric: 5.7367 - val_loss: 29.1047 - val_RecoProb_metric: 23.3720 - val_KL_loss_metric: 5.7327
# Epoch 46/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 29.1412 - RecoProb_metric: 23.3926 - KL_loss_metric: 5.7486 - val_loss: 29.0559 - val_RecoProb_metric: 23.3028 - val_KL_loss_metric: 5.7531
# Epoch 47/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 29.1237 - RecoProb_metric: 23.3287 - KL_loss_metric: 5.7950 - val_loss: 28.9502 - val_RecoProb_metric: 23.1538 - val_KL_loss_metric: 5.7965
# Epoch 48/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 29.0533 - RecoProb_metric: 23.2817 - KL_loss_metric: 5.7715 - val_loss: 28.9999 - val_RecoProb_metric: 23.2354 - val_KL_loss_metric: 5.7645
# Epoch 49/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 29.0392 - RecoProb_metric: 23.2692 - KL_loss_metric: 5.7700 - val_loss: 28.8266 - val_RecoProb_metric: 23.0718 - val_KL_loss_metric: 5.7549
# Epoch 50/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 28.9476 - RecoProb_metric: 23.1665 - KL_loss_metric: 5.7811 - val_loss: 28.8292 - val_RecoProb_metric: 23.0509 - val_KL_loss_metric: 5.7783
# Epoch 51/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 28.9030 - RecoProb_metric: 23.1056 - KL_loss_metric: 5.7975 - val_loss: 28.7421 - val_RecoProb_metric: 22.9886 - val_KL_loss_metric: 5.7536
# Epoch 52/100
# 1600000/1600000 [==============================] - 20s 12us/step - loss: 28.8539 - RecoProb_metric: 23.0439 - KL_loss_metric: 5.8100 - val_loss: 28.8273 - val_RecoProb_metric: 23.0483 - val_KL_loss_metric: 5.7790
# Epoch 53/100
# 1600000/1600000 [==============================] - 21s 13us/step - loss: 28.7708 - RecoProb_metric: 22.9496 - KL_loss_metric: 5.8212 - val_loss: 28.7445 - val_RecoProb_metric: 22.9163 - val_KL_loss_metric: 5.8282
# Epoch 54/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.7353 - RecoProb_metric: 22.9035 - KL_loss_metric: 5.8318 - val_loss: 28.6142 - val_RecoProb_metric: 22.7660 - val_KL_loss_metric: 5.8482
# Epoch 55/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.6660 - RecoProb_metric: 22.8078 - KL_loss_metric: 5.8582 - val_loss: 28.6843 - val_RecoProb_metric: 22.8095 - val_KL_loss_metric: 5.8749
# Epoch 56/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.6317 - RecoProb_metric: 22.7651 - KL_loss_metric: 5.8667 - val_loss: 28.5002 - val_RecoProb_metric: 22.6149 - val_KL_loss_metric: 5.8853
# Epoch 57/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 28.5821 - RecoProb_metric: 22.6968 - KL_loss_metric: 5.8853 - val_loss: 28.4241 - val_RecoProb_metric: 22.5428 - val_KL_loss_metric: 5.8813
# Epoch 58/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.5533 - RecoProb_metric: 22.6462 - KL_loss_metric: 5.9071 - val_loss: 28.3853 - val_RecoProb_metric: 22.4999 - val_KL_loss_metric: 5.8853
# Epoch 59/100
# 1600000/1600000 [==============================] - 20s 12us/step - loss: 28.5054 - RecoProb_metric: 22.5894 - KL_loss_metric: 5.9161 - val_loss: 28.5015 - val_RecoProb_metric: 22.5210 - val_KL_loss_metric: 5.9805
# Epoch 60/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.4510 - RecoProb_metric: 22.5226 - KL_loss_metric: 5.9284 - val_loss: 28.7590 - val_RecoProb_metric: 22.8123 - val_KL_loss_metric: 5.9467
# Epoch 61/100
# 1600000/1600000 [==============================] - 17s 10us/step - loss: 28.3673 - RecoProb_metric: 22.4138 - KL_loss_metric: 5.9534 - val_loss: 28.2185 - val_RecoProb_metric: 22.2451 - val_KL_loss_metric: 5.9734
# Epoch 62/100
# 1600000/1600000 [==============================] - 20s 12us/step - loss: 28.3103 - RecoProb_metric: 22.3481 - KL_loss_metric: 5.9621 - val_loss: 28.2483 - val_RecoProb_metric: 22.2768 - val_KL_loss_metric: 5.9714
# Epoch 63/100
# 1600000/1600000 [==============================] - 22s 14us/step - loss: 28.2477 - RecoProb_metric: 22.2642 - KL_loss_metric: 5.9835 - val_loss: 28.5728 - val_RecoProb_metric: 22.5593 - val_KL_loss_metric: 6.0134
# Epoch 64/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 28.2228 - RecoProb_metric: 22.2175 - KL_loss_metric: 6.0053 - val_loss: 28.1278 - val_RecoProb_metric: 22.1018 - val_KL_loss_metric: 6.0260
# Epoch 65/100
# 1600000/1600000 [==============================] - 18s 12us/step - loss: 28.1577 - RecoProb_metric: 22.1265 - KL_loss_metric: 6.0312 - val_loss: 28.1916 - val_RecoProb_metric: 22.1385 - val_KL_loss_metric: 6.0531
# Epoch 66/100
# 1600000/1600000 [==============================] - 20s 12us/step - loss: 28.1312 - RecoProb_metric: 22.0764 - KL_loss_metric: 6.0548 - val_loss: 28.0277 - val_RecoProb_metric: 21.9847 - val_KL_loss_metric: 6.0430
# Epoch 67/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.0685 - RecoProb_metric: 21.9960 - KL_loss_metric: 6.0725 - val_loss: 27.9557 - val_RecoProb_metric: 21.8680 - val_KL_loss_metric: 6.0877
# Epoch 68/100
# 1600000/1600000 [==============================] - 19s 12us/step - loss: 28.0614 - RecoProb_metric: 21.9709 - KL_loss_metric: 6.0905 - val_loss: 28.1028 - val_RecoProb_metric: 22.0175 - val_KL_loss_metric: 6.0853
# Epoch 69/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 28.0271 - RecoProb_metric: 21.9249 - KL_loss_metric: 6.1022 - val_loss: 27.9444 - val_RecoProb_metric: 21.7806 - val_KL_loss_metric: 6.1638
# Epoch 70/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 27.9941 - RecoProb_metric: 21.8795 - KL_loss_metric: 6.1146 - val_loss: 28.1245 - val_RecoProb_metric: 21.9860 - val_KL_loss_metric: 6.1386
# Epoch 71/100
# 1600000/1600000 [==============================] - 17s 11us/step - loss: 27.9561 - RecoProb_metric: 21.8287 - KL_loss_metric: 6.1274 - val_loss: 27.8758 - val_RecoProb_metric: 21.7376 - val_KL_loss_metric: 6.1382
# Epoch 72/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 27.9165 - RecoProb_metric: 21.7695 - KL_loss_metric: 6.1470 - val_loss: 27.8509 - val_RecoProb_metric: 21.6629 - val_KL_loss_metric: 6.1880
# Epoch 73/100
# 1600000/1600000 [==============================] - 18s 11us/step - loss: 27.8895 - RecoProb_metric: 21.7056 - KL_loss_metric: 6.1839 - val_loss: 27.9777 - val_RecoProb_metric: 21.7877 - val_KL_loss_metric: 6.1900
# Epoch 74/100
# 1600000/1600000 [==============================] - 22s 13us/step - loss: 27.8103 - RecoProb_metric: 21.6020 - KL_loss_metric: 6.2082 - val_loss: 27.7015 - val_RecoProb_metric: 21.4611 - val_KL_loss_metric: 6.2404
# Epoch 75/100
# 1600000/1600000 [==============================] - 26s 16us/step - loss: 27.7523 - RecoProb_metric: 21.5134 - KL_loss_metric: 6.2390 - val_loss: 27.6957 - val_RecoProb_metric: 21.4705 - val_KL_loss_metric: 6.2252
# Epoch 76/100
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.7136 - RecoProb_metric: 21.4565 - KL_loss_metric: 6.2572 - val_loss: 27.5575 - val_RecoProb_metric: 21.2498 - val_KL_loss_metric: 6.3077
# Epoch 77/100
# 1600000/1600000 [==============================] - 26s 17us/step - loss: 27.7028 - RecoProb_metric: 21.4293 - KL_loss_metric: 6.2734 - val_loss: 27.5783 - val_RecoProb_metric: 21.3045 - val_KL_loss_metric: 6.2738
# Epoch 78/100
# 1600000/1600000 [==============================] - 27s 17us/step - loss: 27.6988 - RecoProb_metric: 21.4119 - KL_loss_metric: 6.2869 - val_loss: 27.5607 - val_RecoProb_metric: 21.2977 - val_KL_loss_metric: 6.2630
# Epoch 79/100
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.8814 - RecoProb_metric: 21.5340 - KL_loss_metric: 6.3474 - val_loss: 27.6903 - val_RecoProb_metric: 21.3934 - val_KL_loss_metric: 6.2968
# Epoch 80/100
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.6131 - RecoProb_metric: 21.2979 - KL_loss_metric: 6.3152 - val_loss: 27.5875 - val_RecoProb_metric: 21.2518 - val_KL_loss_metric: 6.3357
# Epoch 81/100
# 1597200/1600000 [============================>.] - ETA: 0s - loss: 27.6075 - RecoProb_metric: 21.2938 - KL_loss_metric: 6.3136
# Epoch 00081: reducing learning rate to 1.0000000475e-05.
# 1600000/1600000 [==============================] - 26s 16us/step - loss: 27.6075 - RecoProb_metric: 21.2939 - KL_loss_metric: 6.3136 - val_loss: 27.5025 - val_RecoProb_metric: 21.1701 - val_KL_loss_metric: 6.3324
# Epoch 82/100
# 1600000/1600000 [==============================] - 26s 16us/step - loss: 27.4257 - RecoProb_metric: 21.0943 - KL_loss_metric: 6.3313 - val_loss: 27.4307 - val_RecoProb_metric: 21.0974 - val_KL_loss_metric: 6.3332
# Epoch 83/100
# 1600000/1600000 [==============================] - 26s 16us/step - loss: 27.4201 - RecoProb_metric: 21.0834 - KL_loss_metric: 6.3367 - val_loss: 27.4328 - val_RecoProb_metric: 21.1023 - val_KL_loss_metric: 6.3305
# Epoch 84/100
# 1600000/1600000 [==============================] - 26s 16us/step - loss: 27.4201 - RecoProb_metric: 21.0783 - KL_loss_metric: 6.3418 - val_loss: 27.4229 - val_RecoProb_metric: 21.0731 - val_KL_loss_metric: 6.3498
# Epoch 85/100
# 1600000/1600000 [==============================] - 27s 17us/step - loss: 27.4198 - RecoProb_metric: 21.0742 - KL_loss_metric: 6.3456 - val_loss: 27.4420 - val_RecoProb_metric: 21.1016 - val_KL_loss_metric: 6.3404
# Epoch 86/100
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.4092 - RecoProb_metric: 21.0620 - KL_loss_metric: 6.3472 - val_loss: 27.3925 - val_RecoProb_metric: 21.0505 - val_KL_loss_metric: 6.3420
# Epoch 87/100
# 1597600/1600000 [============================>.] - ETA: 0s - loss: 27.4029 - RecoProb_metric: 21.0549 - KL_loss_metric: 6.3480
# Epoch 00087: reducing learning rate to 1.00000006569e-06.
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.4028 - RecoProb_metric: 21.0548 - KL_loss_metric: 6.3480 - val_loss: 27.4208 - val_RecoProb_metric: 21.0828 - val_KL_loss_metric: 6.3379
# Epoch 88/100
# 1600000/1600000 [==============================] - 25s 15us/step - loss: 27.3884 - RecoProb_metric: 21.0423 - KL_loss_metric: 6.3461 - val_loss: 27.3916 - val_RecoProb_metric: 21.0447 - val_KL_loss_metric: 6.3469
# Epoch 89/100
# 1600000/1600000 [==============================] - 25s 15us/step - loss: 27.3922 - RecoProb_metric: 21.0403 - KL_loss_metric: 6.3519 - val_loss: 27.3919 - val_RecoProb_metric: 21.0379 - val_KL_loss_metric: 6.3540
# Epoch 90/100
# 1600000/1600000 [==============================] - 25s 16us/step - loss: 27.3837 - RecoProb_metric: 21.0313 - KL_loss_metric: 6.3523 - val_loss: 27.3924 - val_RecoProb_metric: 21.0423 - val_KL_loss_metric: 6.3500
# Epoch 00090: early stopping

# %%
# %matplotlib inline
f = plt.figure(figsize=(16,8))
style = {'loss':'--', 'RecoProb_metric': 'o', 'KL_loss_metric': '--'}
for item in ['loss', 'RecoProb_metric', 'KL_loss_metric']:
    plt.plot(np.array(fit_report.history[item][:])[1:], style[item], label=item)
    plt.plot(np.array(fit_report.history['val_'+item][:])[1:], style[item], label='val_'+item)

plt.xlabel('Epoch')
plt.grid()
plt.legend(loc='best')

# %%
if 1:
    vae.save('VAE_Wlnu_HLF_v3.1.h5')
else:
    from keras.models import load_model
    custom_objects = {
        'original_dim': x_train.shape[1],
        'latent_dim': latent_dim,
        'intermediate_dim': intermediate_dim,
        'act_fun': act_fun,
        'Nf_lognorm' : Nf_lognorm,
        'Nf_gauss' : Nf_gauss,
        'Nf_Pgauss' : Nf_Pgauss,
        'Nf_PDgauss' : Nf_PDgauss,
        'Nf_binomial' : Nf_binomial,
        'Nf_poisson' : Nf_poisson,
        'LossVAE': LossVAE,
        'RecoProb_metric': RecoProb_metric,
        'KL_loss_metric': KL_loss_metric    
    }
    
    vae = load_model('VAE_Wlnu_HLF_v3.1.h5', custom_objects=custom_objects)
    print 'Loaded'

# %% [markdown]
# ### Build encoder and decoder

# %% [markdown]
# Get prior means and variance array

# %%
if 1:
    Prior_Dumper = Model(inputs=x_DNN_input, outputs=[L_prior_mean, L_prior_sigma])
    Prior_Dumper.save('prior_Wlnu_HLF_v3.1.h5')
else:
    Prior_Dumper = load_model('last_saved_prior.h5', custom_objects=custom_objects)
    
aux = Prior_Dumper.predict(np.zeros((1, original_dim)))
mu_prior = aux[0][0]
sigma_prior = aux[1][0]

print mu_prior
print sigma_prior
# Out:
# [11.060321  -3.48145   -2.4929256  4.555655 ]
# [4.8096905 1.0780523 3.2769547 1.7288575]

# %%
if 1:
    encoder = Model(inputs=x_DNN_input, outputs=[L_z_mean, L_z_sigma])
    encoder.save('encoder_Wlnu_HLF_v3.1.h5')
else:
    encoder = load_model('encoder_Wlnu_HLF_v3.1.h5', custom_objects=custom_objects)

# %% [markdown]
# # Validation

# %% [markdown]
# Gather the signal data

# %%
data_folder = '../../data/HLF_ONLY/'

BSM_samples = ['Ato4l', 'Zprime', 'Wprime', 'leptoquark', 'qcd', 'ttbar']

x_sig = {}
for n in BSM_samples:
    s = np.load(data_folder+n+'_lepFilter_13TeV_sample.npy')
    x_sig[n] = s[:N_train, sel]

# %% [markdown]
# ### Predict latent space

# %%
x_train_encoded = np.array(encoder.predict(x_train))

x_sig_encoded = {}
for k,v in x_sig.iteritems():
    print k
    x_sig_encoded[k] = np.array(encoder.predict(v))
# Out:
# Ato4l
# Wprime
# qcd
# leptoquark
# Zprime
# ttbar

# %% [markdown]
# Latent space mean distribution

# %%
def sum_of_gaussians(x, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    single_gaus_val = np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_gaus_val, axis=1)/mu_vec.shape[0]

# %%
histos = []
canvases = []
binning = [70, -8, 8]

for kk in range(latent_dim):
    c = rt.TCanvas('c'+str(kk), 'c'+str(kk), 600, 400)

    lower_bound = mu_prior[kk] - 6*sigma_prior[kk]
    upper_bound = mu_prior[kk] + 6*sigma_prior[kk]
    h = rt.TH1F('hSM{}_{}'.format(SampleName, kk), SampleName, binning[0], lower_bound, upper_bound)
    z = x_train_encoded[0, :, kk]
    rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))
    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    
    h.SetTitle('')
    h.SetXTitle('Mean of z_{'+str(kk)+'}')
    h.SetYTitle('Probability')
    
    h.Draw('Bar SAME')
    histos.append(h)


    colors = [1,2,4,rt.kYellow+2,6,7,8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        h = rt.TH1F('hBSM{}_{}'.format(i, kk), n, binning[0], lower_bound, upper_bound)
        z = x_sig_encoded[n][0, :, kk]
        rtnp.fill_hist(h, z, weights=1/float(z.shape[0])*np.ones_like(z))

        h.SetStats(0)
        h.SetLineColor(colors[i])
        h.SetLineWidth(2)
        h.Draw('SAME')
        histos.append(h)

    c.BuildLegend()
    c.SetGrid()
    c.SetLogy()
    c.Draw()
    canvases.append(c)

# %% [markdown]
# ## Recostruction sum of pdf

# %%
if 1:
    autoencoder = Model(inputs=x_DNN_input, outputs=[L_par1, L_par2, L_par3])
    autoencoder.save('autoencoder_Wlnu_HLF_v3.1.h5')
else:
    autoencoder = load_model('autoencoder_Wlnu_HLF_v3.1.h5', custom_objects=custom_objects)

# %%
pars_ae_train = autoencoder.predict(x_train)
# print pars_ae_train.shape

pars_ae_sig = {}
for k,v in x_sig.iteritems():
    print k
    pars_ae_sig[k] = autoencoder.predict(v)
# Out:
# Ato4l
# Wprime
# qcd
# leptoquark
# Zprime
# ttbar

# %%
def sum_of_possion(x_in, mu_vec):
    out = np.zeros_like(x_in)
    for i, aux in enumerate(x_in):
        out[i] = np.sum(poisson.pmf(aux, mu_vec))
    return out

# %%
def sum_of_lognorm(x, f, mu_vec, sigma_vec):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    x_clipped = np.clip(x, clip_x_to0, 1e8)
    x_norm = (np.log(x_clipped) - mu_vec)/sigma_vec
    single_prob = np.where(np.less(x, clip_x_to0),
                               f,
                               (1-f)*np.exp(-0.5*np.square(x_norm))/(x_clipped*sigma_vec*np.sqrt(2*np.pi))
    )
    return np.sum(single_prob, axis=1)/mu_vec.shape[0]

# %%
from scipy.special import erf
def sum_of_PDgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    
    zp = (x + 0.5 - mu)/sigma
    zm = (x - 0.5 - mu)/sigma
    
    norm_0 = (-0.5 - mu)/sigma
    
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    single_prob = aNorm*0.5*(erf(zp/np.sqrt(2)) - erf(zm/np.sqrt(2)))
    return np.sum(single_prob, axis=1)/mu.shape[0]

def sum_of_Pgauss(x, mu, sigma):
    x = np.atleast_2d(x)
    if x.shape[0] <= x.shape[1]:
        x = x.T
    x_norm = (x - mu_vec)/sigma_vec
    norm_0 = - mu/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/np.sqrt(2)))
    
    single_prob = aNorm*np.exp(-0.5*np.square(x_norm))/(sigma_vec*np.sqrt(2*np.pi))
    return np.sum(single_prob, axis=1)/mu.shape[0]

# %%
f, ax_arr = plt.subplots(1+int(len(active_hlf_features)/3.),3 , figsize=(18,36))

for i,hlf_name in enumerate(active_hlf_features):
    print hlf_name
#     plt.yscale('log', nonposy='clip')
    
    #Plot distribution of the variable
    x_aux = x_train[:, i]
    if i < Nf_lognorm:
        histo_range = (0, np.percentile(x_aux, 99.))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        if np.sum(bin_edges>clip_x_to0) > 0:
            i_aux = np.argmin(bin_edges<clip_x_to0)
            bin_edges = np.concatenate((np.array([0, clip_x_to0]), bin_edges[i_aux:]))
        else:
            bin_edges = np.array([0, clip_x_to0])
        bin_content, bin_edges = np.histogram(x_aux, bins=bin_edges, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bin_edges[1:] - bin_edges[:-1]
        bin_width[0] = 1.

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        f_vec = pars_ae_train[2][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_lognorm(bincenters, f_vec, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_gaussians(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss:
        histo_range = (np.percentile(x_aux, .1), np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=40, range=histo_range)
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_Pgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]

        mu_vec = pars_ae_train[0][:, i]
        sigma_vec = pars_ae_train[1][:, i]
        spdf_bin_content = np.sum(bin_content)*bin_width*sum_of_PDgauss(bincenters, mu_vec, sigma_vec)
    elif i < Nf_lognorm + Nf_gauss + Nf_Pgauss + Nf_PDgauss + Nf_binomial:
        bin_content, bin_edges = np.histogram(x_aux, bins=2, range=(np.min(x_aux), np.max(x_aux)))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        p = 0.5*(1+0.98*np.tanh(pars_ae_train[0][:, i]))

        spdf_bin_content = np.zeros_like(bincenters)
        spdf_bin_content[np.nonzero(bin_content)[0][1]] = np.sum(p)
        spdf_bin_content[np.nonzero(bin_content)[0][0]] = np.sum(1-p)
    else:
        Nmax = int(np.percentile(x_aux, 99.9))
        bin_content, bin_edges = np.histogram(x_aux, bins=Nmax+1, range=(-0.5, Nmax+0.5))
        bincenters = 0.5*(bin_edges[1:]+bin_edges[:-1])
        bin_width = bincenters[1]-bincenters[0]
        aux = pars_ae_train[0][:, i]
        mu_vec = 1 + np.where(np.greater(aux, 0), aux, np.divide(aux, np.sqrt(1+np.square(aux))))
        spdf_bin_content = sum_of_possion(bincenters, mu_vec)


    if i < Nf_lognorm:
        bin_width[0] = clip_x_to0
        
    ax_arr[i/3, i%3].errorbar(bincenters, bin_content, xerr=bin_width/2., yerr=np.sqrt(bin_content), fmt='.b', label='input')
    ax_arr[i/3, i%3].errorbar(bincenters, spdf_bin_content, xerr=bin_width/2., fmt='.r', label='spdf')
    ax_arr[i/3, i%3].grid()
    ax_arr[i/3, i%3].set_title(hlf_name + ' - ' + SampleName)        
    ax_arr[i/3, i%3].legend(loc='best')
    
    if hlf_name.startswith('LepIso') or hlf_name.startswith('all'):
        ax_arr[i/3, i%3].set_yscale('log')
        
plt.show()
# Out:
# HT
# MET
# allJetMass
# allMuPt
# allElePt
# allEleMass
# allMuMass
# LepPt
# LepIsoCh
# LepIsoGamma
# LepIsoNeu
# LepEta
# DPhiMETLep
# MT
# nMu
# nJets
# bJets
# nEle
# LepCharge
# LepIsEle
# nChHad
# nNeuHad
# nPhoton

# %% [markdown]
# # Test Statistics with Losses

# %%
from scipy.special import loggamma

# %%
def numpy_KL_loss(mu, sigma):
    sp = np.atleast_2d(sigma_prior)
    mp = np.atleast_2d(mu_prior)
    kl_loss = np.square(sigma)*np.square(sp)
    kl_loss += np.square((mp - mu)/sp)
    kl_loss += np.log(sp/sigma) -1

    return 0.5 * np.sum(kl_loss, axis=-1)

def numpy_RecoProb(x, par1, par2, par3):
    N = 0
    nll_loss = 0
    
    #Log-Normal distributed variables
    mu = par1[:,:Nf_lognorm]
    sigma = par2[:,:Nf_lognorm]
    fraction = par3[:,:Nf_lognorm]
    x_clipped = np.clip(x[:,:Nf_lognorm], clip_x_to0, 1e8)
    single_NLL = np.where(np.less(x[:,:Nf_lognorm], clip_x_to0), 
                            -np.log(fraction),
                                -np.log(1-fraction)
                                + np.log(sigma) 
                                + np.log(x_clipped)
                                + 0.5*np.square((np.log(x_clipped) - mu) / sigma)
                           )
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_lognorm
    
    # Gaussian distributed variables
    mu = par1[:,N:N+Nf_gauss]
    sigma = par2[:,N:N+Nf_gauss]
    norm_x = (x[:,N:N+Nf_gauss] - mu)/sigma
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_gauss
    
    # Positive Gaussian distributed variables
    mu = par1[:,N:N+Nf_Pgauss]
    sigma = par2[:,N:N+Nf_Pgauss]
    norm_x = (x[:,N:N+Nf_Pgauss] - mu)/sigma

    sqrt2 = 1.4142135624
    aNorm = 1 + 0.5*(1 + erf( -mu/(sigma*sqrt2) ))
    
    single_NLL = np.log(sigma) + 0.5*np.square(norm_x) - np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_Pgauss
    
    # Positive Discrete Gaussian distributed variables
    mu = par1[:,N:N+Nf_PDgauss]
    sigma = par2[:,N:N+Nf_PDgauss]
    norm_xp = (x[:,N:N+Nf_PDgauss] + 0.5 - mu)/sigma
    norm_xm = (x[:,N:N+Nf_PDgauss] - 0.5 - mu)/sigma
    sqrt2 = 1.4142135624
    single_LL = 0.5*(erf(norm_xp/sqrt2) - erf(norm_xm/sqrt2))
    
    norm_0 = (-0.5 - mu)/sigma
    aNorm = 1 + 0.5*(1 + erf(norm_0/sqrt2))
    
    single_NLL = -np.log(np.clip(single_LL, 1e-10, 1e40)) -np.log(aNorm)
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_PDgauss
    
    #Binomial distributed variables
    p = 0.5*(1+0.98*np.tanh(par1[:, N: N+Nf_binomial]))
    single_NLL = -np.where(np.equal(x[:, N: N+Nf_binomial],1), np.log(p), np.log(1-p))
    nll_loss += np.sum(single_NLL, axis=-1)
    N += Nf_binomial
    
    #Poisson distributed variables
    aux = par1[:, N:]
    mu = 1 + np.where(np.greater(aux, 0), aux, aux/np.sqrt(1+np.square(aux)))
    single_NLL = loggamma(x[:, N:]+1) - x[:, N:]*np.log(mu) + mu
    nll_loss += np.sum(np.real(single_NLL), axis=-1)
    
    return nll_loss

def numpy_loss(x, x_encoded, pars_ae):
    mu = x_encoded[0]
    sigma = x_encoded[1]    
    kl_loss = numpy_KL_loss(mu, sigma)
    
    nll_loss = numpy_RecoProb(x, pars_ae[0], pars_ae[1], pars_ae[2])
    
    return [nll_loss + kl_loss, nll_loss, kl_loss]

# %%
loss_train = numpy_loss(x_train, x_train_encoded, pars_ae_train)

loss_sig = {}
for n in x_sig.keys():
    print n
    loss_sig[n] = numpy_loss(x_sig[n], x_sig_encoded[n], pars_ae_sig[n])
# Out:
# Ato4l
# Wprime
# qcd
# leptoquark
# Zprime
# ttbar

# %%
histos = []
canvases = []

for loss_piece in range(3):
    binning = [100, np.min(loss_train[loss_piece]), np.percentile(loss_train[loss_piece], 100*(1-5e-5))]
    print binning
    c = rt.TCanvas('c'+str(loss_piece), 'c'+str(loss_piece), 800, 600)


    h = rt.TH1F('h_loss_SM{}_{}'.format(SampleName, loss_piece), SampleName, binning[0], binning[1], binning[2])
    rtnp.fill_hist(h, loss_train[loss_piece])
    h.Scale(1./loss_train[loss_piece].shape[0])

    h.SetStats(0)
    h.SetLineColor(rt.kGreen+4-2)
    h.SetFillColorAlpha(rt.kGreen+4-2, 0.7)
    h.SetFillStyle(3001)
    h.Draw('Bar SAME')
    histos.append(h)

    val_to_cut = np.percentile(loss_train[loss_piece], 100*(1-1e-3))
    h.SetTitle(h.GetTitle()+' ({:1.1e})'.format(1e-4))
#     print val_to_cut





    colors = [1,2,4,rt.kYellow+2,6,7, 8]
    # fill
    for i, n in enumerate(x_sig.keys()):
        z = loss_sig[n][loss_piece]
        eff = np.sum(z>val_to_cut)/float(z.shape[0])
#         print n, ': {:1.2e}'.format(eff)
        h1 = rt.TH1F('h_loss_BSM{}_{}'.format(i, loss_piece), n+' ({:1.1e})'.format(eff), binning[0], binning[1], binning[2])
        rtnp.fill_hist(h1, z)
        h1.Scale(1./float(z.shape[0]))

        h1.SetStats(0)
        h1.SetLineColor(colors[i])
        h1.SetLineWidth(2)
        h1.Draw('SAME')
        histos.append(h1)

    c.BuildLegend()
    h.SetTitle('')
    Ytitles = ['Loss tot', 'nll(reco probability)', 'KL divergence']
    h.SetXTitle(Ytitles[loss_piece])
    h.SetYTitle('Probability')

    line = rt.TLine()
    line.SetLineColor(rt.kYellow+1)
    line.SetLineWidth(3)
    line.SetLineStyle(9)
    line.DrawLine(val_to_cut,0, val_to_cut,1)

    c.SetGrid()
    c.SetLogy()
    c.Draw()
    
    canvases.append(c)
# Out:
# [100, 8.976618800606172, 307.20836741249104]
# [100, 3.297708680710504, 287.9412598665174]
# [100, 4.9813666, 110.61183098065761]
